# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches
import scipy
import pickle
import warnings

import sys
sys.path.append('..')
from construct_graph.graph import Graph, Flat
import construct_graph
import solve_laplace_operator

import sparseqr

def generate_guesses(x):
    guesses = []
    for i in x:
        if np.abs(i) < 1e-15:
            guesses.append(np.array([1e-15]))
        else:
            guesses.append(np.linspace(i - 0.4, i + 0.1, 3))
    return np.concatenate(guesses)

def calculate_pde_eigenvalues(m, n):
    return np.sqrt((1 / 3 * (np.pi * m)**2 + 2 / 3 * (np.pi * n)**2))

# %%
powers_of_10_lims = (2, 4)
num_Vs_per_tile = 1
num_graphs_per_power_of_10 = 5
total_dpowers = num_graphs_per_power_of_10 * (powers_of_10_lims[1] - powers_of_10_lims[0]) + 1
power_linspace = np.linspace(powers_of_10_lims[0], powers_of_10_lims[1], total_dpowers)

tiles_per_dim = np.int32(np.sqrt(10**power_linspace / num_Vs_per_tile) * 2 / 3)

# %%
fig, ax = g.plot_graph(return_figax=True, embedding_space="square")
plt.savefig("tiling/rectangular_clamped/large_rectangular_clamped_tiling.png", dpi=200, bbox_inches="tight")

# %%
run_eigenvalue_calculations = True

# %%
if run_eigenvalue_calculations:

    eigenvalue_data = {}

    for tile_num in tiles_per_dim:
        g = construct_graph.tiling.Tiling(tile_type='rectangular_tile',
                                          num_horizontal_displacements=tile_num * 2 + 1,
                                          num_vertical_displacements=tile_num + 1, periodic=False,
                                          autoplot=False)

        if g.num_Vs < 800:
            guesses = np.linspace(1, 10, 400)
        else:
            guesses = generate_guesses([calculate_pde_eigenvalues(m, n) 
                                        for m in range(1, 4) for n in range(1, 4)])
        print(f"num_Vs = {g.num_Vs}")
        print("\n\n\n")
        eigs = solve_laplace_operator.solve_laplace_operator.Eigenvalue_Calculator(g)
        ks = eigs(guesses, printerval=1000, max_steps=1000, tol=1e-12, solve_type="SVD iterate")
        _, index = np.unique(np.round(ks, 6), return_index=True)
        eigenvalues = ks[index]
        eigenvalue_data[g.num_Vs] = eigenvalues.copy()

run_eigenvalue_calculations = False
# Out:
# num_Vs = 91
#
#
#
#
#
# Calculating eig number 0
#
# ----------------------
# Converged at step 6:
#
# k = 3.1415926535897962
# ----------------------
#
# Calculating eig number 1
#
# ----------------------
# Converged at step 6:
#
# k = 3.1415926535897922
# ----------------------
#
# Calculating eig number 2
#
# ----------------------
# Converged at step 6:
#
# k = 3.1415926535897936
# ----------------------
#
# Calculating eig number 3
#
# ----------------------
# Converged at step 6:
#
# k = 3.1415926535897913
# ----------------------
#
# Calculating eig number 4
#
# ----------------------
# Converged at step 6:
#
# k = 3.1415926535897927
# ----------------------
#
# Calculating eig number 5
#
# ----------------------
# Converged at step 6:
#
# k = 3.1415926535897913
# ----------------------
#
# Calculating eig number 6
#
# ----------------------
# Converged at step 6:
#
# k = 3.1415926535897936
# ----------------------
#
# Calculating eig number 7
#
# ----------------------
# Converged at step 6:
#
# k = 3.1415926535897927
# ----------------------
#
# Calculating eig number 8
#
# ----------------------
# Converged at step 6:
#
# k = 3.141592653589793
# ----------------------
#
# Calculating eig number 9
#
# ----------------------
# Converged at step 6:
#
# k = 3.1415926535897922
# ----------------------
#
# Calculating eig number 10
#
# ----------------------
# Converged at step 6:
#
# k = 3.1415926535897967
# ----------------------
#
# Calculating eig number 11
#
# ----------------------
# Converged at step 6:
#
# k = 3.1415926535897927
# ----------------------
#
# Calculating eig number 12
#
# ----------------------
# Converged at step 6:
#
# k = 3.1415926535897953
# ----------------------
#
# Calculating eig number 13
#
# ----------------------
# Converged at step 6:
#
# k = 3.1415926535897927
# ----------------------
#
# Calculating eig number 14
#
# ----------------------
# Converged at step 6:
#
# k = 3.1415926535897936
# ----------------------
#
# Calculating eig number 15
#
# ----------------------
# Converged at step 5:
#
# k = 3.1415926535897922
# ----------------------
#
# Calculating eig number 16
#
# ----------------------
# Converged at step 5:
#
# k = 3.1415926535897913
# ----------------------
#
# Calculating eig number 17
#
# ----------------------
# Converged at step 5:
#
# k = 3.1415926535897927
# ----------------------
#
# Calculating eig number 18
#
# ----------------------
# Converged at step 5:
#
# k = 3.1415926535897944
# ----------------------
#
# Calculating eig number 19
#
# ----------------------
# Converged at step 5:
#
# k = 3.141592653589791
# ----------------------
#
# Calculating eig number 20
#
# ----------------------
# Converged at step 5:
#
# k = 3.1415926535897922
# ----------------------
#
# Calculating eig number 21
#
# ----------------------
# Converged at step 5:
#
# k = 3.1415926535897922
# ----------------------
#
# Calculating eig number 22
#
# ----------------------
# Converged at step 5:
#
# k = 3.141592653589789
# ----------------------
#
# Calculating eig number 23
#
# ----------------------
# Converged at step 5:
#
# k = 3.1415926535897922
# ----------------------
#
# Calculating eig number 24
#
# ----------------------
# Converged at step 5:
#
# k = 3.141592653589792
# ----------------------
#
# Calculating eig number 25
#
# ----------------------
# Converged at step 5:
#
# k = 3.1415926535897962
# ----------------------
#
# Calculating eig number 26
#
# ----------------------
# Converged at step 5:
#
# k = 3.1415926535897936
# ----------------------
#
# Calculating eig number 27
#
# ----------------------
# Converged at step 5:
#
# k = 3.141592653589793
# ----------------------
#
# Calculating eig number 28
#
# ----------------------
# Converged at step 5:
#
# k = 3.1415926535897962
# ----------------------
#
# Calculating eig number 29
#
# ----------------------
# Converged at step 5:
#
# k = 3.1415926535897936
# ----------------------
#
# Calculating eig number 30
#
# ----------------------
# Converged at step 5:
#
# k = 3.141592653589794
# ----------------------
#
# Calculating eig number 31
#
# ----------------------
# Converged at step 5:
#
# k = 3.1415926535897927
# ----------------------
#
# Calculating eig number 32
#
# ----------------------
# Converged at step 5:
#
# k = 3.141592653589793
# ----------------------
#
# Calculating eig number 33
#
# ----------------------
# Converged at step 5:
#
# k = 3.141592653589791
# ----------------------
#
# Calculating eig number 34
#
# ----------------------
# Converged at step 5:
#
# k = 3.141592653589793
# ----------------------
#
# Calculating eig number 35
#
# ----------------------
# Converged at step 5:
#
# k = 3.1415926535897922
# ----------------------
#
# Calculating eig number 36
#
# ----------------------
# Converged at step 5:
#
# k = 3.1415926535897922
# ----------------------
#
# Calculating eig number 37
#
# ----------------------
# Converged at step 5:
#
# k = 3.1415926535897927
# ----------------------
#
# Calculating eig number 38
#
# ----------------------
# Converged at step 5:
#
# k = 3.1415926535897944
# ----------------------
#
# Calculating eig number 39
#
# ----------------------
# Converged at step 5:
#
# k = 3.1415926535897922
# ----------------------
#
# Calculating eig number 40
#
# ----------------------
# Converged at step 5:
#
# k = 3.1415926535897913
# ----------------------
#
# Calculating eig number 41
#
# ----------------------
# Converged at step 5:
#
# k = 3.1415926535897936
# ----------------------
#
# Calculating eig number 42
#
# ----------------------
# Converged at step 5:
#
# k = 3.141592653589792
# ----------------------
#
# Calculating eig number 43
#
# ----------------------
# Converged at step 5:
#
# k = 3.141592653589793
# ----------------------
#
# Calculating eig number 44
#
# ----------------------
# Converged at step 5:
#
# k = 3.141592653589791
# ----------------------
#
# Calculating eig number 45
#
# ----------------------
# Converged at step 5:
#
# k = 3.1415926535897922
# ----------------------
#
# Calculating eig number 46
#
# ----------------------
# Converged at step 5:
#
# k = 3.1415926535897967
# ----------------------
#
# Calculating eig number 47
#
# ----------------------
# Converged at step 5:
#
# k = 3.141592653589796
# ----------------------
#
# Calculating eig number 48
#
# ----------------------
# Converged at step 5:
#
# k = 3.1415926535897913
# ----------------------
#
# Calculating eig number 49
#
# ----------------------
# Converged at step 5:
#
# k = 3.1415926535897936
# ----------------------
#
# Calculating eig number 50
#
# ----------------------
# Converged at step 5:
#
# k = 3.141592653589793
# ----------------------
#
# Calculating eig number 51
#
# ----------------------
# Converged at step 5:
#
# k = 3.141592653589791
# ----------------------
#
# Calculating eig number 52
#
# ----------------------
# Converged at step 5:
#
# k = 3.1415926535897936
# ----------------------
#
# Calculating eig number 53
#
# ----------------------
# Converged at step 5:
#
# k = 3.1415926535897905
# ----------------------
#
# Calculating eig number 54
#
# ----------------------
# Converged at step 5:
#
# k = 3.1415926535897927
# ----------------------
#
# Calculating eig number 55
#
# ----------------------
# Converged at step 5:
#
# k = 3.1415926535897927
# ----------------------
#
# Calculating eig number 56
#
# ----------------------
# Converged at step 4:
#
# k = 3.141592653589795
# ----------------------
#
# Calculating eig number 57
#
# ----------------------
# Converged at step 4:
#
# k = 3.1415926535897967
# ----------------------
#
# Calculating eig number 58
#
# ----------------------
# Converged at step 4:
#
# k = 3.1415926535897944
# ----------------------
#
# Calculating eig number 59
#
# ----------------------
# Converged at step 4:
#
# k = 3.1415926535897953
# ----------------------
#
# Calculating eig number 60
#
# ----------------------
# Converged at step 4:
#
# k = 3.1415926535897927
# ----------------------
#
# Calculating eig number 61
#
# ----------------------
# Converged at step 4:
#
# k = 3.141592653589793
# ----------------------
#
# Calculating eig number 62
#
# ----------------------
# Converged at step 4:
#
# k = 3.141592653589793
# ----------------------
#
# Calculating eig number 63
#
# ----------------------
# Converged at step 4:
#
# k = 3.1415926535897962
# ----------------------
#
# Calculating eig number 64
#
# ----------------------
# Converged at step 4:
#
# k = 3.1415926535897896
# ----------------------
#
# Calculating eig number 65
#
# ----------------------
# Converged at step 4:
#
# k = 3.1415926535897944
# ----------------------
#
# Calculating eig number 66
#
# ----------------------
# Converged at step 4:
#
# k = 3.141592653589792
# ----------------------
#
# Calculating eig number 67
#
# ----------------------
# Converged at step 4:
#
# k = 3.1415926535897927
# ----------------------
#
# Calculating eig number 68
#
# ----------------------
# Converged at step 4:
#
# k = 3.141592653589793
# ----------------------
#
# Calculating eig number 69
#
# ----------------------
# Converged at step 4:
#
# k = 3.141592653589792
# ----------------------
#
# Calculating eig number 70
#
# ----------------------
# Converged at step 4:
#
# k = 3.141592653589792
# ----------------------
#
# Calculating eig number 71
#
# ----------------------
# Converged at step 4:
#
# k = 3.141592653589796
# ----------------------
#
# Calculating eig number 72
#
# ----------------------
# Converged at step 4:
#
# k = 3.1415926535897922
# ----------------------
#
# Calculating eig number 73
#
# ----------------------
# Converged at step 4:
#
# k = 3.1415926535897944
# ----------------------
#
# Calculating eig number 74
#
# ----------------------
# Converged at step 4:
#
# k = 3.1415926535897962
# ----------------------
#
# Calculating eig number 75
#
# ----------------------
# Converged at step 4:
#
# k = 3.1415926535897927
# ----------------------
#
# Calculating eig number 76
#
# ----------------------
# Converged at step 4:
#
# k = 3.141592653589793
# ----------------------
#
# Calculating eig number 77
#
# ----------------------
# Converged at step 4:
#
# k = 3.1415926535897927
# ----------------------
#
# Calculating eig number 78
#
# ----------------------
# Converged at step 4:
#
# k = 3.1415926535897905
# ----------------------
#
# Calculating eig number 79
#
# ----------------------
# Converged at step 4:
#
# k = 3.141592653589795
# ----------------------
#
# Calculating eig number 80
#
# ----------------------
# Converged at step 4:
#
# k = 3.141592653589793
# ----------------------
#
# Calculating eig number 81
#
# ----------------------
# Converged at step 4:
#
# k = 3.141592653589793
# ----------------------
#
# Calculating eig number 82
#
# ----------------------
# Converged at step 4:
#
# k = 3.141592653589794
# ----------------------
#
# Calculating eig number 83
#
# ----------------------
# Converged at step 4:
#
# k = 3.141592653589793
# ----------------------
#
# Calculating eig number 84
#
# ----------------------
# Converged at step 4:
#
# k = 3.141592653589792
# ----------------------
#
# Calculating eig number 85
#
# ----------------------
# Converged at step 4:
#
# k = 3.141592653589796
# ----------------------
#
# Calculating eig number 86
#
# ----------------------
# Converged at step 4:
#
# k = 3.1415926535897936
# ----------------------
#
# Calculating eig number 87
#
# ----------------------
# Converged at step 4:
#
# k = 3.1415926535897913
# ----------------------
#
# Calculating eig number 88
#
# ----------------------
# Converged at step 3:
#
# k = 3.1415926535897913
# ----------------------
#
# Calculating eig number 89
#
# ----------------------
# Converged at step 3:
#
# k = 3.141592653589793
# ----------------------
#
# Calculating eig number 90
#
# ----------------------
# Converged at step 3:
#
# k = 3.141592653589797
# ----------------------
#
# Calculating eig number 91
#
# ----------------------
# Converged at step 3:
#
# k = 3.1415926535897905
# ----------------------
#
# Calculating eig number 92
#
# ----------------------
# Converged at step 3:
#
# k = 3.141592653589792
# ----------------------
#
# Calculating eig number 93
#
# ----------------------
# Converged at step 3:
#
# k = 3.1415926535897913
# ----------------------
#
# Calculating eig number 94
#
# ----------------------
# Converged at step 3:
#
# k = 3.141592653589795
# ----------------------
#
# Calculating eig number 95
#
# ----------------------
# Converged at step 3:
#
# k = 3.1415926535897944
# ----------------------
#
# Calculating eig number 96
#
# ----------------------
# Converged at step 4:
#
# k = 3.141592653589791
# ----------------------
#
# Calculating eig number 97
#
# ----------------------
# Converged at step 4:
#
# k = 3.141592653589794
# ----------------------
#
# Calculating eig number 98
#
# ----------------------
# Converged at step 4:
#
# k = 3.1415926535897922
# ----------------------
#
# Calculating eig number 99
#
# ----------------------
# Converged at step 5:
#
# k = 3.141592653589791
# ----------------------
#
# Calculating eig number 100
#
# ----------------------
# Converged at step 5:
#
# k = 3.1415926535897967
# ----------------------
#
# Calculating eig number 101
#
# ----------------------
# Converged at step 5:
#
# k = 3.141592653589791
# ----------------------
#
# Calculating eig number 102
#
# ----------------------
# Converged at step 5:
#
# k = 3.1415926535897936
# ----------------------
#
# Calculating eig number 103
#
# ----------------------
# Converged at step 5:
#
# k = 3.141592653589793
# ----------------------
#
# Calculating eig number 104
#
# ----------------------
# Converged at step 5:
#
# k = 3.1415926535897927
# ----------------------
#
# Calculating eig number 105
#
# ----------------------
# Converged at step 5:
#
# k = 3.141592653589793
# ----------------------
#
# Calculating eig number 106
#
# ----------------------
# Converged at step 5:
#
# k = 3.141592653589793
# ----------------------
#
# Calculating eig number 107
#
# ----------------------
# Converged at step 5:
#
# k = 3.141592653589793
# ----------------------
#
# Calculating eig number 108
#
# ----------------------
# Converged at step 5:
#
# k = 3.141592653589793
# ----------------------
#
# Calculating eig number 109
#
# ----------------------
# Converged at step 5:
#
# k = 3.1415926535897905
# ----------------------
#
# Calculating eig number 110
#
# ----------------------
# Converged at step 5:
#
# k = 3.1415926535897913
# ----------------------
#
# Calculating eig number 111
#
# ----------------------
# Converged at step 5:
#
# k = 3.1415926535897962
# ----------------------
#
# Calculating eig number 112
#
# ----------------------
# Converged at step 5:
#
# k = 3.141592653589791
# ----------------------
#
# Calculating eig number 113
#
# ----------------------
# Converged at step 5:
#
# k = 3.141592653589793
# ----------------------
#
# Calculating eig number 114
#
# ----------------------
# Converged at step 5:
#
# k = 3.141592653589794
# ----------------------
#
# Calculating eig number 115
#
# ----------------------
# Converged at step 5:
#
# k = 3.1415926535897944
# ----------------------
#
# Calculating eig number 116
#
# ----------------------
# Converged at step 5:
#
# k = 3.1415926535897896
# ----------------------
#
# Calculating eig number 117
#
# ----------------------
# Converged at step 5:
#
# k = 3.1415926535897913
# ----------------------
#
# Calculating eig number 118
#
# ----------------------
# Converged at step 5:
#
# k = 3.1415926535897927
# ----------------------
#
# Calculating eig number 119
#
# ----------------------
# Converged at step 5:
#
# k = 3.1415926535897936
# ----------------------
#
# Calculating eig number 120
#
# ----------------------
# Converged at step 5:
#
# k = 3.1415926535897927
# ----------------------
#
# Calculating eig number 121
#
# ----------------------
# Converged at step 5:
#
# k = 3.141592653589793
# ----------------------
#
# Calculating eig number 122
#
# ----------------------
# Converged at step 5:
#
# k = 3.1415926535897953
# ----------------------
#
# Calculating eig number 123
#
# ----------------------
# Converged at step 5:
#
# k = 3.141592653589794
# ----------------------
#
# Calculating eig number 124
#
# ----------------------
# Converged at step 5:
#
# k = 3.141592653589797
# ----------------------
#
# Calculating eig number 125
#
# ----------------------
# Converged at step 5:
#
# k = 3.141592653589789
# ----------------------
#
# Calculating eig number 126
#
# ----------------------
# Converged at step 4:
#
# k = 4.4172009927921865
# ----------------------
#
# Calculating eig number 127
#
# ----------------------
# Converged at step 4:
#
# k = 4.417200992792187
# ----------------------
#
# Calculating eig number 128
#
# ----------------------
# Converged at step 4:
#
# k = 4.417200992792186
# ----------------------
#
# Calculating eig number 129
#
# ----------------------
# Converged at step 4:
#
# k = 4.417200992792183
# ----------------------
#
# Calculating eig number 130
#
# ----------------------
# Converged at step 4:
#
# k = 4.417200992792183
# ----------------------
#
# Calculating eig number 131
#
# ----------------------
# Converged at step 4:
#
# k = 4.417200992792187
# ----------------------
#
# Calculating eig number 132
#
# ----------------------
# Converged at step 4:
#
# k = 4.417200992792183
# ----------------------
#
# Calculating eig number 133
#
# ----------------------
# Converged at step 4:
#
# k = 4.417200992792183
# ----------------------
#
# Calculating eig number 134
#
# ----------------------
# Converged at step 4:
#
# k = 4.417200992792183
# ----------------------
#
# Calculating eig number 135
#
# ----------------------
# Converged at step 4:
#
# k = 4.417200992792183
# ----------------------
#
# Calculating eig number 136
#
# ----------------------
# Converged at step 4:
#
# k = 4.417200992792183
# ----------------------
#
# Calculating eig number 137
#
# ----------------------
# Converged at step 4:
#
# k = 4.417200992792183
# ----------------------
#
# Calculating eig number 138
#
# ----------------------
# Converged at step 4:
#
# k = 4.417200992792183
# ----------------------
#
# Calculating eig number 139
#
# ----------------------
# Converged at step 4:
#
# k = 4.4172009927921865
# ----------------------
#
# Calculating eig number 140
#
# ----------------------
# Converged at step 4:
#
# k = 4.417200992792186
# ----------------------
#
# Calculating eig number 141
#
# ----------------------
# Converged at step 4:
#
# k = 4.417200992792186
# ----------------------
#
# Calculating eig number 142
#
# ----------------------
# Converged at step 3:
#
# k = 4.417200992792187
# ----------------------
#
# Calculating eig number 143
#
# ----------------------
# Converged at step 3:
#
# k = 4.417200992792187
# ----------------------
#
# Calculating eig number 144
#
# ----------------------
# Converged at step 3:
#
# k = 4.417200992792185
# ----------------------
#
# Calculating eig number 145
#
# ----------------------
# Converged at step 3:
#
# k = 4.417200992792186
# ----------------------
#
# Calculating eig number 146
#
# ----------------------
# Converged at step 3:
#
# k = 4.4172009927921865
# ----------------------
#
# Calculating eig number 147
#
# ----------------------
# Converged at step 3:
#
# k = 4.4172009927921865
# ----------------------
#
# Calculating eig number 148
#
# ----------------------
# Converged at step 3:
#
# k = 4.417200992792186
# ----------------------
#
# Calculating eig number 149
#
# ----------------------
# Converged at step 3:
#
# k = 4.417200992792183
# ----------------------
#
# Calculating eig number 150
#
# ----------------------
# Converged at step 3:
#
# k = 4.4172009927921865
# ----------------------
#
# Calculating eig number 151
#
# ----------------------
# Converged at step 3:
#
# k = 4.417200992792186
# ----------------------
#
# Calculating eig number 152
#
# ----------------------
# Converged at step 4:
#
# k = 4.417200992792186
# ----------------------
#
# Calculating eig number 153
#
# ----------------------
# Converged at step 4:
#
# k = 4.417200992792183
# ----------------------
#
# Calculating eig number 154
#
# ----------------------
# Converged at step 4:
#
# k = 4.417200992792187
# ----------------------
#
# Calculating eig number 155
#
# ----------------------
# Converged at step 4:
#
# k = 4.417200992792185
# ----------------------
#
# Calculating eig number 156
#
# ----------------------
# Converged at step 4:
#
# k = 4.417200992792183
# ----------------------
#
# Calculating eig number 157
#
# ----------------------
# Converged at step 4:
#
# k = 4.417200992792186
# ----------------------
#
# Calculating eig number 158
#
# ----------------------
# Converged at step 5:
#
# k = 4.417200992792187
# ----------------------
#
# Calculating eig number 159
#
# ----------------------
# Converged at step 5:
#
# k = 4.417200992792186
# ----------------------
#
# Calculating eig number 160
#
# ----------------------
# Converged at step 5:
#
# k = 4.4172009927921865
# ----------------------
#
# Calculating eig number 161
#
# ----------------------
# Converged at step 5:
#
# k = 4.417200992792186
# ----------------------
#
# Calculating eig number 162
#
# ----------------------
# Converged at step 5:
#
# k = 4.4172009927921865
# ----------------------
#
# Calculating eig number 163
#
# ----------------------
# Converged at step 5:
#
# k = 4.417200992792185
# ----------------------
#
# Calculating eig number 164
#
# ----------------------
# Converged at step 5:
#
# k = 4.417200992792186
# ----------------------
#
# Calculating eig number 165
#
# ----------------------
# Converged at step 5:
#
# k = 4.417200992792186
# ----------------------
#
# Calculating eig number 166
#
# ----------------------
# Converged at step 5:
#
# k = 4.417200992792183
# ----------------------
#
# Calculating eig number 167
#
# ----------------------
# Converged at step 5:
#
# k = 4.417200992792186
# ----------------------
#
# Calculating eig number 168
#
# ----------------------
# Converged at step 5:
#
# k = 4.4172009927921865
# ----------------------
#
# Calculating eig number 169
#
# ----------------------
# Converged at step 5:
#
# k = 4.417200992792186
# ----------------------
#
# Calculating eig number 170
#
# ----------------------
# Converged at step 5:
#
# k = 4.417200992792187
# ----------------------
#
# Calculating eig number 171
#
# ----------------------
# Converged at step 5:
#
# k = 4.417200992792187
# ----------------------
#
# Calculating eig number 172
#
# ----------------------
# Converged at step 5:
#
# k = 4.4172009927921865
# ----------------------
#
# Calculating eig number 173
#
# ----------------------
# Converged at step 5:
#
# k = 4.417200992792183
# ----------------------
#
# Calculating eig number 174
#
# ----------------------
# Converged at step 5:
#
# k = 4.417200992792186
# ----------------------
#
# Calculating eig number 175
#
# ----------------------
# Converged at step 4:
#
# k = 5.419287476350968
# ----------------------
#
# Calculating eig number 176
#
# ----------------------
# Converged at step 4:
#
# k = 5.419287476350969
# ----------------------
#
# Calculating eig number 177
#
# ----------------------
# Converged at step 4:
#
# k = 5.419287476350968
# ----------------------
#
# Calculating eig number 178
#
# ----------------------
# Converged at step 4:
#
# k = 5.419287476350969
# ----------------------
#
# Calculating eig number 179
#
# ----------------------
# Converged at step 4:
#
# k = 5.419287476350967
# ----------------------
#
# Calculating eig number 180
#
# ----------------------
# Converged at step 4:
#
# k = 5.419287476350968
# ----------------------
#
# Calculating eig number 181
#
# ----------------------
# Converged at step 4:
#
# k = 5.419287476350966
# ----------------------
#
# Calculating eig number 182
#
# ----------------------
# Converged at step 4:
#
# k = 5.419287476350967
# ----------------------
#
# Calculating eig number 183
#
# ----------------------
# Converged at step 3:
#
# k = 5.419287476350966
# ----------------------
#
# Calculating eig number 184
#
# ----------------------
# Converged at step 3:
#
# k = 5.419287476350968
# ----------------------
#
# Calculating eig number 185
#
# ----------------------
# Converged at step 3:
#
# k = 5.419287476350969
# ----------------------
#
# Calculating eig number 186
#
# ----------------------
# Converged at step 3:
#
# k = 5.419287476350966
# ----------------------
#
# Calculating eig number 187
#
# ----------------------
# Converged at step 3:
#
# k = 5.419287476350968
# ----------------------
#
# Calculating eig number 188
#
# ----------------------
# Converged at step 3:
#
# k = 5.419287476350967
# ----------------------
#
# Calculating eig number 189
#
# ----------------------
# Converged at step 3:
#
# k = 5.419287476350966
# ----------------------
#
# Calculating eig number 190
#
# ----------------------
# Converged at step 3:
#
# k = 5.419287476350966
# ----------------------
#
# Calculating eig number 191
#
# ----------------------
# Converged at step 3:
#
# k = 5.419287476350968
# ----------------------
#
# Calculating eig number 192
#
# ----------------------
# Converged at step 3:
#
# k = 5.419287476350967
# ----------------------
#
# Calculating eig number 193
#
# ----------------------
# Converged at step 3:
#
# k = 5.419287476350966
# ----------------------
#
# Calculating eig number 194
#
# ----------------------
# Converged at step 3:
#
# k = 5.419287476350967
# ----------------------
#
# Calculating eig number 195
#
# ----------------------
# Converged at step 3:
#
# k = 5.419287476350966
# ----------------------
#
# Calculating eig number 196
#
# ----------------------
# Converged at step 3:
#
# k = 5.419287476350967
# ----------------------
#
# Calculating eig number 197
#
# ----------------------
# Converged at step 4:
#
# k = 5.419287476350967
# ----------------------
#
# Calculating eig number 198
#
# ----------------------
# Converged at step 4:
#
# k = 5.419287476350966
# ----------------------
#
# Calculating eig number 199
#
# ----------------------
# Converged at step 4:
#
# k = 5.4192874763509655
# ----------------------
#
# Calculating eig number 200
#
# ----------------------
# Converged at step 4:
#
# k = 5.419287476350969
# ----------------------
#
# Calculating eig number 201
#
# ----------------------
# Converged at step 4:
#
# k = 5.4192874763509655
# ----------------------
#
# Calculating eig number 202
#
# ----------------------
# Converged at step 4:
#
# k = 5.419287476350968
# ----------------------
#
# Calculating eig number 203
#
# ----------------------
# Converged at step 4:
#
# k = 5.4192874763509655
# ----------------------
#
# Calculating eig number 204
#
# ----------------------
# Converged at step 5:
#
# k = 5.419287476350966
# ----------------------
#
# Calculating eig number 205
#
# ----------------------
# Converged at step 5:
#
# k = 5.419287476350968
# ----------------------
#
# Calculating eig number 206
#
# ----------------------
# Converged at step 5:
#
# k = 5.419287476350966
# ----------------------
#
# Calculating eig number 207
#
# ----------------------
# Converged at step 3:
#
# k = 5.880960317950028
# ----------------------
#
# Calculating eig number 208
#
# ----------------------
# Converged at step 3:
#
# k = 5.880960317950027
# ----------------------
#
# Calculating eig number 209
#
# ----------------------
# Converged at step 3:
#
# k = 5.880960317950029
# ----------------------
#
# Calculating eig number 210
#
# ----------------------
# Converged at step 3:
#
# k = 5.880960317950026
# ----------------------
#
# Calculating eig number 211
#
# ----------------------
# Converged at step 3:
#
# k = 5.880960317950027
# ----------------------
#
# Calculating eig number 212
#
# ----------------------
# Converged at step 3:
#
# k = 5.880960317950027
# ----------------------
#
# Calculating eig number 213
#
# ----------------------
# Converged at step 3:
#
# k = 5.880960317950028
# ----------------------
#
# Calculating eig number 214
#
# ----------------------
# Converged at step 3:
#
# k = 5.880960317950028
# ----------------------
#
# Calculating eig number 215
#
# ----------------------
# Converged at step 3:
#
# k = 5.880960317950028
# ----------------------
#
# Calculating eig number 216
#
# ----------------------
# Converged at step 3:
#
# k = 5.880960317950027
# ----------------------
#
# Calculating eig number 217
#
# ----------------------
# Converged at step 4:
#
# k = 5.880960317950028
# ----------------------
#
# Calculating eig number 218
#
# ----------------------
# Converged at step 4:
#
# k = 5.880960317950028
# ----------------------
#
# Calculating eig number 219
#
# ----------------------
# Converged at step 4:
#
# k = 5.880960317950026
# ----------------------
#
# Calculating eig number 220
#
# ----------------------
# Converged at step 4:
#
# k = 5.880960317950026
# ----------------------
#
# Calculating eig number 221
#
# ----------------------
# Converged at step 4:
#
# k = 5.880960317950027
# ----------------------
#
# Calculating eig number 222
#
# ----------------------
# Converged at step 4:
#
# k = 5.880960317950028
# ----------------------
#
# Calculating eig number 223
#
# ----------------------
# Converged at step 4:
#
# k = 5.880960317950028
# ----------------------
#
# Calculating eig number 224
#
# ----------------------
# Converged at step 4:
#
# k = 5.880960317950028
# ----------------------
#
# Calculating eig number 225
#
# ----------------------
# Converged at step 4:
#
# k = 5.880960317950025
# ----------------------
#
# Calculating eig number 226
#
# ----------------------
# Converged at step 3:
#
# k = 6.283185307179588
# ----------------------
#
# Calculating eig number 227
#
# ----------------------
# Converged at step 3:
#
# k = 6.283185307179589
# ----------------------
#
# Calculating eig number 228
#
# ----------------------
# Converged at step 3:
#
# k = 6.283185307179587
# ----------------------
#
# Calculating eig number 229
#
# ----------------------
# Converged at step 3:
#
# k = 6.283185307179586
# ----------------------
#
# Calculating eig number 230
#
# ----------------------
# Converged at step 3:
#
# k = 6.283185307179585
# ----------------------
#
# Calculating eig number 231
#
# ----------------------
# Converged at step 3:
#
# k = 6.283185307179588
# ----------------------
#
# Calculating eig number 232
#
# ----------------------
# Converged at step 3:
#
# k = 6.283185307179588
# ----------------------
#
# Calculating eig number 233
#
# ----------------------
# Converged at step 3:
#
# k = 6.283185307179588
# ----------------------
#
# Calculating eig number 234
#
# ----------------------
# Converged at step 2:
#
# k = 6.283185307179587
# ----------------------
#
# Calculating eig number 235
#
# ----------------------
# Converged at step 4:
#
# k = 6.283185307179585
# ----------------------
#
# Calculating eig number 236
#
# ----------------------
# Converged at step 4:
#
# k = 6.283185307179585
# ----------------------
#
# Calculating eig number 237
#
# ----------------------
# Converged at step 4:
#
# k = 6.283185307179586
# ----------------------
#
# Calculating eig number 238
#
# ----------------------
# Converged at step 4:
#
# k = 6.283185307179588
# ----------------------
#
# Calculating eig number 239
#
# ----------------------
# Converged at step 4:
#
# k = 6.283185307179587
# ----------------------
#
# Calculating eig number 240
#
# ----------------------
# Converged at step 4:
#
# k = 6.283185307179587
# ----------------------
#
# Calculating eig number 241
#
# ----------------------
# Converged at step 4:
#
# k = 6.283185307179588
# ----------------------
#
# Calculating eig number 242
#
# ----------------------
# Converged at step 4:
#
# k = 6.283185307179586
# ----------------------
#
# Calculating eig number 243
#
# ----------------------
# Converged at step 4:
#
# k = 6.283185307179587
# ----------------------
#
# Calculating eig number 244
#
# ----------------------
# Converged at step 5:
#
# k = 6.283185307179588
# ----------------------
#
# Calculating eig number 245
#
# ----------------------
# Converged at step 5:
#
# k = 6.283185307179588
# ----------------------
#
# Calculating eig number 246
#
# ----------------------
# Converged at step 5:
#
# k = 6.283185307179587
# ----------------------
#
# Calculating eig number 247
#
# ----------------------
# Converged at step 5:
#
# k = 6.283185307179585
# ----------------------
#
# Calculating eig number 248
#
# ----------------------
# Converged at step 5:
#
# k = 6.283185307179588
# ----------------------
#
# Calculating eig number 249
#
# ----------------------
# Converged at step 5:
#
# k = 6.283185307179587
# ----------------------
#
# Calculating eig number 250
#
# ----------------------
# Converged at step 5:
#
# k = 6.283185307179586
# ----------------------
#
# Calculating eig number 251
#
# ----------------------
# Converged at step 5:
#
# k = 6.283185307179588
# ----------------------
#
# Calculating eig number 252
#
# ----------------------
# Converged at step 5:
#
# k = 6.283185307179585
# ----------------------
#
# Calculating eig number 253
#
# ----------------------
# Converged at step 5:
#
# k = 6.283185307179588
# ----------------------
#
# Calculating eig number 254
#
# ----------------------
# Converged at step 5:
#
# k = 6.283185307179588
# ----------------------
#
# Calculating eig number 255
#
# ----------------------
# Converged at step 5:
#
# k = 6.283185307179588
# ----------------------
#
# Calculating eig number 256
#
# ----------------------
# Converged at step 5:
#
# k = 6.283185307179589
# ----------------------
#
# Calculating eig number 257
#
# ----------------------
# Converged at step 5:
#
# k = 6.283185307179589
# ----------------------
#
# Calculating eig number 258
#
# ----------------------
# Converged at step 5:
#
# k = 6.283185307179588
# ----------------------
#
# Calculating eig number 259
#
# ----------------------
# Converged at step 5:
#
# k = 6.283185307179586
# ----------------------
#
# Calculating eig number 260
#
# ----------------------
# Converged at step 3:
#
# k = 7.326098219970046
# ----------------------
#
# Calculating eig number 261
#
# ----------------------
# Converged at step 3:
#
# k = 7.326098219970047
# ----------------------
#
# Calculating eig number 262
#
# ----------------------
# Converged at step 3:
#
# k = 7.326098219970046
# ----------------------
#
# Calculating eig number 263
#
# ----------------------
# Converged at step 3:
#
# k = 7.326098219970047
# ----------------------
#
# Calculating eig number 264
#
# ----------------------
# Converged at step 3:
#
# k = 7.326098219970045
# ----------------------
#
# Calculating eig number 265
#
# ----------------------
# Converged at step 3:
#
# k = 7.326098219970046
# ----------------------
#
# Calculating eig number 266
#
# ----------------------
# Converged at step 3:
#
# k = 7.326098219970045
# ----------------------
#
# Calculating eig number 267
#
# ----------------------
# Converged at step 3:
#
# k = 7.326098219970045
# ----------------------
#
# Calculating eig number 268
#
# ----------------------
# Converged at step 3:
#
# k = 7.326098219970044
# ----------------------
#
# Calculating eig number 269
#
# ----------------------
# Converged at step 3:
#
# k = 7.326098219970047
# ----------------------
#
# Calculating eig number 270
#
# ----------------------
# Converged at step 3:
#
# k = 7.326098219970046
# ----------------------
#
# Calculating eig number 271
#
# ----------------------
# Converged at step 3:
#
# k = 7.326098219970046
# ----------------------
#
# Calculating eig number 272
#
# ----------------------
# Converged at step 3:
#
# k = 7.326098219970046
# ----------------------
#
# Calculating eig number 273
#
# ----------------------
# Converged at step 3:
#
# k = 7.326098219970047
# ----------------------
#
# Calculating eig number 274
#
# ----------------------
# Converged at step 3:
#
# k = 7.326098219970044
# ----------------------
#
# Calculating eig number 275
#
# ----------------------
# Converged at step 3:
#
# k = 7.326098219970045
# ----------------------
#
# Calculating eig number 276
#
# ----------------------
# Converged at step 3:
#
# k = 7.326098219970044
# ----------------------
#
# Calculating eig number 277
#
# ----------------------
# Converged at step 3:
#
# k = 7.326098219970045
# ----------------------
#
# Calculating eig number 278
#
# ----------------------
# Converged at step 3:
#
# k = 7.326098219970045
# ----------------------
#
# Calculating eig number 279
#
# ----------------------
# Converged at step 3:
#
# k = 7.326098219970045
# ----------------------
#
# Calculating eig number 280
#
# ----------------------
# Converged at step 2:
#
# k = 7.326098219970045
# ----------------------
#
# Calculating eig number 281
#
# ----------------------
# Converged at step 4:
#
# k = 7.326098219970046
# ----------------------
#
# Calculating eig number 282
#
# ----------------------
# Converged at step 4:
#
# k = 7.326098219970044
# ----------------------
#
# Calculating eig number 283
#
# ----------------------
# Converged at step 3:
#
# k = 7.4343045888406545
# ----------------------
#
# Calculating eig number 284
#
# ----------------------
# Converged at step 3:
#
# k = 7.434304588840656
# ----------------------
#
# Calculating eig number 285
#
# ----------------------
# Converged at step 2:
#
# k = 7.434304588840655
# ----------------------
#
# Calculating eig number 286
#
# ----------------------
# Converged at step 4:
#
# k = 7.4343045888406545
# ----------------------
#
# Calculating eig number 287
#
# ----------------------
# Converged at step 4:
#
# k = 7.434304588840654
# ----------------------
#
# Calculating eig number 288
#
# ----------------------
# Converged at step 4:
#
# k = 7.434304588840655
# ----------------------
#
# Calculating eig number 289
#
# ----------------------
# Converged at step 4:
#
# k = 7.4343045888406545
# ----------------------
#
# Calculating eig number 290
#
# ----------------------
# Converged at step 4:
#
# k = 7.434304588840655
# ----------------------
#
# Calculating eig number 291
#
# ----------------------
# Converged at step 4:
#
# k = 7.4343045888406545
# ----------------------
#
# Calculating eig number 292
#
# ----------------------
# Converged at step 4:
#
# k = 7.4343045888406545
# ----------------------
#
# Calculating eig number 293
#
# ----------------------
# Converged at step 3:
#
# k = 7.786956907347133
# ----------------------
#
# Calculating eig number 294
#
# ----------------------
# Converged at step 3:
#
# k = 7.786956907347133
# ----------------------
#
# Calculating eig number 295
#
# ----------------------
# Converged at step 3:
#
# k = 7.7869569073471325
# ----------------------
#
# Calculating eig number 296
#
# ----------------------
# Converged at step 3:
#
# k = 7.786956907347133
# ----------------------
#
# Calculating eig number 297
#
# ----------------------
# Converged at step 3:
#
# k = 7.7869569073471325
# ----------------------
#
# Calculating eig number 298
#
# ----------------------
# Converged at step 3:
#
# k = 7.7869569073471325
# ----------------------
#
# Calculating eig number 299
#
# ----------------------
# Converged at step 3:
#
# k = 7.786956907347133
# ----------------------
#
# Calculating eig number 300
#
# ----------------------
# Converged at step 3:
#
# k = 7.786956907347133
# ----------------------
#
# Calculating eig number 301
#
# ----------------------
# Converged at step 3:
#
# k = 7.786956907347133
# ----------------------
#
# Calculating eig number 302
#
# ----------------------
# Converged at step 4:
#
# k = 7.786956907347133
# ----------------------
#
# Calculating eig number 303
#
# ----------------------
# Converged at step 4:
#
# k = 7.786956907347133
# ----------------------
#
# Calculating eig number 304
#
# ----------------------
# Converged at step 4:
#
# k = 7.786956907347133
# ----------------------
#
# Calculating eig number 305
#
# ----------------------
# Converged at step 4:
#
# k = 7.786956907347134
# ----------------------
#
# Calculating eig number 306
#
# ----------------------
# Converged at step 4:
#
# k = 7.7869569073471325
# ----------------------
#
# Calculating eig number 307
#
# ----------------------
# Converged at step 4:
#
# k = 7.786956907347132
# ----------------------
#
# Calculating eig number 308
#
# ----------------------
# Converged at step 4:
#
# k = 7.786956907347134
# ----------------------
#
# Calculating eig number 309
#
# ----------------------
# Converged at step 4:
#
# k = 7.786956907347135
# ----------------------
#
# Calculating eig number 310
#
# ----------------------
# Converged at step 4:
#
# k = 7.786956907347134
# ----------------------
#
# Calculating eig number 311
#
# ----------------------
# Converged at step 4:
#
# k = 7.786956907347134
# ----------------------
#
# Calculating eig number 312
#
# ----------------------
# Converged at step 4:
#
# k = 7.786956907347133
# ----------------------
#
# Calculating eig number 313
#
# ----------------------
# Converged at step 4:
#
# k = 7.786956907347134
# ----------------------
#
# Calculating eig number 314
#
# ----------------------
# Converged at step 4:
#
# k = 7.786956907347135
# ----------------------
#
# Calculating eig number 315
#
# ----------------------
# Converged at step 4:
#
# k = 7.7869569073471325
# ----------------------
#
# Calculating eig number 316
#
# ----------------------
# Converged at step 5:
#
# k = 7.786956907347133
# ----------------------
#
# Calculating eig number 317
#
# ----------------------
# Converged at step 3:
#
# k = 8.46449568068682
# ----------------------
#
# Calculating eig number 318
#
# ----------------------
# Converged at step 3:
#
# k = 8.46449568068682
# ----------------------
#
# Calculating eig number 319
#
# ----------------------
# Converged at step 3:
#
# k = 8.46449568068682
# ----------------------
#
# Calculating eig number 320
#
# ----------------------
# Converged at step 3:
#
# k = 8.46449568068682
# ----------------------
#
# Calculating eig number 321
#
# ----------------------
# Converged at step 3:
#
# k = 8.46449568068682
# ----------------------
#
# Calculating eig number 322
#
# ----------------------
# Converged at step 3:
#
# k = 8.46449568068682
# ----------------------
#
# Calculating eig number 323
#
# ----------------------
# Converged at step 3:
#
# k = 8.46449568068682
# ----------------------
#
# Calculating eig number 324
#
# ----------------------
# Converged at step 3:
#
# k = 8.46449568068682
# ----------------------
#
# Calculating eig number 325
#
# ----------------------
# Converged at step 3:
#
# k = 8.46449568068682
# ----------------------
#
# Calculating eig number 326
#
# ----------------------
# Converged at step 3:
#
# k = 8.46449568068682
# ----------------------
#
# Calculating eig number 327
#
# ----------------------
# Converged at step 3:
#
# k = 8.46449568068682
# ----------------------
#
# Calculating eig number 328
#
# ----------------------
# Converged at step 3:
#
# k = 8.46449568068682
# ----------------------
#
# Calculating eig number 329
#
# ----------------------
# Converged at step 3:
#
# k = 8.46449568068682
# ----------------------
#
# Calculating eig number 330
#
# ----------------------
# Converged at step 3:
#
# k = 8.46449568068682
# ----------------------
#
# Calculating eig number 331
#
# ----------------------
# Converged at step 3:
#
# k = 8.46449568068682
# ----------------------
#
# Calculating eig number 332
#
# ----------------------
# Converged at step 4:
#
# k = 8.46449568068682
# ----------------------
#
# Calculating eig number 333
#
# ----------------------
# Converged at step 4:
#
# k = 8.46449568068682
# ----------------------
#
# Calculating eig number 334
#
# ----------------------
# Converged at step 4:
#
# k = 8.46449568068682
# ----------------------
#
# Calculating eig number 335
#
# ----------------------
# Converged at step 4:
#
# k = 8.46449568068682
# ----------------------
#
# Calculating eig number 336
#
# ----------------------
# Converged at step 3:
#
# k = 8.658732275709534
# ----------------------
#
# Calculating eig number 337
#
# ----------------------
# Converged at step 3:
#
# k = 8.658732275709534
# ----------------------
#
# Calculating eig number 338
#
# ----------------------
# Converged at step 3:
#
# k = 8.658732275709534
# ----------------------
#
# Calculating eig number 339
#
# ----------------------
# Converged at step 2:
#
# k = 8.658732275709534
# ----------------------
#
# Calculating eig number 340
#
# ----------------------
# Converged at step 2:
#
# k = 8.67281097376099
# ----------------------
#
# Calculating eig number 341
#
# ----------------------
# Converged at step 4:
#
# k = 8.67281097376099
# ----------------------
#
# Calculating eig number 342
#
# ----------------------
# Converged at step 4:
#
# k = 8.67281097376099
# ----------------------
#
# Calculating eig number 343
#
# ----------------------
# Converged at step 4:
#
# k = 8.67281097376099
# ----------------------
#
# Calculating eig number 344
#
# ----------------------
# Converged at step 4:
#
# k = 8.67281097376099
# ----------------------
#
# Calculating eig number 345
#
# ----------------------
# Converged at step 4:
#
# k = 8.67281097376099
# ----------------------
#
# Calculating eig number 346
#
# ----------------------
# Converged at step 4:
#
# k = 8.67281097376099
# ----------------------
#
# Calculating eig number 347
#
# ----------------------
# Converged at step 4:
#
# k = 8.67281097376099
# ----------------------
#
# Calculating eig number 348
#
# ----------------------
# Converged at step 4:
#
# k = 8.67281097376099
# ----------------------
#
# Calculating eig number 349
#
# ----------------------
# Converged at step 4:
#
# k = 8.67281097376099
# ----------------------
#
# Calculating eig number 350
#
# ----------------------
# Converged at step 4:
#
# k = 8.67281097376099
# ----------------------
#
# Calculating eig number 351
#
# ----------------------
# Converged at step 4:
#
# k = 8.67281097376099
# ----------------------
#
# Calculating eig number 352
#
# ----------------------
# Converged at step 4:
#
# k = 8.67281097376099
# ----------------------
#
# Calculating eig number 353
#
# ----------------------
# Converged at step 4:
#
# k = 8.67281097376099
# ----------------------
#
# Calculating eig number 354
#
# ----------------------
# Converged at step 4:
#
# k = 8.67281097376099
# ----------------------
#
# Calculating eig number 355
#
# ----------------------
# Converged at step 4:
#
# k = 8.67281097376099
# ----------------------
#
# Calculating eig number 356
#
# ----------------------
# Converged at step 4:
#
# k = 8.67281097376099
# ----------------------
#
# Calculating eig number 357
#
# ----------------------
# Converged at step 3:
#
# k = 9.424777960769381
# ----------------------
#
# Calculating eig number 358
#
# ----------------------
# Converged at step 3:
#
# k = 9.424777960769381
# ----------------------
#
# Calculating eig number 359
#
# ----------------------
# Converged at step 3:
#
# k = 9.424777960769381
# ----------------------
#
# Calculating eig number 360
#
# ----------------------
# Converged at step 3:
#
# k = 9.424777960769381
# ----------------------
#
# Calculating eig number 361
#
# ----------------------
# Converged at step 3:
#
# k = 9.424777960769381
# ----------------------
#
# Calculating eig number 362
#
# ----------------------
# Converged at step 3:
#
# k = 9.424777960769381
# ----------------------
#
# Calculating eig number 363
#
# ----------------------
# Converged at step 3:
#
# k = 9.424777960769381
# ----------------------
#
# Calculating eig number 364
#
# ----------------------
# Converged at step 3:
#
# k = 9.424777960769381
# ----------------------
#
# Calculating eig number 365
#
# ----------------------
# Converged at step 3:
#
# k = 9.424777960769381
# ----------------------
#
# Calculating eig number 366
#
# ----------------------
# Converged at step 3:
#
# k = 9.424777960769381
# ----------------------
#
# Calculating eig number 367
#
# ----------------------
# Converged at step 3:
#
# k = 9.424777960769381
# ----------------------
#
# Calculating eig number 368
#
# ----------------------
# Converged at step 3:
#
# k = 9.424777960769381
# ----------------------
#
# Calculating eig number 369
#
# ----------------------
# Converged at step 3:
#
# k = 9.424777960769381
# ----------------------
#
# Calculating eig number 370
#
# ----------------------
# Converged at step 3:
#
# k = 9.424777960769381
# ----------------------
#
# Calculating eig number 371
#
# ----------------------
# Converged at step 3:
#
# k = 9.424777960769381
# ----------------------
#
# Calculating eig number 372
#
# ----------------------
# Converged at step 3:
#
# k = 9.424777960769381
# ----------------------
#
# Calculating eig number 373
#
# ----------------------
# Converged at step 2:
#
# k = 9.424777960769381
# ----------------------
#
# Calculating eig number 374
#
# ----------------------
# Converged at step 3:
#
# k = 9.424777960769381
# ----------------------
#
# Calculating eig number 375
#
# ----------------------
# Converged at step 4:
#
# k = 9.424777960769381
# ----------------------
#
# Calculating eig number 376
#
# ----------------------
# Converged at step 4:
#
# k = 9.424777960769381
# ----------------------
#
# Calculating eig number 377
#
# ----------------------
# Converged at step 4:
#
# k = 9.424777960769381
# ----------------------
#
# Calculating eig number 378
#
# ----------------------
# Converged at step 4:
#
# k = 9.424777960769381
# ----------------------
#
# Calculating eig number 379
#
# ----------------------
# Converged at step 4:
#
# k = 9.424777960769381
# ----------------------
#
# Calculating eig number 380
#
# ----------------------
# Converged at step 4:
#
# k = 9.424777960769381
# ----------------------
#
# Calculating eig number 381
#
# ----------------------
# Converged at step 4:
#
# k = 9.424777960769381
# ----------------------
#
# Calculating eig number 382
#
# ----------------------
# Converged at step 4:
#
# k = 9.424777960769381
# ----------------------
#
# Calculating eig number 383
#
# ----------------------
# Converged at step 4:
#
# k = 9.424777960769381
# ----------------------
#
# Calculating eig number 384
#
# ----------------------
# Converged at step 3:
#
# k = 9.827002949998942
# ----------------------
#
# Calculating eig number 385
#
# ----------------------
# Converged at step 3:
#
# k = 9.827002949998942
# ----------------------
#
# Calculating eig number 386
#
# ----------------------
# Converged at step 3:
#
# k = 9.827002949998942
# ----------------------
#
# Calculating eig number 387
#
# ----------------------
# Converged at step 3:
#
# k = 9.827002949998942
# ----------------------
#
# Calculating eig number 388
#
# ----------------------
# Converged at step 3:
#
# k = 9.827002949998942
# ----------------------
#
# Calculating eig number 389
#
# ----------------------
# Converged at step 2:
#
# k = 9.827002949998944
# ----------------------
#
# Calculating eig number 390
#
# ----------------------
# Converged at step 2:
#
# k = 9.827002949998942
# ----------------------
#
# Calculating eig number 391
#
# ----------------------
# Converged at step 2:
#
# k = 9.827002949998942
# ----------------------
#
# Calculating eig number 392
#
# ----------------------
# Converged at step 3:
#
# k = 9.827002949998942
# ----------------------
#
# Calculating eig number 393
#
# ----------------------
# Converged at step 2:
#
# k = 9.868445527282496
# ----------------------
#
# Calculating eig number 394
#
# ----------------------
# Converged at step 3:
#
# k = 9.868445527282496
# ----------------------
#
# Calculating eig number 395
#
# ----------------------
# Converged at step 3:
#
# k = 9.868445527282496
# ----------------------
#
# Calculating eig number 396
#
# ----------------------
# Converged at step 4:
#
# k = 9.868445527282498
# ----------------------
#
# Calculating eig number 397
#
# ----------------------
# Converged at step 3:
#
# k = 10.044990068487005
# ----------------------
#
# Calculating eig number 398
#
# ----------------------
# Converged at step 3:
#
# k = 10.044990068487003
# ----------------------
#
# Calculating eig number 399
#
# ----------------------
# Converged at step 3:
#
# k = 10.044990068487003
# ----------------------
# num_Vs = 153
#
#
#
#
#
# Calculating eig number 0
#
# ----------------------
# Converged at step 6:
#
# k = 3.1415926535897896
# ----------------------
#
# Calculating eig number 1
#
# ----------------------
# Converged at step 6:
#
# k = 3.1415926535897944
# ----------------------
#
# Calculating eig number 2
#
# ----------------------
# Converged at step 6:
#
# k = 3.141592653589794
# ----------------------
#
# Calculating eig number 3
#
# ----------------------
# ...
# ----------------------
# num_Vs = 1431
#
#
#
#
#
# Calculating eig number 0
#
# ----------------------
# Converged at step 4:
#
# k = 3.1415926535897682
# ----------------------
#
# Calculating eig number 1
#
# ----------------------
# Converged at step 3:
#
# k = 3.141592653589756
# ----------------------
#
# Calculating eig number 2
#
# ----------------------
# Converged at step 5:
#
# k = 3.141592653589812
# ----------------------
#
# Calculating eig number 3
#
# ----------------------
# Converged at step 4:
#
# k = 5.440291078637703
# ----------------------
#
# Calculating eig number 4
#
# ----------------------
# Converged at step 3:
#
# k = 5.440291078637637
# ----------------------
#
# Calculating eig number 5
#
# ----------------------
# Converged at step 4:
#
# k = 5.440291078637628
# ----------------------
#
# Calculating eig number 6
#
# ----------------------
# Converged at step 4:
#
# k = 7.476250288611084
# ----------------------
#
# Calculating eig number 7
#
# ----------------------
# Converged at step 4:
#
# k = 7.67577866361404
# ----------------------
#
# Calculating eig number 8
#
# ----------------------
# Converged at step 4:
#
# k = 7.900726647831004
# ----------------------
#
# Calculating eig number 9
#
# ----------------------
# Converged at step 4:
#
# k = 4.441530697206924
# ----------------------
#
# Calculating eig number 10
#
# ----------------------
# Converged at step 3:
#
# k = 4.441530697206966
# ----------------------
#
# Calculating eig number 11
#
# ----------------------
# Converged at step 4:
#
# k = 4.441530697206964
# ----------------------
#
# Calculating eig number 12
#
# ----------------------
# Converged at step 3:
#
# k = 6.008589901557514
# ----------------------
#
# Calculating eig number 13
#
# ----------------------
# Converged at step 4:
#
# k = 6.008589901557516
# ----------------------
#
# Calculating eig number 14
#
# ----------------------
# Converged at step 4:
#
# k = 6.283185307179605
# ----------------------
#
# Calculating eig number 15
#
# ----------------------
# Converged at step 5:
#
# k = 7.90072664783099
# ----------------------
#
# Calculating eig number 16
#
# ----------------------
# Converged at step 3:
#
# k = 8.505498700118295
# ----------------------
#
# Calculating eig number 17
#
# ----------------------
# Converged at step 4:
#
# k = 8.5054987001183
# ----------------------
#
# Calculating eig number 18
#
# ----------------------
# Converged at step 5:
#
# k = 5.440291078637665
# ----------------------
#
# Calculating eig number 19
#
# ----------------------
# Converged at step 3:
#
# k = 6.0085899015575714
# ----------------------
#
# Calculating eig number 20
#
# ----------------------
# Converged at step 4:
#
# k = 6.008589901557529
# ----------------------
#
# Calculating eig number 21
#
# ----------------------
# Converged at step 4:
#
# k = 7.476250288611052
# ----------------------
#
# Calculating eig number 22
#
# ----------------------
# Converged at step 3:
#
# k = 7.476250288611103
# ----------------------
#
# Calculating eig number 23
#
# ----------------------
# Converged at step 3:
#
# k = 7.675778663614067
# ----------------------
#
# Calculating eig number 24
#
# ----------------------
# Converged at step 4:
#
# k = 8.874927200672989
# ----------------------
#
# Calculating eig number 25
#
# ----------------------
# Converged at step 3:
#
# k = 9.38397050132184
# ----------------------
#
# Calculating eig number 26
#
# ----------------------
# Converged at step 4:
#
# k = 9.424777960769388
# ----------------------
# num_Vs = 2278
#
#
#
#
#
# Calculating eig number 0
#
# ----------------------
# Converged at step 4:
#
# k = 3.1415926535898344
# ----------------------
#
# Calculating eig number 1
#
# ----------------------
# Converged at step 3:
#
# k = 3.141592653589853
# ----------------------
#
# Calculating eig number 2
#
# ----------------------
# Converged at step 5:
#
# k = 3.1415926535897865
# ----------------------
#
# Calculating eig number 3
#
# ----------------------
# Converged at step 4:
#
# k = 5.440711764833885
# ----------------------
#
# Calculating eig number 4
#
# ----------------------
# Converged at step 3:
#
# k = 5.440711764833889
# ----------------------
#
# Calculating eig number 5
#
# ----------------------
# Converged at step 4:
#
# k = 5.440711764833922
# ----------------------
#
# Calculating eig number 6
#
# ----------------------
# Converged at step 4:
#
# k = 7.477099722253794
# ----------------------
#
# Calculating eig number 7
#
# ----------------------
# Converged at step 4:
#
# k = 7.683185131511966
# ----------------------
#
# Calculating eig number 8
#
# ----------------------
# Converged at step 4:
#
# k = 7.902800086176422
# ----------------------
#
# Calculating eig number 9
#
# ----------------------
# Converged at step 4:
#
# k = 4.442043733864002
# ----------------------
#
# Calculating eig number 10
#
# ----------------------
# Converged at step 3:
#
# k = 4.442043733863987
# ----------------------
#
# Calculating eig number 11
#
# ----------------------
# Converged at step 4:
#
# k = 4.442043733864023
# ----------------------
#
# Calculating eig number 12
#
# ----------------------
# Converged at step 3:
#
# k = 6.0112844358662345
# ----------------------
#
# Calculating eig number 13
#
# ----------------------
# Converged at step 4:
#
# k = 6.011284435866214
# ----------------------
#
# Calculating eig number 14
#
# ----------------------
# Converged at step 4:
#
# k = 6.283185307179565
# ----------------------
#
# Calculating eig number 15
#
# ----------------------
# Converged at step 5:
#
# k = 7.902800086176404
# ----------------------
#
# Calculating eig number 16
#
# ----------------------
# Converged at step 3:
#
# k = 8.506250824239379
# ----------------------
#
# Calculating eig number 17
#
# ----------------------
# Converged at step 4:
#
# k = 8.506250824239363
# ----------------------
#
# Calculating eig number 18
#
# ----------------------
# Converged at step 5:
#
# k = 5.440711764833928
# ----------------------
#
# Calculating eig number 19
#
# ----------------------
# Converged at step 3:
#
# k = 6.011284435866185
# ----------------------
#
# Calculating eig number 20
#
# ----------------------
# Converged at step 4:
#
# k = 6.011284435866195
# ----------------------
#
# Calculating eig number 21
#
# ----------------------
# Converged at step 4:
#
# k = 7.477099722253756
# ----------------------
#
# Calculating eig number 22
#
# ----------------------
# Converged at step 3:
#
# k = 7.477099722253815
# ----------------------
#
# Calculating eig number 23
#
# ----------------------
# Converged at step 4:
#
# k = 7.477099722253769
# ----------------------
#
# Calculating eig number 24
#
# ----------------------
# Converged at step 4:
#
# k = 8.879044251614214
# ----------------------
#
# Calculating eig number 25
#
# ----------------------
# Converged at step 3:
#
# k = 9.399454916079756
# ----------------------
#
# Calculating eig number 26
#
# ----------------------
# Converged at step 4:
#
# k = 9.424777960769381
# ----------------------
# num_Vs = 3655
#
#
#
#
#
# Calculating eig number 0
#
# ----------------------
# Converged at step 4:
#
# k = 3.1415926535898215
# ----------------------
#
# Calculating eig number 1
#
# ----------------------
# Converged at step 3:
#
# k = 3.141592653589597
# ----------------------
#
# Calculating eig number 2
#
# ----------------------
# Converged at step 5:
#
# k = 3.1415926535898677
# ----------------------
#
# Calculating eig number 3
#
# ----------------------
# Converged at step 4:
#
# k = 5.440974719722584
# ----------------------
#
# Calculating eig number 4
#
# ----------------------
# Converged at step 3:
#
# k = 5.4409747197225435
# ----------------------
#
# Calculating eig number 5
#
# ----------------------
# Converged at step 4:
#
# k = 5.440974719722655
# ----------------------
#
# Calculating eig number 6
#
# ----------------------
# Converged at step 4:
#
# k = 7.477630867671896
# ----------------------
#
# Calculating eig number 7
#
# ----------------------
# Converged at step 4:
#
# k = 7.687821885939128
# ----------------------
#
# Calculating eig number 8
#
# ----------------------
# Converged at step 4:
#
# k = 7.904092633990517
# ----------------------
#
# Calculating eig number 9
#
# ----------------------
# Converged at step 4:
#
# k = 4.442364936554397
# ----------------------
#
# Calculating eig number 10
#
# ----------------------
# Converged at step 3:
#
# k = 4.442364936554432
# ----------------------
#
# Calculating eig number 11
#
# ----------------------
# Converged at step 4:
#
# k = 4.442364936554441
# ----------------------
#
# Calculating eig number 12
#
# ----------------------
# Converged at step 3:
#
# k = 6.012971409912765
# ----------------------
#
# Calculating eig number 13
#
# ----------------------
# Converged at step 4:
#
# k = 6.012971409912829
# ----------------------
#
# Calculating eig number 14
#
# ----------------------
# Converged at step 4:
#
# k = 6.28318530717954
# ----------------------
#
# Calculating eig number 15
#
# ----------------------
# Converged at step 5:
#
# k = 7.9040926339905475
# ----------------------
#
# Calculating eig number 16
#
# ----------------------
# Converged at step 3:
#
# k = 8.506719819720043
# ----------------------
#
# Calculating eig number 17
#
# ----------------------
# Converged at step 4:
#
# k = 8.506719819720058
# ----------------------
#
# Calculating eig number 18
#
# ----------------------
# Converged at step 5:
#
# k = 5.440974719722505
# ----------------------
#
# Calculating eig number 19
#
# ----------------------
# Converged at step 3:
#
# k = 6.012971409912738
# ----------------------
#
# Calculating eig number 20
#
# ----------------------
# Converged at step 4:
#
# k = 6.012971409912685
# ----------------------
#
# Calculating eig number 21
#
# ----------------------
# Converged at step 4:
#
# k = 7.477630867671952
# ----------------------
#
# Calculating eig number 22
#
# ----------------------
# Converged at step 3:
#
# k = 7.477630867671921
# ----------------------
#
# Calculating eig number 23
#
# ----------------------
# Converged at step 4:
#
# k = 7.477630867671984
# ----------------------
#
# Calculating eig number 24
#
# ----------------------
# Converged at step 4:
#
# k = 8.881618819321197
# ----------------------
#
# Calculating eig number 25
#
# ----------------------
# Converged at step 3:
#
# k = 9.409148182988364
# ----------------------
#
# Calculating eig number 26
#
# ----------------------
# Converged at step 4:
#
# k = 9.424777960769367
# ----------------------
# num_Vs = 5565
#
#
#
#
#
# Calculating eig number 0
#
# ----------------------
# Converged at step 4:
#
# k = 3.1415926535897523
# ----------------------
#
# Calculating eig number 1
#
# ----------------------
# Converged at step 4:
#
# k = 3.141592653589772
# ----------------------
#
# Calculating eig number 2
#
# ----------------------
# Converged at step 5:
#
# k = 3.1415926535898446
# ----------------------
#
# Calculating eig number 3
#
# ----------------------
# Converged at step 4:
#
# k = 5.441122018524315
# ----------------------
#
# Calculating eig number 4
#
# ----------------------
# Converged at step 3:
#
# k = 5.441122018524135
# ----------------------
#
# Calculating eig number 5
#
# ----------------------
# Converged at step 4:
#
# k = 5.4411220185242195
# ----------------------
#
# Calculating eig number 6
#
# ----------------------
# Converged at step 4:
#
# k = 7.477928464426034
# ----------------------
#
# Calculating eig number 7
#
# ----------------------
# Converged at step 4:
#
# k = 7.690421671414479
# ----------------------
#
# Calculating eig number 8
#
# ----------------------
# Converged at step 4:
#
# k = 7.904815514605262
# ----------------------
#
# Calculating eig number 9
#
# ----------------------
# Converged at step 4:
#
# k = 4.442545039830586
# ----------------------
#
# Calculating eig number 10
#
# ----------------------
# Converged at step 3:
#
# k = 4.4425450398306126
# ----------------------
#
# Calculating eig number 11
#
# ----------------------
# Converged at step 4:
#
# k = 4.4425450398307005
# ----------------------
#
# Calculating eig number 12
#
# ----------------------
# Converged at step 3:
#
# k = 6.013917312914064
# ----------------------
#
# Calculating eig number 13
#
# ----------------------
# Converged at step 4:
#
# k = 6.013917312913898
# ----------------------
#
# Calculating eig number 14
#
# ----------------------
# Converged at step 4:
#
# k = 6.283185307179487
# ----------------------
#
# Calculating eig number 15
#
# ----------------------
# Converged at step 5:
#
# k = 7.904815514605297
# ----------------------
#
# Calculating eig number 16
#
# ----------------------
# Converged at step 3:
#
# k = 8.506982159072265
# ----------------------
#
# Calculating eig number 17
#
# ----------------------
# Converged at step 4:
#
# k = 8.506982159072372
# ----------------------
#
# Calculating eig number 18
#
# ----------------------
# Converged at step 5:
#
# k = 5.441122018524039
# ----------------------
#
# Calculating eig number 19
#
# ----------------------
# Converged at step 3:
#
# k = 6.013917312914064
# ----------------------
#
# Calculating eig number 20
#
# ----------------------
# Converged at step 4:
#
# k = 6.013917312914038
# ----------------------
#
# Calculating eig number 21
#
# ----------------------
# Converged at step 4:
#
# k = 7.477928464426173
# ----------------------
#
# Calculating eig number 22
#
# ----------------------
# Converged at step 3:
#
# k = 7.477928464426058
# ----------------------
#
# Calculating eig number 23
#
# ----------------------
# Converged at step 4:
#
# k = 7.4779284644259745
# ----------------------
#
# Calculating eig number 24
#
# ----------------------
# Converged at step 4:
#
# k = 8.883061394413813
# ----------------------
#
# Calculating eig number 25
#
# ----------------------
# Converged at step 3:
#
# k = 9.4145828537807
# ----------------------
#
# Calculating eig number 26
#
# ----------------------
# Converged at step 4:
#
# k = 9.424777960769347
# ----------------------
# num_Vs = 8911
#
#
#
#
#
# Calculating eig number 0
#
# ----------------------
# Converged at step 4:
#
# k = 3.141592653590006
# ----------------------
#
# Calculating eig number 1
#
# ----------------------
# Converged at step 4:
#
# k = 3.1415926535898535
# ----------------------
#
# Calculating eig number 2
#
# ----------------------
# Converged at step 5:
#
# k = 3.1415926535901466
# ----------------------
#
# Calculating eig number 3
#
# ----------------------
# Converged at step 4:
#
# k = 5.44122677193416
# ----------------------
#
# Calculating eig number 4
#
# ----------------------
# Converged at step 3:
#
# k = 5.44122677193421
# ----------------------
#
# Calculating eig number 5
#
# ----------------------
# Converged at step 4:
#
# k = 5.441226771934307
# ----------------------
#
# Calculating eig number 6
#
# ----------------------
# Converged at step 4:
#
# k = 7.478140133142929
# ----------------------
#
# Calculating eig number 7
#
# ----------------------
# Converged at step 4:
#
# k = 7.692271598394067
# ----------------------
#
# Calculating eig number 8
#
# ----------------------
# Converged at step 4:
#
# k = 7.905329094128728
# ----------------------
#
# Calculating eig number 9
#
# ----------------------
# Converged at step 4:
#
# k = 4.4426731994652275
# ----------------------
#
# Calculating eig number 10
#
# ----------------------
# Converged at step 3:
#
# k = 4.442673199465029
# ----------------------
#
# Calculating eig number 11
#
# ----------------------
# Converged at step 4:
#
# k = 4.442673199465463
# ----------------------
#
# Calculating eig number 12
#
# ----------------------
# Converged at step 3:
#
# k = 6.014590403360661
# ----------------------
#
# Calculating eig number 13
#
# ----------------------
# Converged at step 4:
#
# k = 6.014590403360784
# ----------------------
#
# Calculating eig number 14
#
# ----------------------
# Converged at step 4:
#
# k = 6.283185307179742
# ----------------------
#
# Calculating eig number 15
#
# ----------------------
# Converged at step 5:
#
# k = 7.90532909412888
# ----------------------
#
# Calculating eig number 16
#
# ----------------------
# Converged at step 3:
#
# k = 8.507168561156801
# ----------------------
#
# Calculating eig number 17
#
# ----------------------
# Converged at step 4:
#
# k = 8.507168561156837
# ----------------------
#
# Calculating eig number 18
#
# ----------------------
# Converged at step 5:
#
# k = 5.441226771934438
# ----------------------
#
# Calculating eig number 19
#
# ----------------------
# Converged at step 3:
#
# k = 6.014590403360722
# ----------------------
#
# Calculating eig number 20
#
# ----------------------
# Converged at step 4:
#
# k = 6.0145904033608115
# ----------------------
#
# Calculating eig number 21
#
# ----------------------
# Converged at step 4:
#
# k = 7.478140133142898
# ----------------------
#
# Calculating eig number 22
#
# ----------------------
# Converged at step 3:
#
# k = 7.478140133142806
# ----------------------
#
# Calculating eig number 23
#
# ----------------------
# Converged at step 4:
#
# k = 7.478140133142982
# ----------------------
#
# Calculating eig number 24
#
# ----------------------
# Converged at step 4:
#
# k = 8.88408746772793
# ----------------------
#
# Calculating eig number 25
#
# ----------------------
# Converged at step 3:
#
# k = 9.418449873248505
# ----------------------
#
# Calculating eig number 26
#
# ----------------------
# Converged at step 4:
#
# k = 9.42477796076939
# ----------------------

# %%
for m in range(1, 7):
    print(calculate_pde_eigenvalues(m, np.arange(1, 7)))
# Out:
# [ 3.14159265  5.44139809  7.90616813 10.41948408 12.95311834 15.49710856]
# [ 4.44288294  6.28318531  8.50747312 10.88279619 13.32864881 15.81233627]
# [ 6.01569194  7.47848636  9.42477796 11.61398267 13.93205727 16.32419428]
# [ 7.69529898  8.88576588 10.57617684 12.56637061 14.73537569 17.01494625]
# [ 9.42477796 10.41948408 11.89387783 13.6938849  15.70796327 17.86385202]
# [11.1810102  12.03138387 13.32864881 14.95697272 16.82048333 18.84955592]

# %%
class Eigendata:

    def __init__(self, data):

        self.data = data
        self.V_nums = np.array(list(self.data.keys()))
        self.eigendata_indices = list(self.data[self.V_nums[0]].keys())
        self.graph_eigenvalues, self.PDE_eigenvalues = self.get_eigenvalues()
        self.relative_eigenvalue_differences = self.calculate_relative_eigenvalue_differences()
        self.relative_eigenfunction_differences = self.calculate_relative_eigenfunction_differences()

    def get_eigenvalues(self):

        graph_eigenvalues = {}
        PDE_eigenvalues = {}
        for m, n in self.eigendata_indices:
            graph_eigenvalues[m, n] = []
            PDE_eigenvalues[m, n] = self.data[self.V_nums[0]][m, n]['PDE']['eigenvalue']
            for num_Vs in self.V_nums:
                graph_eigenvalues[m, n].append(self.data[num_Vs][m, n]['graph']['eigenvalue'])

        return graph_eigenvalues, PDE_eigenvalues
        
    def calculate_relative_eigenvalue_differences(self):

        relative_eigenvalue_differences = {}
        for m, n in self.eigendata_indices:
            pde_eig = self.PDE_eigenvalues[m, n]
            if np.abs(self.PDE_eigenvalues[m, n]) < 1e-14:
                rel_errs = [np.mean(np.abs(i - pde_eig)) for i in self.graph_eigenvalues[m, n]]
            else:
                rel_errs = [np.mean(np.abs((i - pde_eig) / pde_eig)) for i in self.graph_eigenvalues[m, n]]
            relative_eigenvalue_differences[m, n] = np.array(rel_errs)

        return relative_eigenvalue_differences

    def calculate_relative_eigenfunction_differences(self):

        relative_eigenfunction_differences = {}
        for m, n in self.eigendata_indices:
            relative_eigenfunction_differences[m, n] = []
            for num_Vs in self.V_nums:
                rel_errs = [(i - j).norm() for i, j in zip(self.data[num_Vs][m, n]['graph']['eigenfunction'], 
                                                           self.data[num_Vs][m, n]['PDE']['eigenfunction'])]
                relative_eigenfunction_differences[m, n].append(np.mean(rel_errs))

        return relative_eigenfunction_differences

class Graph_Modes:

    def __init__(self, g, graph_eigenvalues):

        (self.graph_eigenvalues,
         self.graph_eigenvectors, 
         self.null_space_dims) = self.calculate_graph_eigenvectors(g, graph_eigenvalues)
        self.graph_eigenfunctions = self.construct_graph_eigenfunctions(g)
    
    def construct_graph_eigenfunction(self, g, eigenvalue, eigenvector):

        graph_eigenfunction = []

        if np.abs(eigenvalue) < 1e-13:
            for e_num, ((v_num, w_num), l_vw) in enumerate(g.E_lengths_by_v_num.items()):
                edge_mode = np.ones(g.g_coords[e_num].shape[1])
                graph_eigenfunction.append(edge_mode)
        else:
            for e_num, ((v_num, w_num), l_vw) in enumerate(g.E_lengths_by_v_num.items()):
                parametrised_edge = np.linspace(0, l_vw, g.g_coords[e_num].shape[1])

                edge_mode = ((eigenvector[v_num] * np.sin(eigenvalue * parametrised_edge[::-1])
                            + eigenvector[w_num] * np.sin(eigenvalue * parametrised_edge)) 
                            / np.sin(eigenvalue * l_vw))
                
                graph_eigenfunction.append(edge_mode)

        graph_eigenfunction = Graph_Function(graph_eigenfunction, g.g_coords).normalize()

        return graph_eigenfunction
    
    def construct_graph_eigenfunctions(self, g):

        graph_eigenfunctions = []
        for eigenvalue, eigenvector in zip(self.graph_eigenvalues, self.graph_eigenvectors.T):
            graph_eigenfunctions.append(self.construct_graph_eigenfunction(g, eigenvalue, eigenvector))
        
        return graph_eigenfunctions
    
    def calculate_graph_eigenvectors(self, g, graph_eigenvalues):

        graph_eigenvectors = []
        null_space_dims = []

        for k in graph_eigenvalues:

            if np.abs(k) < 1e-12:
                Q, R, perm, r = sparseqr.qr(g.construct_L(k), tolerance=None)
            else:
                Q, R, perm, r = sparseqr.qr(g.construct_L(k), tolerance=1e-8)

            dim_null_space = len(g.interior_V_num) - r

            null_vectors = np.zeros((g.num_Vs, dim_null_space))
            null_vectors_for_interior = Q.toarray()[:, -dim_null_space:]
            for d in range(dim_null_space):
                null_vectors[:, d][g.interior_V_num] = null_vectors_for_interior[:, d]

            null_space_dims.append(dim_null_space)
            graph_eigenvectors.append(null_vectors)

        graph_eigenvalues = np.repeat(graph_eigenvalues, null_space_dims)
        graph_eigenvectors = np.hstack(graph_eigenvectors)

        return graph_eigenvalues, graph_eigenvectors, null_space_dims 
    
def generate_graph_linewidth(num_Vs):
    # Just a heuristic
    return np.max([0.5, -0.086 * np.sqrt(num_Vs) + 7.66])

def style_plot(fig, ax, aspect="equal", no_ticks=False, no_xticks=False, no_yticks=False):

    # Remove white space
    fig.tight_layout()

    # Makes axes aspect equal
    if aspect:
        ax.set_aspect(aspect)

    # Make tick labels bold font
    for label in ax.get_xticklabels() + ax.get_yticklabels():
        label.set_fontweight('bold')
        label.set_fontsize(20)

    # Make border thicker
    for spine in ax.spines.values():
        spine.set_linewidth(2) 

    # xy_ticks
    major_tick_length = 7
    minor_tick_length = 4
    if no_ticks:
        major_xtick_length = 0
        major_ytick_length = 0
        minor_xtick_length = 0
        minor_ytick_length = 0
    elif no_xticks:
        major_xtick_length = 0
        major_ytick_length = major_tick_length
        minor_xtick_length = 0
        minor_ytick_length = minor_tick_length
    elif no_yticks:
        major_xtick_length = major_tick_length
        major_ytick_length = 0
        minor_xtick_length = minor_tick_length
        minor_ytick_length = 0
    else:
        major_xtick_length = major_tick_length
        major_ytick_length = major_tick_length
        minor_xtick_length = minor_tick_length
        minor_ytick_length = minor_tick_length
    ax.tick_params(axis='x', which='major', length=major_xtick_length, width=2, direction='out')
    ax.tick_params(axis='y', which='major', length=major_ytick_length, width=2, direction='out')
    ax.tick_params(axis='x', which='minor', length=minor_xtick_length, width=1, direction='out')
    ax.tick_params(axis='y', which='minor', length=minor_ytick_length, width=1, direction='out')
    
class Graph_Function:

    def __init__(self, data, domain=None):

        self.data = data
        if domain is not None:
            self.domain = [edge_domain.copy() for edge_domain in domain]

    def __add__(self, other):

        if not isinstance(other, Graph_Function):
            return NotImplemented
        
        result = [i + j for i, j in zip(self.data, other.data)]

        return Graph_Function(result, self.domain)

    def __sub__(self, other):

        if not isinstance(other, Graph_Function):
            return NotImplemented
        
        result = [i - j for i, j in zip(self.data, other.data)]

        return Graph_Function(result, self.domain)

    def __mul__(self, other):

        if isinstance(other, Graph_Function):
            result = [i * j for i, j in zip(self.data, other.data)]

        elif np.isscalar(other):  
            result = [arr * other for arr in self.data]

        else:
            return NotImplemented
        
        return Graph_Function(result, self.domain)

    def __rmul__(self, other):

        return self.__mul__(other)

    def __truediv__(self, other):

        if isinstance(other, Graph_Function):
            result = [i / j for i, j in zip(self.data, other.data)]

        elif np.isscalar(other):  
            result = [arr / other for arr in self.data]

        else:
            return NotImplemented
        
        return Graph_Function(result, self.domain)

    def __rtruediv__(self, other):

        if np.isscalar(other):
            result = [other / arr for arr in self.data]

        else:
            return NotImplemented
        
        return Graph_Function(result, self.domain)

    def __eq__(self, other):

        if not isinstance(other, Graph_Function):
            return NotImplemented
        
        return all(np.array_equal(i, j) for i, j in zip(self.data, other.data))

    def __repr__(self):

        return f"Graph_Function({self.data})"
    
    def norm(self):

        return np.sqrt(self.dot(self))
    
    def normalize(self):

        norm = self.norm()

        if norm == 0:
            raise ValueError("Cannot normalize a zero vector.")

        result = [arr / norm for arr in self.data]

        return Graph_Function(result, self.domain)
    
    def dot(self, other):
        
        if not isinstance(other, Graph_Function):
            return NotImplemented
        
        if (self.domain is None) and not (other.domain is None):
            self.domain = other.domain
        elif not (self.domain is None) and (other.domain is None):
            other.domain = self.domain
        elif (self.domain is None) and (other.domain is None):
            raise ValueError("Graph_Functions need domain attributes.")
        
        graph_inner_product = 0

        for f0_edge, f1_edge, edge in zip(self.data, other.data, self.domain):
            edge_length = np.linalg.norm([edge[0, 0] - edge[0, -1], edge[1, 0] - edge[1, -1]])
            edge_param = np.linspace(0, edge_length, edge.shape[1])
            graph_inner_product += scipy.integrate.trapezoid(f0_edge * f1_edge, edge_param)

        return graph_inner_product

# %%
class Projector:

    def __init__(self, g, eigenvalues):

        self.data = {}
        self.modes = Graph_Modes(g, eigenvalues)
        self.V_coords = g.V_coords
        self.g_coords = g.g_coords

    def generate_basis_functions(self, m, n):

        if (m > 3) or (n > 3) or (m < 1) or (n < 1):
            raise ValueError("Projector is only set up for m, n \in [1, 2, 3]")

        ss = lambda m, n: lambda x, y: np.sin(m * np.pi * x) * np.sin(n * np.pi * y)

        if m == 3 and n == 3:
            return ss(m, n), ss(5, 1)

        return ss(m, n),

    def construct_pde_functions(self, m, n, function_domain="vertices"):

        basis_functions = self.generate_basis_functions(m, n)

        if function_domain == "vertices":
            x, y = self.V_coords[:, 0], self.V_coords[:, 1]

            pde_eigenvectors = [function(x, y) for function in basis_functions]
            pde_eigenvectors = [function / np.linalg.norm(function) for function in pde_eigenvectors]
            pde_eigenvectors = np.vstack((pde_eigenvectors)).T

            return pde_eigenvectors
        
        elif function_domain == "graph":
            pde_eigenfunctions = [[] for _ in range(len(basis_functions))]

            for edge in self.g_coords:
                x, y = edge
                
                for i in range(len(basis_functions)):
                    pde_eigenfunctions[i].append(basis_functions[i](x, y))

            pde_eigenfunctions = [Graph_Function(pde_eigenfunction, self.g_coords).normalize() 
                                  for pde_eigenfunction in pde_eigenfunctions]
            
            return pde_eigenfunctions

        elif function_domain == "continuum":
            edge = np.linspace(0, 1, 256, endpoint=True)   
            x, y = np.meshgrid(edge, edge)
            pde_eigenfunctions = [function(x, y) for function in basis_functions]

            return x, y, pde_eigenfunctions

    def find_graph_eigenspace(self, m, n):

        pde_eigenvectors = self.construct_pde_functions(m, n, function_domain="vertices")
        num_basis_functions = pde_eigenvectors.shape[1]
        prod = pde_eigenvectors.T @ pde_eigenvectors
        invert_prod = np.linalg.inv(prod)
        proj = (pde_eigenvectors @ invert_prod @ pde_eigenvectors.T)

        keep_args = proj @ self.modes.graph_eigenvectors
        keep_args = np.argsort(np.linalg.norm(keep_args, axis=0))[-num_basis_functions:]

        # Handle when the graph eigenspace is larger than the PDE eigenspace
        uniques, counts = np.unique(np.round(self.modes.graph_eigenvalues[keep_args], 10), return_counts=True)
        new_keep_args = []
        for unique, count in zip(uniques, counts):
            where_equal = np.where(np.abs(self.modes.graph_eigenvalues - unique) < 1e-9)[0]
            if np.shape(where_equal)[0] != count:
                message = (f"For num_Vs={self.V_coords.shape[0]},m={m},n={n}, the graph eigenspace is larger than the PDE eigenspace. " + 
                            "This might be (a) a problem, (b) saying something interesting, or (c) nothing special.")
                warnings.warn(message)
            new_keep_args.append(where_equal)
        keep_args = np.concatenate((new_keep_args))

        return keep_args

    def __call__(self, m, n):

        self.data[m, n] = {"graph": {}, "PDE": {}}

        # Get PDE eigenvalues
        self.data[m, n]["PDE"]["eigenvalue"] = calculate_pde_eigenvalues(m, n)

        # Get PDE eigenfunctions
        pde_eigenfunctions = self.construct_pde_functions(m, n, function_domain="graph")
        self.data[m, n]["PDE"]["eigenfunction"] = pde_eigenfunctions
        
        # Get graph eigenvalues
        keep_args = self.find_graph_eigenspace(m, n)
        self.data[m, n]["graph"]["eigenvalue"] = self.modes.graph_eigenvalues[keep_args]

        # Get graph eigenfunctions
        project_functions = []
        for pde_eigenfunction in pde_eigenfunctions:
            projection = []
            for arg in keep_args:
                ip = pde_eigenfunction.dot(self.modes.graph_eigenfunctions[arg])
                projection.append(ip * self.modes.graph_eigenfunctions[arg])
            project_functions.append(np.sum(projection))
        self.data[m, n]["graph"]["eigenfunction"] = project_functions

# %%
mn = [[1, 1], [1, 2], [1, 3], [2, 1], [2, 2], [2, 3], [3, 1], [3, 2], [3, 3]]

# %%
full_data = {}

for tile_num in tiles_per_dim:

    g = construct_graph.tiling.Tiling(tile_type='rectangular_tile',
                                        num_horizontal_displacements=tile_num * 2 + 1,
                                        num_vertical_displacements=tile_num + 1,
                                        autoplot=False, periodic=False)
    print(g.num_Vs)
    p = Projector(g, eigenvalue_data[g.num_Vs])
    for m, n in mn:
        print(m, n)
        p(m, n)
    full_data[g.num_Vs] = p.data
    print()
# Out:
# 91
# 1 1
# 1 2
# 1 3
# 2 1
# 2 2
# 2 3
# 3 1
# 3 2
# 3 3
#
# 153
# 1 1
# 1 2
# 1 3
# 2 1
# 2 2
# 2 3
# 3 1
# 3 2
# 3 3
#
# 231
# 1 1
# 1 2
# 1 3
# 2 1
# 2 2
# 2 3
# 3 1
# 3 2
# 3 3
#
# 378
# 1 1
# 1 2
# 1 3
# 2 1
# 2 2
# 2 3
# 3 1
# 3 2
# 3 3
#
# 561
# 1 1
# 1 2
# 1 3
# 2 1
# 2 2
# 2 3
# 3 1
# 3 2
# 3 3
#
# 946
# 1 1
# 1 2
# 1 3
# 2 1
# 2 2
# 2 3
# 3 1
# 3 2
# 3 3
#
# 1431
# 1 1
# 1 2
# 1 3
# 2 1
# 2 2
# 2 3
# 3 1
# 3 2
# 3 3
#
# 2278
# 1 1
# 1 2
# 1 3
# 2 1
# 2 2
# 2 3
# 3 1
# 3 2
# 3 3
#
# 3655
# 1 1
# 1 2
# 1 3
# 2 1
# 2 2
# 2 3
# 3 1
# 3 2
# 3 3
#
# 5565
# 1 1
# 1 2
# 1 3
# 2 1
# 2 2
# 2 3
# 3 1
# 3 2
# 3 3
#
# 8911
# 1 1
# 1 2
# 1 3
# 2 1
# 2 2
# 2 3
# 3 1
# 3 2
# 3 3

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
order_line_color = colors[6]
colors = colors[:6] + colors[7:]
def plot_loglog_rel_err(Num_Vs, rel_errs, show_legend=False, rate_slope=1., rate_scaling=1):
    
    fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True, figsize=(7, 6), gridspec_kw={'height_ratios': [6, 1]})
    fig.subplots_adjust(hspace=0.2, )  # adjust space between axes

    # Separate data by size
    for en, rel_err in enumerate(rel_errs.T):
        if np.all(rel_err > 1e-10):
            ax1.loglog(Num_Vs, rel_err, 'o-', markersize=10, c=colors[en], label=str(mn[en]))
        else:
            ax2.loglog(Num_Vs, rel_err, 'o-', markersize=10, c=colors[en], label=str(mn[en]))
            if np.any(rel_err > 1e-10):
                relevant_data = rel_err[rel_err <= 1e-10]
                ax2.set_ylim(0.1 * np.min(relevant_data), 10 * np.max(relevant_data))

    # Setup convergence line
    ax1_data_lims = (np.min(rel_errs[rel_errs > 1e-10]), np.max(rel_errs[rel_errs > 1e-10]))
    ax1_log_dif = np.log10(ax1_data_lims[1]) - np.log10(ax1_data_lims[0])
    max_order_height = np.max(rel_errs) / np.max(Num_Vs**(-1.))
    order_line_data = max_order_height * Num_Vs**(-rate_slope) * 10**(0.15 * ax1_log_dif) / rate_scaling
    # order_line_data = max_order_height * Num_Vs**(-1.) * 1
    ax1.loglog(Num_Vs, order_line_data, 
               linewidth=4, c=order_line_color)

    # hide the spines between ax and ax2
    ax1.spines.bottom.set_visible(False)
    ax2.spines.top.set_visible(False)
    ax1.xaxis.tick_top()
    ax1.tick_params(labeltop=False)  # don't put tick labels at the top
    ax2.xaxis.tick_bottom()

    # Slanted lines
    d = 0.5
    kwargs = dict(marker=[(-1, -d), (1, d)], markersize=12,
                linestyle="none", color='k', mec='k', mew=3, clip_on=False)
    ax1.plot([0, 1], [0, 0], transform=ax1.transAxes, **kwargs)
    ax2.plot([0, 1], [1, 1], transform=ax2.transAxes, **kwargs)

    style_plot(fig, ax1, aspect=None, no_xticks=True)
    style_plot(fig, ax2, aspect=None)

    if show_legend:
        ax1.legend()
        ax2.legend()

    # ax1.set_ylim(2e-3, 4e0)

    # minor_ticks = ax2.yaxis.get_minorticklocs()
    # ax2.set_yticks(minor_ticks, minor=True)
    # ax2.set_yticklabels([], minor=True)

    return fig, fig.axes

def plot_loglog_rel_err_single(Num_Vs, rel_errs, show_legend=False, rate_slope=1., rate_scaling=1):
    
    fig, ax1 = plt.subplots(1, 1, sharex=True, figsize=(7, 6))

    # Separate data by size
    for en, rel_err in enumerate(rel_errs.T):
        ax1.loglog(Num_Vs, rel_err, 'o-', markersize=10, c=colors[en], label=str(mn[en]))

    # Setup convergence line
    ax1_data_lims = (np.min(rel_errs[rel_errs > 1e-10]), np.max(rel_errs[rel_errs > 1e-10]))
    ax1_log_dif = np.log10(ax1_data_lims[1]) - np.log10(ax1_data_lims[0])
    max_order_height = np.max(rel_errs) / np.max(Num_Vs**(-1.))
    order_line_data = max_order_height * Num_Vs**(-rate_slope) * 10**(0.15 * ax1_log_dif) / rate_scaling
    # order_line_data = max_order_height * Num_Vs**(-1.) * 1
    ax1.loglog(Num_Vs, order_line_data, 
               linewidth=4, c=order_line_color)

    style_plot(fig, ax1, aspect=None)

    if show_legend:
        ax1.legend()

    return fig, ax1

# %%
edata = Eigendata(full_data)

# %%
x = edata.V_nums
y = np.array(list(edata.relative_eigenvalue_differences.values())).T
plot_loglog_rel_err(x, y, show_legend=False, rate_scaling=1)
plt.savefig("tiling/rectangular_clamped/rectangular_clamped_tiling_eigenvalue_relerr.png", dpi=200, bbox_inches='tight')

# %%
x = edata.V_nums
y = np.array(list(edata.relative_eigenfunction_differences.values())).T
fig, ax1 = plot_loglog_rel_err_single(x, y, show_legend=True, rate_slope=1., rate_scaling=1)

order_line_data = x**(-1.5) * 0.3
ax1.loglog(x, order_line_data, linewidth=4, c='r')
ax1.set_ylim(1.5e-7, 4e-0)
# plt.savefig("tiling/rectangular_clamped/rectangular_clamped_tiling_eigenfunction_relerr.png", dpi=200, bbox_inches='tight')
# Out:
# (1.5e-07, 4.0)

# %%
plot_and_save_modes = True

# %%
if plot_and_save_modes:

    g = construct_graph.tiling.Tiling(tile_type='rectangular_tile',
                                        num_horizontal_displacements=tiles_per_dim[4] * 2 + 1,
                                        num_vertical_displacements=tiles_per_dim[4] + 1,
                                        autoplot=False, periodic=False)
    print(g.num_Vs)

    for m, n in mn:
        emodes = full_data[g.num_Vs][m, n]['graph']['eigenfunction']
        for en, emode in enumerate(emodes):
            fig, ax = g.plot_graph(eigenmode=emode.data, return_figax=True, background_color="black")
            plt.savefig(f"tiling/rectangular_clamped/mode_plots/eigenmode_{g.num_Vs}Vs_m{m}_n{n}_number{en}.png", dpi=200, bbox_inches='tight')
            plt.close()

plot_and_save_modes = False
# Out:
# 561

# %%
plot_and_save_continuum_modes = True

# %%
if plot_and_save_continuum_modes:

    g = construct_graph.tiling.Tiling(tile_type='rectangular_tile',
                                        num_horizontal_displacements=tiles_per_dim[0] * 2 + 1,
                                        num_vertical_displacements=tiles_per_dim[0] + 1,
                                        autoplot=False, periodic=False)

    print(g.num_Vs)
    p = Projector(g, np.array([1]))

    for m, n in mn:
        print(m, n)
        x, y, A = p.construct_pde_functions(m, n, function_domain="continuum")
        for en, a in enumerate(A):
            fig = plt.figure(figsize=(10, 10))
            ax = fig.add_subplot(111)
            ax.pcolormesh(x, y, a, cmap="plasma", shading='auto')
            style_plot(fig, ax, aspect="equal", no_ticks=True)
            ax.axis('off')
            fig.set_facecolor("black")
            plt.savefig(f"tiling/rectangular_clamped/PDE_mode_plots/continuum_eigenmode_m{m}_n{n}_number{en}.png", dpi=200, bbox_inches='tight')
            plt.close()

plot_and_save_continuum_modes = False
# Out:
# 91
# 1 1
# 1 2
# 1 3
# 2 1
# 2 2
# 2 3
# 3 1
# 3 2
# 3 3
