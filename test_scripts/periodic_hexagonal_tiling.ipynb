# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches
import scipy
import pickle
import warnings

import sys
sys.path.append('..')
from construct_graph.graph import Graph, Flat
import construct_graph
import solve_laplace_operator

import sparseqr

# %%
powers_of_10_lims = (2, 4)
num_Vs_per_tile = 4
num_graphs_per_power_of_10 = 5
total_dpowers = num_graphs_per_power_of_10 * (powers_of_10_lims[1] - powers_of_10_lims[0]) + 1
power_linspace = np.linspace(powers_of_10_lims[0], powers_of_10_lims[1], total_dpowers)

tiles_per_dim = np.int32(np.sqrt(10**power_linspace / num_Vs_per_tile))

# %%
g = construct_graph.tiling.Tiling(tile_type='hexagonal_tile',
                                    num_horizontal_displacements=tiles_per_dim[-1],
                                    num_vertical_displacements=tiles_per_dim[-1],
                                    autoplot=False, figsize=3)

# %%
fig, ax = g.plot_graph(return_figax=True, linewidth=generate_graph_linewidth(g.num_Vs), embedding_space="hexagon_rectangle")
plt.savefig("tiling/hexagonal_periodic/large_hexagonal_tiling.png", dpi=200, bbox_inches="tight")

# %%
run_eigenvalue_calculations = True

if run_eigenvalue_calculations:
    guesses = np.concatenate([np.array([1e-15]), np.linspace(1, 20, 300)])

    eigenvalue_data = {}

    for tile_num in tiles_per_dim:
        g = construct_graph.tiling.Tiling(tile_type='hexagonal_tile',
                                          num_horizontal_displacements=tile_num,
                                          num_vertical_displacements=tile_num,
                                          autoplot=False, figsize=3)
        print(f"num_Vs = {g.num_Vs}")
        print("\n\n\n")
        eigs = solve_laplace_operator.solve_laplace_operator.Eigenvalue_Calculator(g)
        ks = eigs(guesses, printerval=1000, max_steps=1000, tol=1e-12, solve_type="SVD iterate")
        _, index = np.unique(np.round(ks, 6), return_index=True)
        eigenvalues = ks[index]
        eigenvalue_data[g.num_Vs] = eigenvalues.copy()
# Out:
# num_Vs = 100
#
#
#
#
#
# Calculating eig number 0
#
# ----------------------
# Converged at step 0:
#
# k = 1.049508204260907e-15
# ----------------------
#
# Calculating eig number 1
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 2
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 3
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 4
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 5
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 6
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 7
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 8
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 9
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 10
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 11
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 12
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 13
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 14
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 15
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 16
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 17
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 18
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 19
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 20
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 21
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 22
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 23
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 24
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 25
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 26
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 27
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 28
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 29
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 30
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 31
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 32
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 33
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 34
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 35
#
# ----------------------
# Converged at step 5:
#
# k = 4.434472557001616
# ----------------------
#
# Calculating eig number 36
#
# ----------------------
# Converged at step 5:
#
# k = 4.434472557001615
# ----------------------
#
# Calculating eig number 37
#
# ----------------------
# Converged at step 4:
#
# k = 4.434472557001612
# ----------------------
#
# Calculating eig number 38
#
# ----------------------
# Converged at step 4:
#
# k = 4.4344725570016275
# ----------------------
#
# Calculating eig number 39
#
# ----------------------
# Converged at step 4:
#
# k = 4.434472557001619
# ----------------------
#
# Calculating eig number 40
#
# ----------------------
# Converged at step 4:
#
# k = 4.434472557001625
# ----------------------
#
# Calculating eig number 41
#
# ----------------------
# Converged at step 4:
#
# k = 4.434472557001607
# ----------------------
#
# Calculating eig number 42
#
# ----------------------
# Converged at step 4:
#
# k = 4.434472557001611
# ----------------------
#
# Calculating eig number 43
#
# ----------------------
# Converged at step 4:
#
# k = 4.43447255700162
# ----------------------
#
# Calculating eig number 44
#
# ----------------------
# Converged at step 4:
#
# k = 4.434472557001618
# ----------------------
#
# Calculating eig number 45
#
# ----------------------
# Converged at step 4:
#
# k = 4.4344725570016115
# ----------------------
#
# Calculating eig number 46
#
# ----------------------
# Converged at step 4:
#
# k = 4.434472557001611
# ----------------------
#
# Calculating eig number 47
#
# ----------------------
# Converged at step 4:
#
# k = 4.434472557001614
# ----------------------
#
# Calculating eig number 48
#
# ----------------------
# Converged at step 4:
#
# k = 4.434472557001611
# ----------------------
#
# Calculating eig number 49
#
# ----------------------
# Converged at step 4:
#
# k = 4.434472557001611
# ----------------------
#
# Calculating eig number 50
#
# ----------------------
# Converged at step 4:
#
# k = 4.434472557001615
# ----------------------
#
# Calculating eig number 51
#
# ----------------------
# Converged at step 4:
#
# k = 4.434472557001621
# ----------------------
#
# Calculating eig number 52
#
# ----------------------
# Converged at step 3:
#
# k = 4.434472557001619
# ----------------------
#
# Calculating eig number 53
#
# ----------------------
# Converged at step 3:
#
# k = 4.434472557001621
# ----------------------
#
# Calculating eig number 54
#
# ----------------------
# Converged at step 3:
#
# k = 4.4344725570016115
# ----------------------
#
# Calculating eig number 55
#
# ----------------------
# Converged at step 2:
#
# k = 4.434472557001617
# ----------------------
#
# Calculating eig number 56
#
# ----------------------
# Converged at step 4:
#
# k = 4.434472557001611
# ----------------------
#
# Calculating eig number 57
#
# ----------------------
# Converged at step 5:
#
# k = 4.434472557001616
# ----------------------
#
# Calculating eig number 58
#
# ----------------------
# Converged at step 5:
#
# k = 4.434472557001608
# ----------------------
#
# Calculating eig number 59
#
# ----------------------
# Converged at step 5:
#
# k = 4.4344725570016195
# ----------------------
#
# Calculating eig number 60
#
# ----------------------
# Converged at step 5:
#
# k = 4.434472557001619
# ----------------------
#
# Calculating eig number 61
#
# ----------------------
# Converged at step 5:
#
# k = 4.434472557001612
# ----------------------
#
# Calculating eig number 62
#
# ----------------------
# Converged at step 5:
#
# k = 4.434472557001611
# ----------------------
#
# Calculating eig number 63
#
# ----------------------
# Converged at step 5:
#
# k = 4.434472557001615
# ----------------------
#
# Calculating eig number 64
#
# ----------------------
# Converged at step 5:
#
# k = 4.434472557001608
# ----------------------
#
# Calculating eig number 65
#
# ----------------------
# Converged at step 5:
#
# k = 4.434472557001619
# ----------------------
#
# Calculating eig number 66
#
# ----------------------
# Converged at step 5:
#
# k = 4.43447255700161
# ----------------------
#
# Calculating eig number 67
#
# ----------------------
# Converged at step 5:
#
# k = 4.434472557001612
# ----------------------
#
# Calculating eig number 68
#
# ----------------------
# Converged at step 5:
#
# k = 4.4344725570016195
# ----------------------
#
# Calculating eig number 69
#
# ----------------------
# Converged at step 6:
#
# k = 4.434472557001626
# ----------------------
#
# Calculating eig number 70
#
# ----------------------
# Converged at step 6:
#
# k = 4.4344725570016195
# ----------------------
#
# Calculating eig number 71
#
# ----------------------
# Converged at step 6:
#
# k = 4.434472557001614
# ----------------------
#
# Calculating eig number 72
#
# ----------------------
# Converged at step 6:
#
# k = 4.4344725570016195
# ----------------------
#
# Calculating eig number 73
#
# ----------------------
# Converged at step 6:
#
# k = 4.4344725570016195
# ----------------------
#
# Calculating eig number 74
#
# ----------------------
# Converged at step 6:
#
# k = 4.434472557001622
# ----------------------
#
# Calculating eig number 75
#
# ----------------------
# Converged at step 6:
#
# k = 4.434472557001615
# ----------------------
#
# Calculating eig number 76
#
# ----------------------
# Converged at step 6:
#
# k = 4.434472557001614
# ----------------------
#
# Calculating eig number 77
#
# ----------------------
# Converged at step 6:
#
# k = 4.434472557001607
# ----------------------
#
# Calculating eig number 78
#
# ----------------------
# Converged at step 6:
#
# k = 4.434472557001619
# ----------------------
#
# Calculating eig number 79
#
# ----------------------
# Converged at step 6:
#
# k = 4.434472557001611
# ----------------------
#
# Calculating eig number 80
#
# ----------------------
# Converged at step 6:
#
# k = 4.434472557001608
# ----------------------
#
# Calculating eig number 81
#
# ----------------------
# Converged at step 6:
#
# k = 4.4344725570016195
# ----------------------
#
# Calculating eig number 82
#
# ----------------------
# Converged at step 6:
#
# k = 4.434472557001631
# ----------------------
#
# Calculating eig number 83
#
# ----------------------
# Converged at step 6:
#
# k = 4.434472557001617
# ----------------------
#
# Calculating eig number 84
#
# ----------------------
# Converged at step 4:
#
# k = 7.652043416552633
# ----------------------
#
# Calculating eig number 85
#
# ----------------------
# Converged at step 4:
#
# k = 7.652043416552634
# ----------------------
#
# Calculating eig number 86
#
# ----------------------
# Converged at step 4:
#
# k = 7.652043416552634
# ----------------------
#
# Calculating eig number 87
#
# ----------------------
# Converged at step 4:
#
# k = 7.652043416552635
# ----------------------
#
# Calculating eig number 88
#
# ----------------------
# Converged at step 4:
#
# k = 7.652043416552634
# ----------------------
#
# Calculating eig number 89
#
# ----------------------
# Converged at step 4:
#
# k = 7.652043416552634
# ----------------------
#
# Calculating eig number 90
#
# ----------------------
# Converged at step 4:
#
# k = 7.652043416552635
# ----------------------
#
# Calculating eig number 91
#
# ----------------------
# Converged at step 4:
#
# k = 7.652043416552634
# ----------------------
#
# Calculating eig number 92
#
# ----------------------
# Converged at step 4:
#
# k = 7.652043416552638
# ----------------------
#
# Calculating eig number 93
#
# ----------------------
# Converged at step 4:
#
# k = 7.652043416552634
# ----------------------
#
# Calculating eig number 94
#
# ----------------------
# Converged at step 4:
#
# k = 7.652043416552636
# ----------------------
#
# Calculating eig number 95
#
# ----------------------
# Converged at step 4:
#
# k = 7.652043416552632
# ----------------------
#
# Calculating eig number 96
#
# ----------------------
# Converged at step 4:
#
# k = 7.652043416552633
# ----------------------
#
# Calculating eig number 97
#
# ----------------------
# Converged at step 4:
#
# k = 7.652043416552634
# ----------------------
#
# Calculating eig number 98
#
# ----------------------
# Converged at step 4:
#
# k = 7.6520434165526305
# ----------------------
#
# Calculating eig number 99
#
# ----------------------
# Converged at step 4:
#
# k = 7.652043416552634
# ----------------------
#
# Calculating eig number 100
#
# ----------------------
# Converged at step 3:
#
# k = 7.652043416552632
# ----------------------
#
# Calculating eig number 101
#
# ----------------------
# Converged at step 3:
#
# k = 7.652043416552635
# ----------------------
#
# Calculating eig number 102
#
# ----------------------
# Converged at step 3:
#
# k = 7.652043416552635
# ----------------------
#
# Calculating eig number 103
#
# ----------------------
# Converged at step 3:
#
# k = 7.652043416552638
# ----------------------
#
# Calculating eig number 104
#
# ----------------------
# Converged at step 3:
#
# k = 7.652043416552636
# ----------------------
#
# Calculating eig number 105
#
# ----------------------
# Converged at step 3:
#
# k = 7.652043416552631
# ----------------------
#
# Calculating eig number 106
#
# ----------------------
# Converged at step 4:
#
# k = 7.652043416552637
# ----------------------
#
# Calculating eig number 107
#
# ----------------------
# Converged at step 4:
#
# k = 7.652043416552637
# ----------------------
#
# Calculating eig number 108
#
# ----------------------
# Converged at step 4:
#
# k = 7.652043416552637
# ----------------------
#
# Calculating eig number 109
#
# ----------------------
# Converged at step 5:
#
# k = 7.652043416552632
# ----------------------
#
# Calculating eig number 110
#
# ----------------------
# Converged at step 5:
#
# k = 7.652043416552634
# ----------------------
#
# Calculating eig number 111
#
# ----------------------
# Converged at step 5:
#
# k = 7.652043416552632
# ----------------------
#
# Calculating eig number 112
#
# ----------------------
# Converged at step 5:
#
# k = 7.652043416552634
# ----------------------
#
# Calculating eig number 113
#
# ----------------------
# Converged at step 5:
#
# k = 7.652043416552633
# ----------------------
#
# Calculating eig number 114
#
# ----------------------
# Converged at step 5:
#
# k = 7.652043416552633
# ----------------------
#
# Calculating eig number 115
#
# ----------------------
# Converged at step 5:
#
# k = 7.652043416552635
# ----------------------
#
# Calculating eig number 116
#
# ----------------------
# Converged at step 4:
#
# k = 8.81046932513987
# ----------------------
#
# Calculating eig number 117
#
# ----------------------
# Converged at step 4:
#
# k = 8.810469325139874
# ----------------------
#
# Calculating eig number 118
#
# ----------------------
# Converged at step 3:
#
# k = 8.81046932513987
# ----------------------
#
# Calculating eig number 119
#
# ----------------------
# Converged at step 3:
#
# k = 8.810469325139872
# ----------------------
#
# Calculating eig number 120
#
# ----------------------
# Converged at step 3:
#
# k = 8.810469325139872
# ----------------------
#
# Calculating eig number 121
#
# ----------------------
# Converged at step 3:
#
# k = 8.81046932513987
# ----------------------
#
# Calculating eig number 122
#
# ----------------------
# Converged at step 3:
#
# k = 8.810469325139868
# ----------------------
#
# Calculating eig number 123
#
# ----------------------
# Converged at step 3:
#
# k = 8.810469325139868
# ----------------------
#
# Calculating eig number 124
#
# ----------------------
# Converged at step 4:
#
# k = 8.810469325139874
# ----------------------
#
# Calculating eig number 125
#
# ----------------------
# Converged at step 4:
#
# k = 8.81046932513987
# ----------------------
#
# Calculating eig number 126
#
# ----------------------
# Converged at step 4:
#
# k = 8.810469325139872
# ----------------------
#
# Calculating eig number 127
#
# ----------------------
# Converged at step 4:
#
# k = 8.810469325139868
# ----------------------
#
# Calculating eig number 128
#
# ----------------------
# Converged at step 5:
#
# k = 8.81046932513987
# ----------------------
#
# Calculating eig number 129
#
# ----------------------
# Converged at step 5:
#
# k = 8.810469325139868
# ----------------------
#
# Calculating eig number 130
#
# ----------------------
# Converged at step 5:
#
# k = 8.810469325139874
# ----------------------
#
# Calculating eig number 131
#
# ----------------------
# Converged at step 5:
#
# k = 8.81046932513987
# ----------------------
#
# Calculating eig number 132
#
# ----------------------
# Converged at step 5:
#
# k = 8.810469325139872
# ----------------------
#
# Calculating eig number 133
#
# ----------------------
# Converged at step 5:
#
# k = 8.810469325139874
# ----------------------
#
# Calculating eig number 134
#
# ----------------------
# Converged at step 5:
#
# k = 8.810469325139874
# ----------------------
#
# Calculating eig number 135
#
# ----------------------
# Converged at step 5:
#
# k = 8.81046932513987
# ----------------------
#
# Calculating eig number 136
#
# ----------------------
# Converged at step 5:
#
# k = 8.810469325139868
# ----------------------
#
# Calculating eig number 137
#
# ----------------------
# Converged at step 5:
#
# k = 8.810469325139868
# ----------------------
#
# Calculating eig number 138
#
# ----------------------
# Converged at step 5:
#
# k = 8.810469325139874
# ----------------------
#
# Calculating eig number 139
#
# ----------------------
# Converged at step 5:
#
# k = 8.810469325139874
# ----------------------
#
# Calculating eig number 140
#
# ----------------------
# Converged at step 5:
#
# k = 8.810469325139872
# ----------------------
#
# Calculating eig number 141
#
# ----------------------
# Converged at step 5:
#
# k = 8.810469325139874
# ----------------------
#
# Calculating eig number 142
#
# ----------------------
# Converged at step 5:
#
# k = 8.810469325139874
# ----------------------
#
# Calculating eig number 143
#
# ----------------------
# Converged at step 5:
#
# k = 8.810469325139872
# ----------------------
#
# Calculating eig number 144
#
# ----------------------
# Converged at step 5:
#
# k = 8.81046932513987
# ----------------------
#
# Calculating eig number 145
#
# ----------------------
# Converged at step 5:
#
# k = 8.810469325139872
# ----------------------
#
# Calculating eig number 146
#
# ----------------------
# Converged at step 5:
#
# k = 8.810469325139872
# ----------------------
#
# Calculating eig number 147
#
# ----------------------
# Converged at step 4:
#
# k = 11.584226571748674
# ----------------------
#
# Calculating eig number 148
#
# ----------------------
# Converged at step 4:
#
# k = 11.584226571748678
# ----------------------
#
# Calculating eig number 149
#
# ----------------------
# Converged at step 4:
#
# k = 11.584226571748676
# ----------------------
#
# Calculating eig number 150
#
# ----------------------
# Converged at step 4:
#
# k = 11.584226571748676
# ----------------------
#
# Calculating eig number 151
#
# ----------------------
# Converged at step 4:
#
# k = 11.584226571748676
# ----------------------
#
# Calculating eig number 152
#
# ----------------------
# Converged at step 4:
#
# k = 11.58422657174868
# ----------------------
#
# Calculating eig number 153
#
# ----------------------
# Converged at step 4:
#
# k = 11.584226571748676
# ----------------------
#
# Calculating eig number 154
#
# ----------------------
# Converged at step 4:
#
# k = 11.584226571748673
# ----------------------
#
# Calculating eig number 155
#
# ----------------------
# Converged at step 4:
#
# k = 11.584226571748676
# ----------------------
#
# Calculating eig number 156
#
# ----------------------
# Converged at step 4:
#
# k = 11.58422657174868
# ----------------------
#
# Calculating eig number 157
#
# ----------------------
# Converged at step 4:
#
# k = 11.584226571748674
# ----------------------
#
# Calculating eig number 158
#
# ----------------------
# Converged at step 4:
#
# k = 11.584226571748678
# ----------------------
#
# Calculating eig number 159
#
# ----------------------
# Converged at step 3:
#
# k = 11.58422657174868
# ----------------------
#
# Calculating eig number 160
#
# ----------------------
# Converged at step 3:
#
# k = 11.58422657174868
# ----------------------
#
# Calculating eig number 161
#
# ----------------------
# Converged at step 3:
#
# k = 11.584226571748681
# ----------------------
#
# Calculating eig number 162
#
# ----------------------
# Converged at step 3:
#
# k = 11.584226571748676
# ----------------------
#
# Calculating eig number 163
#
# ----------------------
# Converged at step 3:
#
# k = 11.584226571748674
# ----------------------
#
# Calculating eig number 164
#
# ----------------------
# Converged at step 3:
#
# k = 11.584226571748678
# ----------------------
#
# Calculating eig number 165
#
# ----------------------
# Converged at step 3:
#
# k = 11.584226571748678
# ----------------------
#
# Calculating eig number 166
#
# ----------------------
# Converged at step 3:
#
# k = 11.584226571748678
# ----------------------
#
# Calculating eig number 167
#
# ----------------------
# Converged at step 3:
#
# k = 11.584226571748676
# ----------------------
#
# Calculating eig number 168
#
# ----------------------
# Converged at step 4:
#
# k = 11.584226571748678
# ----------------------
#
# Calculating eig number 169
#
# ----------------------
# Converged at step 4:
#
# k = 11.584226571748676
# ----------------------
#
# Calculating eig number 170
#
# ----------------------
# Converged at step 4:
#
# k = 11.584226571748674
# ----------------------
#
# Calculating eig number 171
#
# ----------------------
# Converged at step 4:
#
# k = 11.584226571748678
# ----------------------
#
# Calculating eig number 172
#
# ----------------------
# Converged at step 4:
#
# k = 11.58422657174868
# ----------------------
#
# Calculating eig number 173
#
# ----------------------
# Converged at step 5:
#
# k = 11.584226571748678
# ----------------------
#
# Calculating eig number 174
#
# ----------------------
# Converged at step 5:
#
# k = 11.584226571748676
# ----------------------
#
# Calculating eig number 175
#
# ----------------------
# Converged at step 5:
#
# k = 11.584226571748678
# ----------------------
#
# Calculating eig number 176
#
# ----------------------
# Converged at step 5:
#
# k = 11.58422657174868
# ----------------------
#
# Calculating eig number 177
#
# ----------------------
# Converged at step 5:
#
# k = 11.584226571748678
# ----------------------
#
# Calculating eig number 178
#
# ----------------------
# Converged at step 5:
#
# k = 11.584226571748676
# ----------------------
#
# Calculating eig number 179
#
# ----------------------
# Converged at step 5:
#
# k = 11.58422657174868
# ----------------------
#
# Calculating eig number 180
#
# ----------------------
# Converged at step 3:
#
# k = 13.013289836310983
# ----------------------
#
# Calculating eig number 181
#
# ----------------------
# Converged at step 3:
#
# k = 13.013289836310985
# ----------------------
#
# Calculating eig number 182
#
# ----------------------
# Converged at step 3:
#
# k = 13.013289836310985
# ----------------------
#
# Calculating eig number 183
#
# ----------------------
# Converged at step 3:
#
# k = 13.013289836310983
# ----------------------
#
# Calculating eig number 184
#
# ----------------------
# Converged at step 3:
#
# k = 13.013289836310985
# ----------------------
#
# Calculating eig number 185
#
# ----------------------
# Converged at step 3:
#
# k = 13.01328983631098
# ----------------------
#
# Calculating eig number 186
#
# ----------------------
# Converged at step 3:
#
# k = 13.013289836310983
# ----------------------
#
# Calculating eig number 187
#
# ----------------------
# Converged at step 3:
#
# k = 13.01328983631098
# ----------------------
#
# Calculating eig number 188
#
# ----------------------
# Converged at step 3:
#
# k = 13.013289836310983
# ----------------------
#
# Calculating eig number 189
#
# ----------------------
# Converged at step 3:
#
# k = 13.013289836310983
# ----------------------
#
# Calculating eig number 190
#
# ----------------------
# Converged at step 2:
#
# k = 13.013289836310982
# ----------------------
#
# Calculating eig number 191
#
# ----------------------
# Converged at step 4:
#
# k = 13.01328983631098
# ----------------------
#
# Calculating eig number 192
#
# ----------------------
# Converged at step 4:
#
# k = 13.013289836310983
# ----------------------
#
# Calculating eig number 193
#
# ----------------------
# Converged at step 4:
#
# k = 13.013289836310983
# ----------------------
#
# Calculating eig number 194
#
# ----------------------
# Converged at step 4:
#
# k = 13.013289836310985
# ----------------------
#
# Calculating eig number 195
#
# ----------------------
# Converged at step 4:
#
# k = 13.013289836310983
# ----------------------
#
# Calculating eig number 196
#
# ----------------------
# Converged at step 4:
#
# k = 13.013289836310982
# ----------------------
#
# Calculating eig number 197
#
# ----------------------
# Converged at step 5:
#
# k = 13.013289836310983
# ----------------------
#
# Calculating eig number 198
#
# ----------------------
# Converged at step 5:
#
# k = 13.013289836310983
# ----------------------
#
# Calculating eig number 199
#
# ----------------------
# Converged at step 5:
#
# k = 13.013289836310983
# ----------------------
#
# Calculating eig number 200
#
# ----------------------
# Converged at step 5:
#
# k = 13.01328983631098
# ----------------------
#
# Calculating eig number 201
#
# ----------------------
# Converged at step 5:
#
# k = 13.01328983631098
# ----------------------
#
# Calculating eig number 202
#
# ----------------------
# Converged at step 5:
#
# k = 13.013289836310983
# ----------------------
#
# Calculating eig number 203
#
# ----------------------
# Converged at step 5:
#
# k = 13.01328983631098
# ----------------------
#
# Calculating eig number 204
#
# ----------------------
# Converged at step 5:
#
# k = 13.013289836310983
# ----------------------
#
# Calculating eig number 205
#
# ----------------------
# Converged at step 5:
#
# k = 13.013289836310982
# ----------------------
#
# Calculating eig number 206
#
# ----------------------
# Converged at step 5:
#
# k = 13.013289836310982
# ----------------------
#
# Calculating eig number 207
#
# ----------------------
# Converged at step 4:
#
# k = 15.017064644008025
# ----------------------
#
# Calculating eig number 208
#
# ----------------------
# Converged at step 4:
#
# k = 15.017064644008023
# ----------------------
#
# Calculating eig number 209
#
# ----------------------
# Converged at step 3:
#
# k = 15.017064644008025
# ----------------------
#
# Calculating eig number 210
#
# ----------------------
# Converged at step 3:
#
# k = 15.01706464400803
# ----------------------
#
# Calculating eig number 211
#
# ----------------------
# Converged at step 3:
#
# k = 15.017064644008027
# ----------------------
#
# Calculating eig number 212
#
# ----------------------
# Converged at step 3:
#
# k = 15.01706464400803
# ----------------------
#
# Calculating eig number 213
#
# ----------------------
# Converged at step 3:
#
# k = 15.017064644008025
# ----------------------
#
# Calculating eig number 214
#
# ----------------------
# Converged at step 3:
#
# k = 15.017064644008027
# ----------------------
#
# Calculating eig number 215
#
# ----------------------
# Converged at step 3:
#
# k = 15.017064644008023
# ----------------------
#
# Calculating eig number 216
#
# ----------------------
# Converged at step 3:
#
# k = 15.017064644008023
# ----------------------
#
# Calculating eig number 217
#
# ----------------------
# Converged at step 3:
#
# k = 15.017064644008027
# ----------------------
#
# Calculating eig number 218
#
# ----------------------
# Converged at step 3:
#
# k = 15.017064644008025
# ----------------------
#
# Calculating eig number 219
#
# ----------------------
# Converged at step 3:
#
# k = 15.017064644008023
# ----------------------
#
# Calculating eig number 220
#
# ----------------------
# Converged at step 3:
#
# k = 15.017064644008025
# ----------------------
#
# Calculating eig number 221
#
# ----------------------
# Converged at step 3:
#
# k = 15.017064644008025
# ----------------------
#
# Calculating eig number 222
#
# ----------------------
# Converged at step 4:
#
# k = 15.017064644008025
# ----------------------
#
# Calculating eig number 223
#
# ----------------------
# Converged at step 4:
#
# k = 15.017064644008023
# ----------------------
#
# Calculating eig number 224
#
# ----------------------
# Converged at step 4:
#
# k = 15.017064644008023
# ----------------------
#
# Calculating eig number 225
#
# ----------------------
# Converged at step 4:
#
# k = 15.017064644008027
# ----------------------
#
# Calculating eig number 226
#
# ----------------------
# Converged at step 3:
#
# k = 15.456383284498143
# ----------------------
#
# Calculating eig number 227
#
# ----------------------
# Converged at step 3:
#
# k = 15.456383284498148
# ----------------------
#
# Calculating eig number 228
#
# ----------------------
# Converged at step 3:
#
# k = 15.456383284498143
# ----------------------
#
# Calculating eig number 229
#
# ----------------------
# Converged at step 4:
#
# k = 15.456383284498148
# ----------------------
#
# Calculating eig number 230
#
# ----------------------
# Converged at step 4:
#
# k = 15.456383284498148
# ----------------------
#
# Calculating eig number 231
#
# ----------------------
# Converged at step 4:
#
# k = 15.456383284498148
# ----------------------
#
# Calculating eig number 232
#
# ----------------------
# Converged at step 4:
#
# k = 15.456383284498148
# ----------------------
#
# Calculating eig number 233
#
# ----------------------
# Converged at step 4:
#
# k = 15.456383284498147
# ----------------------
#
# Calculating eig number 234
#
# ----------------------
# Converged at step 4:
#
# k = 15.456383284498145
# ----------------------
#
# Calculating eig number 235
#
# ----------------------
# Converged at step 4:
#
# k = 15.456383284498145
# ----------------------
#
# Calculating eig number 236
#
# ----------------------
# Converged at step 4:
#
# k = 15.456383284498145
# ----------------------
#
# Calculating eig number 237
#
# ----------------------
# Converged at step 5:
#
# k = 15.456383284498148
# ----------------------
#
# Calculating eig number 238
#
# ----------------------
# Converged at step 5:
#
# k = 15.456383284498148
# ----------------------
#
# Calculating eig number 239
#
# ----------------------
# Converged at step 3:
#
# k = 16.682658120068393
# ----------------------
#
# Calculating eig number 240
#
# ----------------------
# Converged at step 3:
#
# k = 16.682658120068393
# ----------------------
#
# Calculating eig number 241
#
# ----------------------
# Converged at step 3:
#
# k = 16.682658120068393
# ----------------------
#
# Calculating eig number 242
#
# ----------------------
# Converged at step 3:
#
# k = 16.682658120068393
# ----------------------
#
# Calculating eig number 243
#
# ----------------------
# Converged at step 3:
#
# k = 16.682658120068393
# ----------------------
#
# Calculating eig number 244
#
# ----------------------
# Converged at step 3:
#
# k = 16.682658120068393
# ----------------------
#
# Calculating eig number 245
#
# ----------------------
# Converged at step 3:
#
# k = 16.682658120068393
# ----------------------
#
# Calculating eig number 246
#
# ----------------------
# Converged at step 3:
#
# k = 16.682658120068393
# ----------------------
#
# Calculating eig number 247
#
# ----------------------
# Converged at step 3:
#
# k = 16.682658120068393
# ----------------------
#
# Calculating eig number 248
#
# ----------------------
# Converged at step 4:
#
# k = 16.682658120068393
# ----------------------
#
# Calculating eig number 249
#
# ----------------------
# Converged at step 4:
#
# k = 16.682658120068393
# ----------------------
#
# Calculating eig number 250
#
# ----------------------
# Converged at step 4:
#
# k = 16.682658120068393
# ----------------------
#
# Calculating eig number 251
#
# ----------------------
# Converged at step 4:
#
# k = 16.682658120068393
# ----------------------
#
# Calculating eig number 252
#
# ----------------------
# Converged at step 4:
#
# k = 16.682658120068393
# ----------------------
#
# Calculating eig number 253
#
# ----------------------
# Converged at step 4:
#
# k = 16.682658120068393
# ----------------------
#
# Calculating eig number 254
#
# ----------------------
# Converged at step 4:
#
# k = 16.682658120068396
# ----------------------
#
# Calculating eig number 255
#
# ----------------------
# Converged at step 4:
#
# k = 16.682658120068396
# ----------------------
#
# Calculating eig number 256
#
# ----------------------
# Converged at step 4:
#
# k = 16.682658120068396
# ----------------------
#
# Calculating eig number 257
#
# ----------------------
# Converged at step 4:
#
# k = 16.682658120068393
# ----------------------
#
# Calculating eig number 258
#
# ----------------------
# Converged at step 4:
#
# k = 16.682658120068396
# ----------------------
#
# Calculating eig number 259
#
# ----------------------
# Converged at step 5:
#
# k = 16.682658120068393
# ----------------------
#
# Calculating eig number 260
#
# ----------------------
# Converged at step 5:
#
# k = 16.682658120068393
# ----------------------
#
# Calculating eig number 261
#
# ----------------------
# Converged at step 5:
#
# k = 16.682658120068393
# ----------------------
#
# Calculating eig number 262
#
# ----------------------
# Converged at step 3:
#
# k = 18.46439126011162
# ----------------------
#
# Calculating eig number 263
#
# ----------------------
# Converged at step 3:
#
# k = 18.46439126011162
# ----------------------
#
# Calculating eig number 264
#
# ----------------------
# Converged at step 3:
#
# k = 18.464391260111622
# ----------------------
#
# Calculating eig number 265
#
# ----------------------
# Converged at step 3:
#
# k = 18.464391260111622
# ----------------------
#
# Calculating eig number 266
#
# ----------------------
# Converged at step 3:
#
# k = 18.464391260111622
# ----------------------
#
# Calculating eig number 267
#
# ----------------------
# Converged at step 3:
#
# k = 18.464391260111622
# ----------------------
#
# Calculating eig number 268
#
# ----------------------
# Converged at step 3:
#
# k = 18.464391260111622
# ----------------------
#
# Calculating eig number 269
#
# ----------------------
# Converged at step 3:
#
# k = 18.464391260111622
# ----------------------
#
# Calculating eig number 270
#
# ----------------------
# Converged at step 3:
#
# k = 18.464391260111622
# ----------------------
#
# Calculating eig number 271
#
# ----------------------
# Converged at step 3:
#
# k = 18.464391260111622
# ----------------------
#
# Calculating eig number 272
#
# ----------------------
# Converged at step 3:
#
# k = 18.464391260111622
# ----------------------
#
# Calculating eig number 273
#
# ----------------------
# Converged at step 3:
#
# k = 18.464391260111622
# ----------------------
#
# Calculating eig number 274
#
# ----------------------
# Converged at step 3:
#
# k = 18.464391260111622
# ----------------------
#
# Calculating eig number 275
#
# ----------------------
# Converged at step 3:
#
# k = 18.464391260111622
# ----------------------
#
# Calculating eig number 276
#
# ----------------------
# Converged at step 3:
#
# k = 18.464391260111622
# ----------------------
#
# Calculating eig number 277
#
# ----------------------
# Converged at step 4:
#
# k = 18.464391260111622
# ----------------------
#
# Calculating eig number 278
#
# ----------------------
# Converged at step 4:
#
# k = 18.464391260111622
# ----------------------
#
# Calculating eig number 279
#
# ----------------------
# Converged at step 4:
#
# k = 18.464391260111622
# ----------------------
#
# Calculating eig number 280
#
# ----------------------
# Converged at step 4:
#
# k = 18.464391260111622
# ----------------------
#
# Calculating eig number 281
#
# ----------------------
# Converged at step 4:
#
# k = 18.464391260111622
# ----------------------
#
# Calculating eig number 282
#
# ----------------------
# Converged at step 4:
#
# k = 18.464391260111622
# ----------------------
#
# Calculating eig number 283
#
# ----------------------
# Converged at step 4:
#
# k = 18.464391260111622
# ----------------------
#
# Calculating eig number 284
#
# ----------------------
# Converged at step 4:
#
# k = 18.46439126011162
# ----------------------
#
# Calculating eig number 285
#
# ----------------------
# Converged at step 4:
#
# k = 18.46439126011162
# ----------------------
#
# Calculating eig number 286
#
# ----------------------
# Converged at step 4:
#
# k = 18.464391260111622
# ----------------------
#
# Calculating eig number 287
#
# ----------------------
# Converged at step 4:
#
# k = 18.46439126011162
# ----------------------
#
# Calculating eig number 288
#
# ----------------------
# Converged at step 4:
#
# k = 18.464391260111622
# ----------------------
#
# Calculating eig number 289
#
# ----------------------
# Converged at step 4:
#
# k = 18.46439126011162
# ----------------------
#
# Calculating eig number 290
#
# ----------------------
# Converged at step 4:
#
# k = 18.46439126011162
# ----------------------
#
# Calculating eig number 291
#
# ----------------------
# Converged at step 4:
#
# k = 18.46439126011162
# ----------------------
#
# Calculating eig number 292
#
# ----------------------
# Converged at step 3:
#
# k = 20.449488498389325
# ----------------------
#
# Calculating eig number 293
#
# ----------------------
# Converged at step 3:
#
# k = 20.449488498389325
# ----------------------
#
# Calculating eig number 294
#
# ----------------------
# Converged at step 3:
#
# k = 20.449488498389325
# ----------------------
#
# Calculating eig number 295
#
# ----------------------
# Converged at step 3:
#
# k = 20.449488498389325
# ----------------------
#
# Calculating eig number 296
#
# ----------------------
# Converged at step 3:
#
# k = 20.449488498389325
# ----------------------
#
# Calculating eig number 297
#
# ----------------------
# Converged at step 3:
#
# k = 20.449488498389325
# ----------------------
#
# Calculating eig number 298
#
# ----------------------
# Converged at step 3:
#
# k = 20.449488498389325
# ----------------------
#
# Calculating eig number 299
#
# ----------------------
# Converged at step 3:
#
# k = 20.449488498389325
# ----------------------
#
# Calculating eig number 300
#
# ----------------------
# Converged at step 3:
#
# k = 20.449488498389325
# ----------------------
# num_Vs = 144
#
#
#
#
#
# Calculating eig number 0
#
# ----------------------
# Converged at step 0:
#
# k = 2.2842918305380106e-15
# ----------------------
#
# Calculating eig number 1
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 2
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 3
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 4
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 5
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 6
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 7
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 8
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 9
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 10
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 11
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 12
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 13
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 14
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 15
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 16
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 17
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 18
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 19
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 20
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 21
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 22
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 23
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 24
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 25
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 26
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 27
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 28
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 29
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 30
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 31
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 32
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 33
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 34
#
# ----------------------
# Converged at step 2:
#
# k = 0
# ----------------------
#
# Calculating eig number 35
#
# ----------------------
# Converged at step 5:
#
# k = 4.4371053990682485
# ----------------------
#
# Calculating eig number 36
#
# ----------------------
# Converged at step 5:
#
# k = 4.43710539906826
# ----------------------
#
# Calculating eig number 37
#
# ----------------------
# Converged at step 4:
#
# k = 4.43710539906826
# ----------------------
#
# Calculating eig number 38
#
# ----------------------
# Converged at step 4:
#
# k = 4.437105399068248
# ----------------------
#
# Calculating eig number 39
#
# ----------------------
# Converged at step 4:
#
# k = 4.437105399068269
# ----------------------
#
# Calculating eig number 40
#
# ----------------------
# Converged at step 4:
#
# k = 4.437105399068256
# ----------------------
#
# Calculating eig number 41
#
# ----------------------
# Converged at step 4:
#
# k = 4.43710539906826
# ----------------------
#
# Calculating eig number 42
#
# ----------------------
# Converged at step 4:
#
# k = 4.437105399068254
# ----------------------
#
# Calculating eig number 43
#
# ----------------------
# Converged at step 4:
#
# k = 4.437105399068249
# ----------------------
#
# Calculating eig number 44
#
# ----------------------
# Converged at step 4:
#
# k = 4.437105399068265
# ----------------------
#
# Calculating eig number 45
#
# ----------------------
# Converged at step 4:
#
# k = 4.43710539906825
# ----------------------
#
# Calculating eig number 46
#
# ----------------------
# Converged at step 4:
#
# k = 4.43710539906826
# ----------------------
#
# Calculating eig number 47
#
# ----------------------
# Converged at step 4:
#
# k = 4.437105399068266
# ----------------------
#
# Calculating eig number 48
#
# ----------------------
# Converged at step 4:
#
# k = 4.437105399068262
# ----------------------
#
# Calculating eig number 49
#
# ----------------------
# Converged at step 4:
#
# k = 4.437105399068261
# ----------------------
#
# Calculating eig number 50
#
# ----------------------
# Converged at step 4:
#
# k = 4.437105399068256
# ----------------------
#
# Calculating eig number 51
#
# ----------------------
# Converged at step 4:
#
# k = 4.437105399068265
# ----------------------
#
# Calculating eig number 52
#
# ----------------------
# Converged at step 3:
#
# k = 4.437105399068258
# ----------------------
#
# Calculating eig number 53
#
# ----------------------
# Converged at step 3:
#
# k = 4.437105399068266
# ----------------------
#
# Calculating eig number 54
#
# ----------------------
# Converged at step 3:
#
# k = 4.437105399068263
# ----------------------
#
# Calculating eig number 55
#
# ----------------------
# Converged at step 3:
#
# k = 4.437105399068255
# ----------------------
#
# Calculating eig number 56
#
# ----------------------
# Converged at step 4:
#
# k = 4.437105399068263
# ----------------------
#
# Calculating eig number 57
#
# ----------------------
# Converged at step 5:
#
# k = 4.437105399068242
# ----------------------
#
# Calculating eig number 58
#
# ----------------------
# Converged at step 5:
#
# k = 4.437105399068253
# ----------------------
#
# Calculating eig number 59
#
# ----------------------
# Converged at step 5:
#
# k = 4.43710539906826
# ----------------------
#
# Calculating eig number 60
#
# ----------------------
# Converged at step 5:
#
# k = 4.437105399068254
# ----------------------
#
# Calculating eig number 61
#
# ----------------------
# Converged at step 5:
#
# k = 4.437105399068263
# ----------------------
#
# Calculating eig number 62
#
# ----------------------
# Converged at step 5:
#
# k = 4.437105399068258
# ----------------------
#
# Calculating eig number 63
#
# ----------------------
# Converged at step 5:
#
# k = 4.4371053990682565
# ----------------------
#
# Calculating eig number 64
#
# ----------------------
# Converged at step 5:
#
# k = 4.437105399068251
# ----------------------
#
# Calculating eig number 65
#
# ----------------------
# Converged at step 5:
#
# k = 4.437105399068263
# ----------------------
#
# Calculating eig number 66
#
# ----------------------
# Converged at step 5:
#
# k = 4.437105399068269
# ----------------------
#
# Calculating eig number 67
#
# ----------------------
# Converged at step 5:
#
# k = 4.437105399068247
# ----------------------
#
# Calculating eig number 68
#
# ----------------------
# Converged at step 6:
#
# k = 4.437105399068242
# ----------------------
#
# Calculating eig number 69
#
# ----------------------
# Converged at step 6:
#
# k = 4.437105399068256
# ----------------------
#
# Calculating eig number 70
#
# ----------------------
# Converged at step 6:
#
# k = 4.43710539906826
# ----------------------
#
# Calculating eig number 71
#
# ----------------------
# Converged at step 6:
#
# k = 4.4371053990682645
# ----------------------
#
# Calculating eig number 72
#
# ----------------------
# Converged at step 6:
#
# k = 4.437105399068249
# ----------------------
#
# Calculating eig number 73
#
# ----------------------
# Converged at step 6:
#
# k = 4.437105399068253
# ----------------------
#
# Calculating eig number 74
#
# ----------------------
# Converged at step 6:
#
# k = 4.43710539906826
# ----------------------
#
# Calculating eig number 75
#
# ----------------------
# Converged at step 6:
#
# k = 4.437105399068259
# ----------------------
#
# Calculating eig number 76
#
# ----------------------
# Converged at step 6:
#
# k = 4.437105399068262
# ----------------------
#
# Calculating eig number 77
#
# ----------------------
# Converged at step 6:
#
# k = 4.437105399068254
# ----------------------
#
# Calculating eig number 78
#
# ----------------------
# Converged at step 6:
#
# k = 4.437105399068258
# ----------------------
#
# Calculating eig number 79
#
# ----------------------
# Converged at step 6:
#
# k = 4.437105399068263
# ----------------------
#
# Calculating eig number 80
#
# ----------------------
# Converged at step 6:
#
# k = 4.437105399068259
# ----------------------
#
# Calculating eig number 81
#
# ----------------------
# Converged at step 6:
#
# k = 4.437105399068252
# ----------------------
#
# Calculating eig number 82
#
# ----------------------
# Converged at step 6:
#
# k = 4.437105399068264
# ----------------------
#
# Calculating eig number 83
#
# ----------------------
# Converged at step 6:
#
# k = 4.43710539906826
# ----------------------
#
# Calculating eig number 84
#
# ----------------------
# Converged at step 4:
#
# k = 7.665488614305238
# ----------------------
#
# Calculating eig number 85
#
# ----------------------
# Converged at step 4:
#
# k = 7.665488614305236
# ----------------------
#
# Calculating eig number 86
#
# ----------------------
# Converged at step 4:
#
# k = 7.665488614305245
# ----------------------
#
# Calculating eig number 87
#
# ----------------------
# Converged at step 4:
#
# k = 7.665488614305245
# ----------------------
#
# Calculating eig number 88
#
# ----------------------
# Converged at step 4:
#
# k = 7.665488614305238
# ----------------------
#
# Calculating eig number 89
#
# ----------------------
# Converged at step 4:
#
# k = 7.665488614305244
# ----------------------
#
# Calculating eig number 90
#
# ----------------------
# Converged at step 4:
#
# k = 7.665488614305235
# ----------------------
#
# Calculating eig number 91
#
# ----------------------
# Converged at step 4:
#
# k = 7.665488614305231
# ----------------------
#
# Calculating eig number 92
#
# ----------------------
# Converged at step 4:
#
# k = 7.665488614305235
# ----------------------
#
# Calculating eig number 93
#
# ----------------------
# Converged at step 4:
#
# k = 7.665488614305244
# ----------------------
#
# Calculating eig number 94
#
# ----------------------
# Converged at step 4:
#
# k = 7.665488614305246
# ----------------------
#
# Calculating eig number 95
#
# ----------------------
# Converged at step 4:
#
# k = 7.665488614305241
# ----------------------
#
# Calculating eig number 96
#
# ----------------------
# Converged at step 4:
#
# k = 7.665488614305235
# ----------------------
#
# Calculating eig number 97
#
# ----------------------
# Converged at step 4:
#
# k = 7.665488614305242
# ----------------------
#
# Calculating eig number 98
#
# ----------------------
# Converged at step 4:
#
# k = 7.665488614305237
# ----------------------
#
# Calculating eig number 99
#
# ----------------------
# Converged at step 4:
#
# k = 7.665488614305242
# ----------------------
#
# Calculating eig number 100
#
# ----------------------
# Converged at step 4:
#
# k = 7.665488614305242
# ----------------------
#
# Calculating eig number 101
#
# ----------------------
# Converged at step 3:
#
# k = 7.6654886143052385
# ----------------------
#
# Calculating eig number 102
#
# ----------------------
# Converged at step 3:
#
# k = 7.665488614305243
# ----------------------
#
# Calculating eig number 103
#
# ----------------------
# Converged at step 3:
#
# k = 7.665488614305236
# ----------------------
#
# Calculating eig number 104
#
# ----------------------
# Converged at step 3:
#
# k = 7.665488614305238
# ----------------------
#
# Calculating eig number 105
#
# ----------------------
# Converged at step 3:
#
# k = 7.665488614305236
# ----------------------
#
# Calculating eig number 106
#
# ----------------------
# Converged at step 4:
#
# k = 7.66548861430523
# ----------------------
#
# Calculating eig number 107
#
# ----------------------
# Converged at step 4:
#
# k = 7.665488614305235
# ----------------------
#
# Calculating eig number 108
#
# ----------------------
# Converged at step 4:
#
# k = 7.6654886143052385
# ----------------------
#
# Calculating eig number 109
#
# ----------------------
# Converged at step 5:
#
# k = 7.6654886143052465
# ----------------------
#
# Calculating eig number 110
#
# ----------------------
# Converged at step 5:
#
# k = 7.665488614305235
# ----------------------
#
# Calculating eig number 111
#
# ----------------------
# Converged at step 5:
#
# k = 7.665488614305233
# ...
# Converged at step 3:
#
# k = 11.753257785800837
# ----------------------
#
# Calculating eig number 168
#
# ----------------------
# Converged at step 3:
#
# k = 11.753257785801011
# ----------------------
#
# Calculating eig number 169
#
# ----------------------
# Converged at step 3:
#
# k = 11.75325778580087
# ----------------------
#
# Calculating eig number 170
#
# ----------------------
# Converged at step 3:
#
# k = 11.75325778580102
# ----------------------
#
# Calculating eig number 171
#
# ----------------------
# Converged at step 4:
#
# k = 11.753257785800647
# ----------------------
#
# Calculating eig number 172
#
# ----------------------
# Converged at step 4:
#
# k = 11.753257785800903
# ----------------------
#
# Calculating eig number 173
#
# ----------------------
# Converged at step 4:
#
# k = 11.753257785800681
# ----------------------
#
# Calculating eig number 174
#
# ----------------------
# Converged at step 4:
#
# k = 11.753257785800907
# ----------------------
#
# Calculating eig number 175
#
# ----------------------
# Converged at step 5:
#
# k = 11.75325778580086
# ----------------------
#
# Calculating eig number 176
#
# ----------------------
# Converged at step 5:
#
# k = 11.753257785800999
# ----------------------
#
# Calculating eig number 177
#
# ----------------------
# Converged at step 5:
#
# k = 11.753257785800812
# ----------------------
#
# Calculating eig number 178
#
# ----------------------
# Converged at step 5:
#
# k = 11.753257785800873
# ----------------------
#
# Calculating eig number 179
#
# ----------------------
# Converged at step 5:
#
# k = 11.753257785800933
# ----------------------
#
# Calculating eig number 180
#
# ----------------------
# Converged at step 5:
#
# k = 11.753257785801154
# ----------------------
#
# Calculating eig number 181
#
# ----------------------
# Converged at step 5:
#
# k = 11.75325778580129
# ----------------------
#
# Calculating eig number 182
#
# ----------------------
# Converged at step 5:
#
# k = 11.753257785800766
# ----------------------
#
# Calculating eig number 183
#
# ----------------------
# Converged at step 4:
#
# k = 13.326449502985072
# ----------------------
#
# Calculating eig number 184
#
# ----------------------
# Converged at step 4:
#
# k = 13.326449502984856
# ----------------------
#
# Calculating eig number 185
#
# ----------------------
# Converged at step 4:
#
# k = 13.326449502984842
# ----------------------
#
# Calculating eig number 186
#
# ----------------------
# Converged at step 4:
#
# k = 13.326449502984994
# ----------------------
#
# Calculating eig number 187
#
# ----------------------
# Converged at step 3:
#
# k = 13.326449502984584
# ----------------------
#
# Calculating eig number 188
#
# ----------------------
# Converged at step 3:
#
# k = 13.326449502984742
# ----------------------
#
# Calculating eig number 189
#
# ----------------------
# Converged at step 3:
#
# k = 13.326449502985009
# ----------------------
#
# Calculating eig number 190
#
# ----------------------
# Converged at step 3:
#
# k = 13.326449502984858
# ----------------------
#
# Calculating eig number 191
#
# ----------------------
# Converged at step 3:
#
# k = 13.32644950298453
# ----------------------
#
# Calculating eig number 192
#
# ----------------------
# Converged at step 3:
#
# k = 13.326449502984717
# ----------------------
#
# Calculating eig number 193
#
# ----------------------
# Converged at step 3:
#
# k = 13.326449502984833
# ----------------------
#
# Calculating eig number 194
#
# ----------------------
# Converged at step 3:
#
# k = 13.326449502984984
# ----------------------
#
# Calculating eig number 195
#
# ----------------------
# Converged at step 3:
#
# k = 13.326449502985035
# ----------------------
#
# Calculating eig number 196
#
# ----------------------
# Converged at step 4:
#
# k = 13.326449502984868
# ----------------------
#
# Calculating eig number 197
#
# ----------------------
# Converged at step 4:
#
# k = 13.326449502985032
# ----------------------
#
# Calculating eig number 198
#
# ----------------------
# Converged at step 4:
#
# k = 13.326449502984856
# ----------------------
#
# Calculating eig number 199
#
# ----------------------
# Converged at step 4:
#
# k = 13.32644950298487
# ----------------------
#
# Calculating eig number 200
#
# ----------------------
# Converged at step 5:
#
# k = 13.326449502984614
# ----------------------
#
# Calculating eig number 201
#
# ----------------------
# Converged at step 5:
#
# k = 13.326449502985009
# ----------------------
#
# Calculating eig number 202
#
# ----------------------
# Converged at step 5:
#
# k = 13.326449502984614
# ----------------------
#
# Calculating eig number 203
#
# ----------------------
# Converged at step 5:
#
# k = 13.326449502984893
# ----------------------
#
# Calculating eig number 204
#
# ----------------------
# Converged at step 5:
#
# k = 13.326449502985026
# ----------------------
#
# Calculating eig number 205
#
# ----------------------
# Converged at step 5:
#
# k = 13.326449502984838
# ----------------------
#
# Calculating eig number 206
#
# ----------------------
# Converged at step 5:
#
# k = 13.32644950298454
# ----------------------
#
# Calculating eig number 207
#
# ----------------------
# Converged at step 5:
#
# k = 13.326449502984808
# ----------------------
#
# Calculating eig number 208
#
# ----------------------
# Converged at step 5:
#
# k = 13.32644950298492
# ----------------------
#
# Calculating eig number 209
#
# ----------------------
# Converged at step 5:
#
# k = 13.326449502984781
# ----------------------
#
# Calculating eig number 210
#
# ----------------------
# Converged at step 5:
#
# k = 13.326449502984799
# ----------------------
#
# Calculating eig number 211
#
# ----------------------
# Converged at step 5:
#
# k = 13.326449502984806
# ----------------------
#
# Calculating eig number 212
#
# ----------------------
# Converged at step 4:
#
# k = 15.387219092000073
# ----------------------
#
# Calculating eig number 213
#
# ----------------------
# Converged at step 4:
#
# k = 15.387219092000208
# ----------------------
#
# Calculating eig number 214
#
# ----------------------
# Converged at step 4:
#
# k = 15.387219092000315
# ----------------------
#
# Calculating eig number 215
#
# ----------------------
# Converged at step 4:
#
# k = 15.38721909200025
# ----------------------
#
# Calculating eig number 216
#
# ----------------------
# Converged at step 4:
#
# k = 15.38721909200016
# ----------------------
#
# Calculating eig number 217
#
# ----------------------
# Converged at step 4:
#
# k = 15.387219092000525
# ----------------------
#
# Calculating eig number 218
#
# ----------------------
# Converged at step 3:
#
# k = 15.387219092000215
# ----------------------
#
# Calculating eig number 219
#
# ----------------------
# Converged at step 3:
#
# k = 15.387219092000345
# ----------------------
#
# Calculating eig number 220
#
# ----------------------
# Converged at step 3:
#
# k = 15.387219091999972
# ----------------------
#
# Calculating eig number 221
#
# ----------------------
# Converged at step 3:
#
# k = 15.387219092000164
# ----------------------
#
# Calculating eig number 222
#
# ----------------------
# Converged at step 3:
#
# k = 15.387219092000526
# ----------------------
#
# Calculating eig number 223
#
# ----------------------
# Converged at step 3:
#
# k = 15.387219092000366
# ----------------------
#
# Calculating eig number 224
#
# ----------------------
# Converged at step 3:
#
# k = 15.387219092000048
# ----------------------
#
# Calculating eig number 225
#
# ----------------------
# Converged at step 3:
#
# k = 15.387219092000121
# ----------------------
#
# Calculating eig number 226
#
# ----------------------
# Converged at step 3:
#
# k = 15.3872190920001
# ----------------------
#
# Calculating eig number 227
#
# ----------------------
# Converged at step 3:
#
# k = 15.387219092000233
# ----------------------
#
# Calculating eig number 228
#
# ----------------------
# Converged at step 4:
#
# k = 15.387219092000434
# ----------------------
#
# Calculating eig number 229
#
# ----------------------
# Converged at step 4:
#
# k = 15.387219092000358
# ----------------------
#
# Calculating eig number 230
#
# ----------------------
# Converged at step 4:
#
# k = 15.387219092000324
# ----------------------
#
# Calculating eig number 231
#
# ----------------------
# Converged at step 4:
#
# k = 15.387219092000167
# ----------------------
#
# Calculating eig number 232
#
# ----------------------
# Converged at step 4:
#
# k = 15.38721909200029
# ----------------------
#
# Calculating eig number 233
#
# ----------------------
# Converged at step 3:
#
# k = 16.01522472111037
# ----------------------
#
# Calculating eig number 234
#
# ----------------------
# Converged at step 3:
#
# k = 16.015224721110194
# ----------------------
#
# Calculating eig number 235
#
# ----------------------
# Converged at step 3:
#
# k = 16.015224721110144
# ----------------------
#
# Calculating eig number 236
#
# ----------------------
# Converged at step 3:
#
# k = 16.015224721110147
# ----------------------
#
# Calculating eig number 237
#
# ----------------------
# Converged at step 3:
#
# k = 16.01522472111013
# ----------------------
#
# Calculating eig number 238
#
# ----------------------
# Converged at step 4:
#
# k = 16.015224721110116
# ----------------------
#
# Calculating eig number 239
#
# ----------------------
# Converged at step 4:
#
# k = 16.015224721109867
# ----------------------
#
# Calculating eig number 240
#
# ----------------------
# Converged at step 4:
#
# k = 16.01522472111031
# ----------------------
#
# Calculating eig number 241
#
# ----------------------
# Converged at step 4:
#
# k = 16.015224721110123
# ----------------------
#
# Calculating eig number 242
#
# ----------------------
# Converged at step 4:
#
# k = 16.0152247211101
# ----------------------
#
# Calculating eig number 243
#
# ----------------------
# Converged at step 5:
#
# k = 16.015224721110275
# ----------------------
#
# Calculating eig number 244
#
# ----------------------
# Converged at step 5:
#
# k = 16.01522472111036
# ----------------------
#
# Calculating eig number 245
#
# ----------------------
# Converged at step 5:
#
# k = 16.015224721110286
# ----------------------
#
# Calculating eig number 246
#
# ----------------------
# Converged at step 5:
#
# k = 16.015224721109956
# ----------------------
#
# Calculating eig number 247
#
# ----------------------
# Converged at step 5:
#
# k = 16.015224721110318
# ----------------------
#
# Calculating eig number 248
#
# ----------------------
# Converged at step 5:
#
# k = 16.015224721110368
# ----------------------
#
# Calculating eig number 249
#
# ----------------------
# Converged at step 5:
#
# k = 16.01522472111022
# ----------------------
#
# Calculating eig number 250
#
# ----------------------
# Converged at step 5:
#
# k = 16.015224721110464
# ----------------------
#
# Calculating eig number 251
#
# ----------------------
# Converged at step 5:
#
# k = 16.01522472111015
# ----------------------
#
# Calculating eig number 252
#
# ----------------------
# Converged at step 4:
#
# k = 17.766305898470094
# ----------------------
#
# Calculating eig number 253
#
# ----------------------
# Converged at step 4:
#
# k = 17.76630589847014
# ----------------------
#
# Calculating eig number 254
#
# ----------------------
# Converged at step 3:
#
# k = 17.76630589846992
# ----------------------
#
# Calculating eig number 255
#
# ----------------------
# Converged at step 3:
#
# k = 17.766305898470083
# ----------------------
#
# Calculating eig number 256
#
# ----------------------
# Converged at step 3:
#
# k = 17.766305898470037
# ----------------------
#
# Calculating eig number 257
#
# ----------------------
# Converged at step 3:
#
# k = 17.766305898469913
# ----------------------
#
# Calculating eig number 258
#
# ----------------------
# Converged at step 3:
#
# k = 17.766305898469916
# ----------------------
#
# Calculating eig number 259
#
# ----------------------
# Converged at step 3:
#
# k = 17.76630589847003
# ----------------------
#
# Calculating eig number 260
#
# ----------------------
# Converged at step 3:
#
# k = 17.766305898469813
# ----------------------
#
# Calculating eig number 261
#
# ----------------------
# Converged at step 3:
#
# k = 17.76630589846975
# ----------------------
#
# Calculating eig number 262
#
# ----------------------
# Converged at step 3:
#
# k = 17.766305898470197
# ----------------------
#
# Calculating eig number 263
#
# ----------------------
# Converged at step 3:
#
# k = 17.76630589846982
# ----------------------
#
# Calculating eig number 264
#
# ----------------------
# Converged at step 3:
#
# k = 17.766305898469913
# ----------------------
#
# Calculating eig number 265
#
# ----------------------
# Converged at step 4:
#
# k = 17.766305898470065
# ----------------------
#
# Calculating eig number 266
#
# ----------------------
# Converged at step 4:
#
# k = 17.766305898469763
# ----------------------
#
# Calculating eig number 267
#
# ----------------------
# Converged at step 4:
#
# k = 17.766305898470193
# ----------------------
#
# Calculating eig number 268
#
# ----------------------
# Converged at step 4:
#
# k = 17.766305898470044
# ----------------------
#
# Calculating eig number 269
#
# ----------------------
# Converged at step 4:
#
# k = 17.76630589846997
# ----------------------
#
# Calculating eig number 270
#
# ----------------------
# Converged at step 4:
#
# k = 17.766305898469863
# ----------------------
#
# Calculating eig number 271
#
# ----------------------
# Converged at step 5:
#
# k = 17.766305898469966
# ----------------------
#
# Calculating eig number 272
#
# ----------------------
# Converged at step 5:
#
# k = 17.766305898470055
# ----------------------
#
# Calculating eig number 273
#
# ----------------------
# Converged at step 5:
#
# k = 17.766305898469806
# ----------------------
#
# Calculating eig number 274
#
# ----------------------
# Converged at step 5:
#
# k = 17.76630589846975
# ----------------------
#
# Calculating eig number 275
#
# ----------------------
# Converged at step 5:
#
# k = 17.766305898469938
# ----------------------
#
# Calculating eig number 276
#
# ----------------------
# Converged at step 5:
#
# k = 17.76630589846974
# ----------------------
#
# Calculating eig number 277
#
# ----------------------
# Converged at step 5:
#
# k = 17.766305898470126
# ----------------------
#
# Calculating eig number 278
#
# ----------------------
# Converged at step 3:
#
# k = 19.359338209943424
# ----------------------
#
# Calculating eig number 279
#
# ----------------------
# Converged at step 3:
#
# k = 19.359338209943076
# ----------------------
#
# Calculating eig number 280
#
# ----------------------
# Converged at step 3:
#
# k = 19.359338209943264
# ----------------------
#
# Calculating eig number 281
#
# ----------------------
# Converged at step 3:
#
# k = 19.359338209943225
# ----------------------
#
# Calculating eig number 282
#
# ----------------------
# Converged at step 3:
#
# k = 19.35933820994317
# ----------------------
#
# Calculating eig number 283
#
# ----------------------
# Converged at step 3:
#
# k = 19.35933820994312
# ----------------------
#
# Calculating eig number 284
#
# ----------------------
# Converged at step 3:
#
# k = 19.359338209943296
# ----------------------
#
# Calculating eig number 285
#
# ----------------------
# Converged at step 3:
#
# k = 19.35933820994324
# ----------------------
#
# Calculating eig number 286
#
# ----------------------
# Converged at step 3:
#
# k = 19.359338209943413
# ----------------------
#
# Calculating eig number 287
#
# ----------------------
# Converged at step 3:
#
# k = 19.359338209943274
# ----------------------
#
# Calculating eig number 288
#
# ----------------------
# Converged at step 3:
#
# k = 19.359338209943104
# ----------------------
#
# Calculating eig number 289
#
# ----------------------
# Converged at step 3:
#
# k = 19.359338209943225
# ----------------------
#
# Calculating eig number 290
#
# ----------------------
# Converged at step 3:
#
# k = 19.359338209943225
# ----------------------
#
# Calculating eig number 291
#
# ----------------------
# Converged at step 4:
#
# k = 19.359338209943104
# ----------------------
#
# Calculating eig number 292
#
# ----------------------
# Converged at step 4:
#
# k = 19.35933820994317
# ----------------------
#
# Calculating eig number 293
#
# ----------------------
# Converged at step 4:
#
# k = 19.35933820994342
# ----------------------
#
# Calculating eig number 294
#
# ----------------------
# Converged at step 4:
#
# k = 19.35933820994318
# ----------------------
#
# Calculating eig number 295
#
# ----------------------
# Converged at step 4:
#
# k = 19.359338209943267
# ----------------------
#
# Calculating eig number 296
#
# ----------------------
# Converged at step 4:
#
# k = 19.359338209943243
# ----------------------
#
# Calculating eig number 297
#
# ----------------------
# Converged at step 5:
#
# k = 19.35933820994321
# ----------------------
#
# Calculating eig number 298
#
# ----------------------
# Converged at step 3:
#
# k = 20.351988510794403
# ----------------------
#
# Calculating eig number 299
#
# ----------------------
# Converged at step 3:
#
# k = 20.351988510794456
# ----------------------
#
# Calculating eig number 300
#
# ----------------------
# Converged at step 3:
#
# k = 20.351988510794328
# ----------------------

# %%
eigenvalue_data
# Out:
# {100: array([1.04950820e-15, 4.43447256e+00, 7.65204342e+00, 8.81046933e+00,
#         1.15842266e+01, 1.30132898e+01, 1.50170646e+01, 1.54563833e+01,
#         1.66826581e+01, 1.84643913e+01, 2.04494885e+01]),
#  144: array([2.28429183e-15, 4.43710540e+00, 7.66548861e+00, 8.83588821e+00,
#         1.16411930e+01, 1.31350978e+01, 1.51392361e+01, 1.56806198e+01,
#         1.71956991e+01, 1.88081589e+01, 1.94384457e+01]),
#  196: array([1.29092579e-15, 4.43866567e+00, 7.67349764e+00, 8.85011652e+00,
#         1.16732733e+01, 1.31958980e+01, 1.52093565e+01, 1.57883103e+01,
#         1.74047006e+01, 1.89780549e+01, 1.97908248e+01]),
#  324: array([8.30888980e-16, 4.44034968e+00, 7.68217631e+00, 8.86482434e+00,
#         1.17066669e+01, 1.32538323e+01, 1.52831647e+01, 1.58893524e+01,
#         1.75784861e+01, 1.91433600e+01, 2.00662421e+01]),
#  576: array([2.03506443e-15, 4.44146466e+00, 7.68794211e+00, 8.87421080e+00,
#         1.17281348e+01, 1.32884187e+01, 1.53309772e+01, 1.59493091e+01,
#         1.76717764e+01, 1.92447506e+01, 2.02092121e+01]),
#  900: array([4.50543317e-16, 4.44197721e+00, 7.69059786e+00, 8.87843538e+00,
#         1.17378429e+01, 1.33034177e+01, 1.53526772e+01, 1.59752918e+01,
#         1.77100202e+01, 1.92895197e+01, 2.02671552e+01]),
#  1444: array([5.23663237e-15, 4.44231924e+00, 7.69237195e+00, 8.88122366e+00,
#         1.17442674e+01, 1.33131317e+01, 1.53670610e+01, 1.59921259e+01,
#         1.77341116e+01, 1.93188016e+01, 2.03035167e+01]),
#  2500: array([-1.32436091e-15,  4.44255768e+00,  7.69360955e+00,  8.88315295e+00,
#          1.17487208e+01,  1.33197685e+01,  1.53770423e+01,  1.60036336e+01,
#          1.77502743e+01,  1.93389447e+01,  2.03278652e+01]),
#  3844: array([1.21695227e-15, 4.44267150e+00, 7.69420061e+00, 8.88406982e+00,
#         1.17508397e+01, 1.33228987e+01, 1.53817941e+01, 1.60090633e+01,
#         1.77578149e+01, 1.93484847e+01, 2.03392148e+01]),
#  6084: array([5.71888304e-16, 4.44274939e+00, 7.69460517e+00, 8.88469569e+00,
#         1.17522869e+01, 1.33250266e+01, 1.53850407e+01, 1.60127554e+01,
#         1.77629114e+01, 1.93549850e+01, 2.03468827e+01]),
#  10000: array([-1.39790192e-15,  4.44280171e+00,  7.69487693e+00,  8.88511536e+00,
#          1.17532578e+01,  1.33264495e+01,  1.53872191e+01,  1.60152247e+01,
#          1.77663059e+01,  1.93593382e+01,  2.03519885e+01])}

# %%
def calculate_pde_eigenvalues(m, n):
    return np.sqrt( ((2 * np.pi * m)**2 + (2 * np.pi * n * np.sqrt(3))**2) / 2 )

mn = [[0, 0], [0, 1], [0, 2], [1, 0], [1, 1], [1, 2], [2, 0], [2, 1], [2, 2]]

# %%
class Eigendata:

    def __init__(self, data):

        self.data = data
        self.V_nums = np.array(list(self.data.keys()))
        self.eigendata_indices = list(self.data[self.V_nums[0]].keys())
        self.graph_eigenvalues, self.PDE_eigenvalues = self.get_eigenvalues()
        self.relative_eigenvalue_differences = self.calculate_relative_eigenvalue_differences()
        self.relative_eigenfunction_differences = self.calculate_relative_eigenfunction_differences()

    def get_eigenvalues(self):

        graph_eigenvalues = {}
        PDE_eigenvalues = {}
        for m, n in self.eigendata_indices:
            graph_eigenvalues[m, n] = []
            PDE_eigenvalues[m, n] = self.data[self.V_nums[0]][m, n]['PDE']['eigenvalue']
            for num_Vs in self.V_nums:
                graph_eigenvalues[m, n].append(self.data[num_Vs][m, n]['graph']['eigenvalue'])

        return graph_eigenvalues, PDE_eigenvalues
        
    def calculate_relative_eigenvalue_differences(self):

        relative_eigenvalue_differences = {}
        for m, n in self.eigendata_indices:
            pde_eig = self.PDE_eigenvalues[m, n]
            if np.abs(self.PDE_eigenvalues[m, n]) < 1e-14:
                rel_errs = [np.mean(np.abs(i - pde_eig)) for i in self.graph_eigenvalues[m, n]]
            else:
                rel_errs = [np.mean(np.abs((i - pde_eig) / pde_eig)) for i in self.graph_eigenvalues[m, n]]
            relative_eigenvalue_differences[m, n] = np.array(rel_errs)

        return relative_eigenvalue_differences

    def calculate_relative_eigenfunction_differences(self):

        relative_eigenfunction_differences = {}
        for m, n in self.eigendata_indices:
            relative_eigenfunction_differences[m, n] = []
            for num_Vs in self.V_nums:
                rel_errs = [(i - j).norm() for i, j in zip(self.data[num_Vs][m, n]['graph']['eigenfunction'], 
                                                           self.data[num_Vs][m, n]['PDE']['eigenfunction'])]
                relative_eigenfunction_differences[m, n].append(np.mean(rel_errs))

        return relative_eigenfunction_differences

class Graph_Modes:

    def __init__(self, g, graph_eigenvalues):

        (self.graph_eigenvalues,
         self.graph_eigenvectors, 
         self.null_space_dims) = self.calculate_graph_eigenvectors(g, graph_eigenvalues)
        self.graph_eigenfunctions = self.construct_graph_eigenfunctions(g)
    
    def construct_graph_eigenfunction(self, g, eigenvalue, eigenvector):

        graph_eigenfunction = []

        if np.abs(eigenvalue) < 1e-13:
            for e_num, ((v_num, w_num), l_vw) in enumerate(g.E_lengths_by_v_num.items()):
                edge_mode = np.ones(g.g_coords[e_num].shape[1])
                graph_eigenfunction.append(edge_mode)
        else:
            for e_num, ((v_num, w_num), l_vw) in enumerate(g.E_lengths_by_v_num.items()):
                parametrised_edge = np.linspace(0, l_vw, g.g_coords[e_num].shape[1])

                edge_mode = ((eigenvector[v_num] * np.sin(eigenvalue * parametrised_edge[::-1])
                            + eigenvector[w_num] * np.sin(eigenvalue * parametrised_edge)) 
                            / np.sin(eigenvalue * l_vw))
                
                graph_eigenfunction.append(edge_mode)

        graph_eigenfunction = Graph_Function(graph_eigenfunction, g.g_coords).normalize()

        return graph_eigenfunction
    
    def construct_graph_eigenfunctions(self, g):

        graph_eigenfunctions = []
        for eigenvalue, eigenvector in zip(self.graph_eigenvalues, self.graph_eigenvectors.T):
            graph_eigenfunctions.append(self.construct_graph_eigenfunction(g, eigenvalue, eigenvector))
        
        return graph_eigenfunctions
    
    def calculate_graph_eigenvectors(self, g, graph_eigenvalues):

        graph_eigenvectors = []
        null_space_dims = []
        if g.num_Vs < 10000: tolerance = None
        else: tolerance = 1e-8

        for k in graph_eigenvalues:

            if np.abs(k) < 1e-12:
                Q, R, perm, r = sparseqr.qr(g.construct_L(k), tolerance=None)
            else:
                Q, R, perm, r = sparseqr.qr(g.construct_L(k), tolerance=tolerance)

            dim_null_space = len(g.interior_V_num) - r

            null_vectors = Q.toarray()[:, -dim_null_space:]

            null_space_dims.append(dim_null_space)
            graph_eigenvectors.append(null_vectors)

        graph_eigenvalues = np.repeat(graph_eigenvalues, null_space_dims)
        graph_eigenvectors = np.hstack(graph_eigenvectors)

        return graph_eigenvalues, graph_eigenvectors, null_space_dims 
    
def generate_graph_linewidth(num_Vs):
    # Just a heuristic
    return np.max([0.5, -0.086 * np.sqrt(num_Vs) + 7.66])

def style_plot(fig, ax, aspect="equal", no_ticks=False, no_xticks=False, no_yticks=False):

    # Remove white space
    fig.tight_layout()

    # Makes axes aspect equal
    if aspect:
        ax.set_aspect(aspect)

    # Make tick labels bold font
    for label in ax.get_xticklabels() + ax.get_yticklabels():
        label.set_fontweight('bold')
        label.set_fontsize(20)

    # Make border thicker
    for spine in ax.spines.values():
        spine.set_linewidth(2) 

    # xy_ticks
    major_tick_length = 7
    minor_tick_length = 4
    if no_ticks:
        major_xtick_length = 0
        major_ytick_length = 0
        minor_xtick_length = 0
        minor_ytick_length = 0
    elif no_xticks:
        major_xtick_length = 0
        major_ytick_length = major_tick_length
        minor_xtick_length = 0
        minor_ytick_length = minor_tick_length
    elif no_yticks:
        major_xtick_length = major_tick_length
        major_ytick_length = 0
        minor_xtick_length = minor_tick_length
        minor_ytick_length = 0
    else:
        major_xtick_length = major_tick_length
        major_ytick_length = major_tick_length
        minor_xtick_length = minor_tick_length
        minor_ytick_length = minor_tick_length
    ax.tick_params(axis='x', which='major', length=major_xtick_length, width=2, direction='out')
    ax.tick_params(axis='y', which='major', length=major_ytick_length, width=2, direction='out')
    ax.tick_params(axis='x', which='minor', length=minor_xtick_length, width=1, direction='out')
    ax.tick_params(axis='y', which='minor', length=minor_ytick_length, width=1, direction='out')
    
class Graph_Function:

    def __init__(self, data, domain=None):

        self.data = data
        if domain is not None:
            self.domain = [edge_domain.copy() for edge_domain in domain]

    def __add__(self, other):

        if not isinstance(other, Graph_Function):
            return NotImplemented
        
        result = [i + j for i, j in zip(self.data, other.data)]

        return Graph_Function(result, self.domain)

    def __sub__(self, other):

        if not isinstance(other, Graph_Function):
            return NotImplemented
        
        result = [i - j for i, j in zip(self.data, other.data)]

        return Graph_Function(result, self.domain)

    def __mul__(self, other):

        if isinstance(other, Graph_Function):
            result = [i * j for i, j in zip(self.data, other.data)]

        elif np.isscalar(other):  
            result = [arr * other for arr in self.data]

        else:
            return NotImplemented
        
        return Graph_Function(result, self.domain)

    def __rmul__(self, other):

        return self.__mul__(other)

    def __truediv__(self, other):

        if isinstance(other, Graph_Function):
            result = [i / j for i, j in zip(self.data, other.data)]

        elif np.isscalar(other):  
            result = [arr / other for arr in self.data]

        else:
            return NotImplemented
        
        return Graph_Function(result, self.domain)

    def __rtruediv__(self, other):

        if np.isscalar(other):
            result = [other / arr for arr in self.data]

        else:
            return NotImplemented
        
        return Graph_Function(result, self.domain)

    def __eq__(self, other):

        if not isinstance(other, Graph_Function):
            return NotImplemented
        
        return all(np.array_equal(i, j) for i, j in zip(self.data, other.data))

    def __repr__(self):

        return f"Graph_Function({self.data})"
    
    def norm(self):

        return np.sqrt(self.dot(self))
    
    def normalize(self):

        norm = self.norm()

        if norm == 0:
            raise ValueError("Cannot normalize a zero vector.")

        result = [arr / norm for arr in self.data]

        return Graph_Function(result, self.domain)
    
    def dot(self, other):
        
        if not isinstance(other, Graph_Function):
            return NotImplemented
        
        if (self.domain is None) and not (other.domain is None):
            self.domain = other.domain
        elif not (self.domain is None) and (other.domain is None):
            other.domain = self.domain
        elif (self.domain is None) and (other.domain is None):
            raise ValueError("Graph_Functions need domain attributes.")
        
        graph_inner_product = 0

        for f0_edge, f1_edge, edge in zip(self.data, other.data, self.domain):
            edge_length = np.linalg.norm([edge[0, 0] - edge[0, -1], edge[1, 0] - edge[1, -1]])
            edge_param = np.linspace(0, edge_length, edge.shape[1])
            graph_inner_product += scipy.integrate.trapezoid(f0_edge * f1_edge, edge_param)

        return graph_inner_product

# %%
for m in range(6):
    print(np.round(calculate_pde_eigenvalues(m, np.arange(6)), 4))
# Out:
# [ 0.      7.6953 15.3906 23.0859 30.7812 38.4765]
# [ 4.4429  8.8858 16.019  23.5095 31.1002 38.7322]
# [ 8.8858 11.7548 17.7715 24.7369 32.0381 39.4892]
# [13.3286 15.3906 20.3598 26.6573 33.543  40.7197]
# [17.7715 19.3661 23.5095 29.1339 35.5431 42.3824]
# [22.2144 23.5095 27.025  32.0381 37.96   44.4288]

# %%
class Projector:

    def __init__(self, g, eigenvalues):

        self.data = {}
        self.modes = Graph_Modes(g, eigenvalues)
        self.V_coords = g.V_coords
        self.g_coords = g.g_coords

    def generate_basis_functions(self, m, n):

        if (m > 2) or (n > 2) or (m < 0) or (n < 0):
            raise ValueError("Projector is only set up for m, n \in [0, 1, 2]")

        if (m == 0) and (n == 0):
            return lambda x, y: np.ones(x.shape), 

        hexagonal_lattice_height = 1 / np.sqrt(3)

        cc = lambda m, n: lambda x, y: np.cos(2 * np.pi * m * x) * np.cos(2 * np.pi * n * y / hexagonal_lattice_height)
        cs = lambda m, n: lambda x, y: np.cos(2 * np.pi * m * x) * np.sin(2 * np.pi * n * y / hexagonal_lattice_height)
        sc = lambda m, n: lambda x, y: np.sin(2 * np.pi * m * x) * np.cos(2 * np.pi * n * y / hexagonal_lattice_height)
        ss = lambda m, n: lambda x, y: np.sin(2 * np.pi * m * x) * np.sin(2 * np.pi * n * y / hexagonal_lattice_height)

        if (m == 0) and (n == 1):
            return cc(m, n), cs(m, n)
        elif (m == 0) and (n == 2):
            return cc(m, n), cs(m, n), cc(3, 1), cs(3, 1), sc(3, 1), ss(3, 1)
        elif (m == 1) and (n == 0):
            return cc(m, n), sc(m, n)
        elif ((m == 1) and (n == 1)) or ((m == 2) and (n == 0)):
            return cc(1, 1), cs(1, 1), sc(1, 1), ss(1, 1), cc(2, 0), sc(2, 0)
        elif (m == 2) and (n == 2):
            return cc(m, n), cs(m, n), sc(m, n), ss(m, n), cc(4, 0), sc(4, 0)
        else:
            return cc(m, n), cs(m, n), sc(m, n), ss(m, n)

    def construct_pde_functions(self, m, n, function_domain="vertices"):

        basis_functions = self.generate_basis_functions(m, n)

        if function_domain == "vertices":
            x, y = self.V_coords[:, 0], self.V_coords[:, 1]

            pde_eigenvectors = [function(x, y) for function in basis_functions]
            pde_eigenvectors = [function / np.linalg.norm(function) for function in pde_eigenvectors]
            pde_eigenvectors = np.vstack((pde_eigenvectors)).T

            return pde_eigenvectors
        
        elif function_domain == "graph":
            pde_eigenfunctions = [[] for _ in range(len(basis_functions))]

            for edge in self.g_coords:
                x, y = edge
                
                for i in range(len(basis_functions)):
                    pde_eigenfunctions[i].append(basis_functions[i](x, y))

            pde_eigenfunctions = [Graph_Function(pde_eigenfunction, self.g_coords).normalize() 
                                  for pde_eigenfunction in pde_eigenfunctions]
            
            return pde_eigenfunctions

        elif function_domain == "continuum":
            edge = np.linspace(0, 1, 256, endpoint=True)   
            x, y = np.meshgrid(edge, edge / np.sqrt(3))
            pde_eigenfunctions = [function(x, y) for function in basis_functions]

            return x, y, pde_eigenfunctions

    def find_graph_eigenspace(self, m, n):

        pde_eigenvectors = self.construct_pde_functions(m, n, function_domain="vertices")
        num_basis_functions = pde_eigenvectors.shape[1]
        prod = pde_eigenvectors.T @ pde_eigenvectors
        invert_prod = np.linalg.inv(prod)
        proj = (pde_eigenvectors @ invert_prod @ pde_eigenvectors.T)

        keep_args = proj @ self.modes.graph_eigenvectors
        keep_args = np.argsort(np.linalg.norm(keep_args, axis=0))[-num_basis_functions:]

        # Handle when the graph eigenspace is larger than the PDE eigenspace
        uniques, counts = np.unique(np.round(self.modes.graph_eigenvalues[keep_args], 10), return_counts=True)
        new_keep_args = []
        for unique, count in zip(uniques, counts):
            where_equal = np.where(np.abs(self.modes.graph_eigenvalues - unique) < 1e-9)[0]
            if np.shape(where_equal)[0] != count:
                message = (f"For num_Vs={self.V_coords.shape[0]},m={m},n={n}, the graph eigenspace is larger than the PDE eigenspace. " + 
                            "This might be (a) a problem, (b) saying something interesting, or (c) nothing special.")
                warnings.warn(message)
            new_keep_args.append(where_equal)
        keep_args = np.concatenate((new_keep_args))

        return keep_args

    def __call__(self, m, n):

        self.data[m, n] = {"graph": {}, "PDE": {}}

        # Get PDE eigenvalues
        self.data[m, n]["PDE"]["eigenvalue"] = calculate_pde_eigenvalues(m, n)

        # Get PDE eigenfunctions
        pde_eigenfunctions = self.construct_pde_functions(m, n, function_domain="graph")
        self.data[m, n]["PDE"]["eigenfunction"] = pde_eigenfunctions
        
        # Get graph eigenvalues
        keep_args = self.find_graph_eigenspace(m, n)
        self.data[m, n]["graph"]["eigenvalue"] = self.modes.graph_eigenvalues[keep_args]

        # Get graph eigenfunctions
        project_functions = []
        for pde_eigenfunction in pde_eigenfunctions:
            projection = []
            for arg in keep_args:
                ip = pde_eigenfunction.dot(self.modes.graph_eigenfunctions[arg])
                projection.append(ip * self.modes.graph_eigenfunctions[arg])
            project_functions.append(np.sum(projection))
        self.data[m, n]["graph"]["eigenfunction"] = project_functions

# %%
print(eigenvalue_data.keys())
# Out:
# dict_keys([100, 144, 196, 324, 576, 900, 1444, 2500, 3844, 6084, 10000])

# %%
full_data = {}

for tile_num in tiles_per_dim:

    g = construct_graph.tiling.Tiling(tile_type='hexagonal_tile',
                                      num_horizontal_displacements=tile_num,
                                      num_vertical_displacements=tile_num,
                                      autoplot=False)
    print(g.num_Vs)
    p = Projector(g, eigenvalue_data[g.num_Vs])
    for m, n in mn:
        p(m, n)
    full_data[g.num_Vs] = p.data
# Out:
# 100
# 144
# 196
# 324
# 576
# 900
# 1444
# 2500
# 3844
# 6084
# 10000

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
order_line_color = colors[6]
colors = colors[:6] + colors[7:]
def plot_loglog_rel_err(Num_Vs, rel_errs):
    fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True, figsize=(7, 6), gridspec_kw={'height_ratios': [6, 1]})
    fig.subplots_adjust(hspace=0.2, )  # adjust space between axes

    # Separate data by size
    for en, rel_err in enumerate(rel_errs.T):
        if np.all(rel_err > 1e-10):
            ax1.loglog(Num_Vs, rel_err, 'o-', markersize=10, c=colors[en])
        else:
            ax2.loglog(Num_Vs, rel_err, 'o-', markersize=10, c=colors[en])
            if np.any(rel_err > 1e-10):
                relevant_data = rel_err[rel_err <= 1e-10]
                ax2.set_ylim(0.1 * np.min(relevant_data), 10 * np.max(relevant_data))

    # Setup convergence line
    ax1_data_lims = (np.min(rel_errs[rel_errs > 1e-10]), np.max(rel_errs[rel_errs > 1e-10]))
    ax1_log_dif = np.log10(ax1_data_lims[1]) - np.log10(ax1_data_lims[0])
    max_order_height = np.max(rel_errs) / np.max(Num_Vs**(-1.))
    order_line_data = max_order_height * Num_Vs**(-1.) * 10**(0.15 * ax1_log_dif)
    # order_line_data = max_order_height * Num_Vs**(-1.) * 1
    ax1.loglog(Num_Vs, order_line_data, 
               linewidth=4, c=order_line_color)

    # hide the spines between ax and ax2
    ax1.spines.bottom.set_visible(False)
    ax2.spines.top.set_visible(False)
    ax1.xaxis.tick_top()
    ax1.tick_params(labeltop=False)  # don't put tick labels at the top
    ax2.xaxis.tick_bottom()

    # Slanted lines
    d = 0.5
    kwargs = dict(marker=[(-1, -d), (1, d)], markersize=12,
                linestyle="none", color='k', mec='k', mew=3, clip_on=False)
    ax1.plot([0, 1], [0, 0], transform=ax1.transAxes, **kwargs)
    ax2.plot([0, 1], [1, 1], transform=ax2.transAxes, **kwargs)

    style_plot(fig, ax1, aspect=None, no_xticks=True)
    style_plot(fig, ax2, aspect=None)

    return fig, fig.axes

# %%
edata = Eigendata(full_data)

# %%
x = edata.V_nums
y = np.array(list(edata.relative_eigenvalue_differences.values())).T
plot_loglog_rel_err(x, y)
plt.savefig("tiling/hexagonal_periodic/hexagonal_periodic_tiling_eigenvalue_relerr.png", dpi=200, bbox_inches='tight')

# %%
x = edata.V_nums
y = np.array(list(edata.relative_eigenfunction_differences.values())).T
plot_loglog_rel_err(x, y)
plt.savefig("tiling/hexagonal_periodic/hexagonal_periodic_tiling_eigenfunction_relerr.png", dpi=200, bbox_inches='tight')

# %%
g = construct_graph.tiling.Tiling(tile_type='hexagonal_tile',
                                    num_horizontal_displacements=tiles_per_dim[0],
                                    num_vertical_displacements=tiles_per_dim[0],
                                    autoplot=False)
print(g.num_Vs)
p = Projector(g, eigenvalue_data[g.num_Vs])

for m, n in [[0, 0], [0, 1], [1, 0], [1, 1]]:
    x, y, A = p.construct_pde_functions(m, n, function_domain="continuum")
    for en, a in enumerate(A):
        fig = plt.figure(figsize=(10, 10))
        ax = fig.add_subplot(111)
        ax.pcolormesh(x, y, a, cmap="plasma", shading='auto')
        style_plot(fig, ax, aspect="equal", no_ticks=True)
        ax.axis('off')
        fig.set_facecolor("black")
        plt.savefig(f"tiling/hexagonal_periodic/PDE_mode_plots/continuum_eigenmode_m{m}_n{n}_number{en}.png", dpi=200, bbox_inches='tight')
        plt.close()
# Out:
# 100

# %%
g = construct_graph.tiling.Tiling(tile_type='hexagonal_tile',
                                    num_horizontal_displacements=tiles_per_dim[4],
                                    num_vertical_displacements=tiles_per_dim[4],
                                    autoplot=False)
print(g.num_Vs)
# Out:
# 576

# %%
for m, n in mn:
    emodes = full_data[g.num_Vs][m, n]['graph']['eigenfunction']
    for en, emode in enumerate(emodes):
        fig, ax = g.plot_graph(eigenmode=emode.data, return_figax=True, background_color="black", linewidth=generate_graph_linewidth(g.num_Vs))
        plt.savefig(f"tiling/hexagonal_periodic/mode_plots/eigenmode_{g.num_Vs}Vs_m{m}_n{n}_number{en}.png", dpi=200, bbox_inches='tight')
        plt.close()
