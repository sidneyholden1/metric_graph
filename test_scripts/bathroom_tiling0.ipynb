# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches
import scipy
import pickle
import warnings

import sys
sys.path.append('..')
from construct_graph.graph import Graph, Flat
import construct_graph
import solve_laplace_operator

import sparseqr

# %%
# file = open("tiling/bathroom_tile0_periodic/eigendata.pkl", "wb")
# pickle.dump(full_data, file)
# file.close()

# %%
powers_of_10_lims = (2, 4)
num_Vs_per_tile = 4
num_graphs_per_power_of_10 = 5
total_dpowers = num_graphs_per_power_of_10 * (powers_of_10_lims[1] - powers_of_10_lims[0]) + 1
power_linspace = np.linspace(powers_of_10_lims[0], powers_of_10_lims[1], total_dpowers)

tiles_per_dim = np.int32(np.sqrt(10**power_linspace / num_Vs_per_tile))

# %%
g = construct_graph.tiling.Tiling(tile_type='truncated_square',
                                    num_horizontal_displacements=tiles_per_dim[0],
                                    num_vertical_displacements=tiles_per_dim[0],
                                    autoplot=False)

# %%
pwd
# Out:
# '/Users/sidneyholden/repos/metric_graph/test_scripts'

# %%
fig, ax = g.plot_graph(embedding_space="square", 
                       linewidth=1, return_figax=True)
plt.savefig("/Users/sidneyholden/repos/metric_graph/data/tiling/bathroom_tile0_periodic/example_tile0_tiling.png", dpi=200, bbox_inches="tight")

# %%
def calculate_pde_eigenvalues(m, n):
    a = 1 / 2 * ((1 + np.sqrt(2))**2 / 6)
    return np.sqrt(((2 * np.pi * m)**2 + (2 * np.pi * n)**2) * a)

# %%
run_eigenvalue_calculations = True

if run_eigenvalue_calculations:
    guesses = np.concatenate([np.array([1e-15]), np.linspace(4, 14, 200)])

    eigenvalue_data = {}

    for tile_num in tiles_per_dim:
        g = construct_graph.tiling.Tiling(tile_type='bathroom_tile0',
                                          num_horizontal_displacements=tile_num,
                                          num_vertical_displacements=tile_num,
                                          autoplot=False, figsize=3)
        print(f"num_Vs = {g.num_Vs}")
        print("\n\n\n")
        eigs = solve_laplace_operator.solve_laplace_operator.Eigenvalue_Calculator(g)
        ks = eigs(guesses, printerval=1000, max_steps=1000, tol=1e-12, solve_type="SVD iterate")
        _, index = np.unique(np.round(ks, 6), return_index=True)
        eigenvalues = ks[index]
        eigenvalue_data[g.num_Vs] = eigenvalues.copy()
# Out:
# num_Vs = 100
#
#
#
#
#
# Calculating eig number 0
#
# ----------------------
# Converged at step 0:
#
# k = 4.074858824100324e-15
# ----------------------
#
# Calculating eig number 1
#
# ----------------------
# Converged at step 4:
#
# k = 4.32428946136029
# ----------------------
#
# Calculating eig number 2
#
# ----------------------
# Converged at step 4:
#
# k = 4.324289461360293
# ----------------------
#
# Calculating eig number 3
#
# ----------------------
# Converged at step 4:
#
# k = 4.324289461360285
# ----------------------
#
# Calculating eig number 4
#
# ----------------------
# Converged at step 3:
#
# k = 4.324289461360287
# ----------------------
#
# Calculating eig number 5
#
# ----------------------
# Converged at step 3:
#
# k = 4.32428946136029
# ----------------------
#
# Calculating eig number 6
#
# ----------------------
# Converged at step 3:
#
# k = 4.324289461360291
# ----------------------
#
# Calculating eig number 7
#
# ----------------------
# Converged at step 3:
#
# k = 4.324289461360288
# ----------------------
#
# Calculating eig number 8
#
# ----------------------
# Converged at step 4:
#
# k = 4.324289461360287
# ----------------------
#
# Calculating eig number 9
#
# ----------------------
# Converged at step 4:
#
# k = 4.324289461360291
# ----------------------
#
# Calculating eig number 10
#
# ----------------------
# Converged at step 5:
#
# k = 4.32428946136029
# ----------------------
#
# Calculating eig number 11
#
# ----------------------
# Converged at step 5:
#
# k = 4.324289461360287
# ----------------------
#
# Calculating eig number 12
#
# ----------------------
# Converged at step 5:
#
# k = 4.324289461360284
# ----------------------
#
# Calculating eig number 13
#
# ----------------------
# Converged at step 5:
#
# k = 4.324289461360288
# ----------------------
#
# Calculating eig number 14
#
# ----------------------
# Converged at step 5:
#
# k = 4.32428946136029
# ----------------------
#
# Calculating eig number 15
#
# ----------------------
# Converged at step 5:
#
# k = 4.324289461360293
# ----------------------
#
# Calculating eig number 16
#
# ----------------------
# Converged at step 5:
#
# k = 4.324289461360295
# ----------------------
#
# Calculating eig number 17
#
# ----------------------
# Converged at step 5:
#
# k = 4.324289461360291
# ----------------------
#
# Calculating eig number 18
#
# ----------------------
# Converged at step 5:
#
# k = 4.324289461360291
# ----------------------
#
# Calculating eig number 19
#
# ----------------------
# Converged at step 5:
#
# k = 4.324289461360295
# ----------------------
#
# Calculating eig number 20
#
# ----------------------
# Converged at step 5:
#
# k = 4.324289461360289
# ----------------------
#
# Calculating eig number 21
#
# ----------------------
# Converged at step 5:
#
# k = 4.3242894613603005
# ----------------------
#
# Calculating eig number 22
#
# ----------------------
# Converged at step 5:
#
# k = 4.324289461360286
# ----------------------
#
# Calculating eig number 23
#
# ----------------------
# Converged at step 5:
#
# k = 4.324289461360293
# ----------------------
#
# Calculating eig number 24
#
# ----------------------
# Converged at step 5:
#
# k = 4.324289461360295
# ----------------------
#
# Calculating eig number 25
#
# ----------------------
# Converged at step 6:
#
# k = 4.324289461360295
# ----------------------
#
# Calculating eig number 26
#
# ----------------------
# Converged at step 6:
#
# k = 4.324289461360287
# ----------------------
#
# Calculating eig number 27
#
# ----------------------
# Converged at step 6:
#
# k = 4.3242894613602845
# ----------------------
#
# Calculating eig number 28
#
# ----------------------
# Converged at step 4:
#
# k = 6.157888998703045
# ----------------------
#
# Calculating eig number 29
#
# ----------------------
# Converged at step 4:
#
# k = 6.157888998703043
# ----------------------
#
# Calculating eig number 30
#
# ----------------------
# Converged at step 4:
#
# k = 6.157888998703042
# ----------------------
#
# Calculating eig number 31
#
# ----------------------
# Converged at step 4:
#
# k = 6.157888998703043
# ----------------------
#
# Calculating eig number 32
#
# ----------------------
# Converged at step 4:
#
# k = 6.1578889987030445
# ----------------------
#
# Calculating eig number 33
#
# ----------------------
# Converged at step 4:
#
# k = 6.157888998703039
# ----------------------
#
# Calculating eig number 34
#
# ----------------------
# Converged at step 4:
#
# k = 6.157888998703041
# ----------------------
#
# Calculating eig number 35
#
# ----------------------
# Converged at step 4:
#
# k = 6.157888998703041
# ----------------------
#
# Calculating eig number 36
#
# ----------------------
# Converged at step 4:
#
# k = 6.157888998703042
# ----------------------
#
# Calculating eig number 37
#
# ----------------------
# Converged at step 4:
#
# k = 6.15788899870304
# ----------------------
#
# Calculating eig number 38
#
# ----------------------
# Converged at step 3:
#
# k = 6.157888998703045
# ----------------------
#
# Calculating eig number 39
#
# ----------------------
# Converged at step 3:
#
# k = 6.157888998703047
# ----------------------
#
# Calculating eig number 40
#
# ----------------------
# Converged at step 3:
#
# k = 6.157888998703044
# ----------------------
#
# Calculating eig number 41
#
# ----------------------
# Converged at step 3:
#
# k = 6.157888998703038
# ----------------------
#
# Calculating eig number 42
#
# ----------------------
# Converged at step 3:
#
# k = 6.157888998703042
# ----------------------
#
# Calculating eig number 43
#
# ----------------------
# Converged at step 3:
#
# k = 6.157888998703041
# ----------------------
#
# Calculating eig number 44
#
# ----------------------
# Converged at step 3:
#
# k = 6.157888998703042
# ----------------------
#
# Calculating eig number 45
#
# ----------------------
# Converged at step 4:
#
# k = 6.1578889987030445
# ----------------------
#
# Calculating eig number 46
#
# ----------------------
# Converged at step 4:
#
# k = 6.1578889987030445
# ----------------------
#
# Calculating eig number 47
#
# ----------------------
# Converged at step 4:
#
# k = 6.157888998703045
# ----------------------
#
# Calculating eig number 48
#
# ----------------------
# Converged at step 5:
#
# k = 6.157888998703041
# ----------------------
#
# Calculating eig number 49
#
# ----------------------
# Converged at step 5:
#
# k = 6.157888998703042
# ----------------------
#
# Calculating eig number 50
#
# ----------------------
# Converged at step 5:
#
# k = 6.157888998703039
# ----------------------
#
# Calculating eig number 51
#
# ----------------------
# Converged at step 5:
#
# k = 6.157888998703045
# ----------------------
#
# Calculating eig number 52
#
# ----------------------
# Converged at step 5:
#
# k = 6.15788899870304
# ----------------------
#
# Calculating eig number 53
#
# ----------------------
# Converged at step 5:
#
# k = 6.157888998703045
# ----------------------
#
# Calculating eig number 54
#
# ----------------------
# Converged at step 5:
#
# k = 6.157888998703044
# ----------------------
#
# Calculating eig number 55
#
# ----------------------
# Converged at step 5:
#
# k = 6.1578889987030445
# ----------------------
#
# Calculating eig number 56
#
# ----------------------
# Converged at step 5:
#
# k = 6.157888998703039
# ----------------------
#
# Calculating eig number 57
#
# ----------------------
# Converged at step 5:
#
# k = 6.157888998703043
# ----------------------
#
# Calculating eig number 58
#
# ----------------------
# Converged at step 5:
#
# k = 6.157888998703042
# ----------------------
#
# Calculating eig number 59
#
# ----------------------
# Converged at step 5:
#
# k = 6.157888998703043
# ----------------------
#
# Calculating eig number 60
#
# ----------------------
# Converged at step 5:
#
# k = 6.157888998703039
# ----------------------
#
# Calculating eig number 61
#
# ----------------------
# Converged at step 5:
#
# k = 6.157888998703038
# ----------------------
#
# Calculating eig number 62
#
# ----------------------
# Converged at step 5:
#
# k = 6.157888998703047
# ----------------------
#
# Calculating eig number 63
#
# ----------------------
# Converged at step 5:
#
# k = 6.15788899870304
# ----------------------
#
# Calculating eig number 64
#
# ----------------------
# Converged at step 4:
#
# k = 8.042160420721038
# ----------------------
#
# Calculating eig number 65
#
# ----------------------
# Converged at step 4:
#
# k = 8.042160420721034
# ----------------------
#
# Calculating eig number 66
#
# ----------------------
# Converged at step 4:
#
# k = 8.042160420721036
# ----------------------
#
# Calculating eig number 67
#
# ----------------------
# Converged at step 4:
#
# k = 8.042160420721038
# ----------------------
#
# Calculating eig number 68
#
# ----------------------
# Converged at step 4:
#
# k = 8.042160420721036
# ----------------------
#
# Calculating eig number 69
#
# ----------------------
# Converged at step 4:
#
# k = 8.042160420721036
# ----------------------
#
# Calculating eig number 70
#
# ----------------------
# Converged at step 4:
#
# k = 8.042160420721038
# ----------------------
#
# Calculating eig number 71
#
# ----------------------
# Converged at step 4:
#
# k = 8.042160420721038
# ----------------------
#
# Calculating eig number 72
#
# ----------------------
# Converged at step 4:
#
# k = 8.042160420721034
# ----------------------
#
# Calculating eig number 73
#
# ----------------------
# Converged at step 4:
#
# k = 8.042160420721038
# ----------------------
#
# Calculating eig number 74
#
# ----------------------
# Converged at step 3:
#
# k = 8.042160420721038
# ----------------------
#
# Calculating eig number 75
#
# ----------------------
# Converged at step 3:
#
# k = 8.042160420721038
# ----------------------
#
# Calculating eig number 76
#
# ----------------------
# Converged at step 3:
#
# k = 8.04216042072104
# ----------------------
#
# Calculating eig number 77
#
# ----------------------
# Converged at step 3:
#
# k = 8.042160420721038
# ----------------------
#
# Calculating eig number 78
#
# ----------------------
# Converged at step 3:
#
# k = 8.042160420721038
# ----------------------
#
# Calculating eig number 79
#
# ----------------------
# Converged at step 3:
#
# k = 8.042160420721036
# ----------------------
#
# Calculating eig number 80
#
# ----------------------
# Converged at step 3:
#
# k = 8.042160420721038
# ----------------------
#
# Calculating eig number 81
#
# ----------------------
# Converged at step 3:
#
# k = 8.042160420721038
# ----------------------
#
# Calculating eig number 82
#
# ----------------------
# Converged at step 4:
#
# k = 8.042160420721038
# ----------------------
#
# Calculating eig number 83
#
# ----------------------
# Converged at step 4:
#
# k = 8.042160420721038
# ----------------------
#
# Calculating eig number 84
#
# ----------------------
# Converged at step 4:
#
# k = 8.04216042072104
# ----------------------
#
# Calculating eig number 85
#
# ----------------------
# Converged at step 4:
#
# k = 8.042160420721034
# ----------------------
#
# Calculating eig number 86
#
# ----------------------
# Converged at step 5:
#
# k = 8.042160420721038
# ----------------------
#
# Calculating eig number 87
#
# ----------------------
# Converged at step 5:
#
# k = 8.042160420721038
# ----------------------
#
# Calculating eig number 88
#
# ----------------------
# Converged at step 5:
#
# k = 8.042160420721036
# ----------------------
#
# Calculating eig number 89
#
# ----------------------
# Converged at step 5:
#
# k = 8.042160420721036
# ----------------------
#
# Calculating eig number 90
#
# ----------------------
# Converged at step 5:
#
# k = 8.042160420721038
# ----------------------
#
# Calculating eig number 91
#
# ----------------------
# Converged at step 5:
#
# k = 8.042160420721034
# ----------------------
#
# Calculating eig number 92
#
# ----------------------
# Converged at step 5:
#
# k = 8.042160420721036
# ----------------------
#
# Calculating eig number 93
#
# ----------------------
# Converged at step 5:
#
# k = 8.042160420721038
# ----------------------
#
# Calculating eig number 94
#
# ----------------------
# Converged at step 5:
#
# k = 8.042160420721038
# ----------------------
#
# Calculating eig number 95
#
# ----------------------
# Converged at step 4:
#
# k = 9.29197927342722
# ----------------------
#
# Calculating eig number 96
#
# ----------------------
# Converged at step 4:
#
# k = 9.291979273427218
# ----------------------
#
# Calculating eig number 97
#
# ----------------------
# Converged at step 3:
#
# k = 9.29197927342722
# ----------------------
#
# Calculating eig number 98
#
# ----------------------
# Converged at step 3:
#
# k = 9.291979273427218
# ----------------------
#
# Calculating eig number 99
#
# ----------------------
# Converged at step 3:
#
# k = 9.291979273427216
# ----------------------
#
# Calculating eig number 100
#
# ----------------------
# Converged at step 3:
#
# k = 9.291979273427213
# ----------------------
#
# Calculating eig number 101
#
# ----------------------
# Converged at step 3:
#
# k = 9.291979273427216
# ----------------------
#
# Calculating eig number 102
#
# ----------------------
# Converged at step 3:
#
# k = 9.291979273427218
# ----------------------
#
# Calculating eig number 103
#
# ----------------------
# Converged at step 3:
#
# k = 9.291979273427218
# ----------------------
#
# Calculating eig number 104
#
# ----------------------
# Converged at step 3:
#
# k = 9.29197927342722
# ----------------------
#
# Calculating eig number 105
#
# ----------------------
# Converged at step 3:
#
# k = 9.291979273427218
# ----------------------
#
# Calculating eig number 106
#
# ----------------------
# Converged at step 3:
#
# k = 9.29197927342722
# ----------------------
#
# Calculating eig number 107
#
# ----------------------
# Converged at step 4:
#
# k = 9.291979273427216
# ----------------------
#
# Calculating eig number 108
#
# ----------------------
# Converged at step 4:
#
# k = 9.291979273427218
# ----------------------
#
# Calculating eig number 109
#
# ----------------------
# Converged at step 4:
#
# k = 9.291979273427218
# ----------------------
#
# Calculating eig number 110
#
# ----------------------
# Converged at step 4:
#
# k = 9.29197927342722
# ----------------------
#
# Calculating eig number 111
#
# ----------------------
# Converged at step 4:
#
# k = 9.291979273427218
# ----------------------
#
# Calculating eig number 112
#
# ----------------------
# Converged at step 5:
#
# k = 9.29197927342722
# ----------------------
#
# Calculating eig number 113
#
# ----------------------
# Converged at step 5:
#
# k = 9.291979273427218
# ----------------------
#
# Calculating eig number 114
#
# ----------------------
# Converged at step 5:
#
# k = 9.291979273427218
# ----------------------
#
# Calculating eig number 115
#
# ----------------------
# Converged at step 5:
#
# k = 9.291979273427218
# ----------------------
#
# Calculating eig number 116
#
# ----------------------
# Converged at step 5:
#
# k = 9.291979273427218
# ----------------------
#
# Calculating eig number 117
#
# ----------------------
# Converged at step 5:
#
# k = 9.291979273427216
# ----------------------
#
# Calculating eig number 118
#
# ----------------------
# Converged at step 5:
#
# k = 9.291979273427218
# ----------------------
#
# Calculating eig number 119
#
# ----------------------
# Converged at step 5:
#
# k = 9.291979273427218
# ----------------------
#
# Calculating eig number 120
#
# ----------------------
# Converged at step 5:
#
# k = 9.291979273427218
# ----------------------
#
# Calculating eig number 121
#
# ----------------------
# Converged at step 5:
#
# k = 9.29197927342722
# ----------------------
#
# Calculating eig number 122
#
# ----------------------
# Converged at step 5:
#
# k = 9.291979273427218
# ----------------------
#
# Calculating eig number 123
#
# ----------------------
# Converged at step 5:
#
# k = 9.291979273427215
# ----------------------
#
# Calculating eig number 124
#
# ----------------------
# Converged at step 5:
#
# k = 9.291979273427218
# ----------------------
#
# Calculating eig number 125
#
# ----------------------
# Converged at step 5:
#
# k = 9.29197927342722
# ----------------------
#
# Calculating eig number 126
#
# ----------------------
# Converged at step 5:
#
# k = 9.291979273427218
# ----------------------
#
# Calculating eig number 127
#
# ----------------------
# Converged at step 5:
#
# k = 9.291979273427218
# ----------------------
#
# Calculating eig number 128
#
# ----------------------
# Converged at step 5:
#
# k = 9.291979273427218
# ----------------------
#
# Calculating eig number 129
#
# ----------------------
# Converged at step 5:
#
# k = 9.29197927342722
# ----------------------
#
# Calculating eig number 130
#
# ----------------------
# Converged at step 5:
#
# k = 9.291979273427216
# ----------------------
#
# Calculating eig number 131
#
# ----------------------
# Converged at step 5:
#
# k = 9.291979273427218
# ----------------------
#
# Calculating eig number 132
#
# ----------------------
# Converged at step 5:
#
# k = 9.29197927342722
# ----------------------
#
# Calculating eig number 133
#
# ----------------------
# Converged at step 5:
#
# k = 9.29197927342722
# ----------------------
#
# Calculating eig number 134
#
# ----------------------
# Converged at step 5:
#
# k = 9.291979273427218
# ----------------------
#
# Calculating eig number 135
#
# ----------------------
# Converged at step 5:
#
# k = 9.291979273427218
# ----------------------
#
# Calculating eig number 136
#
# ----------------------
# Converged at step 4:
#
# k = 12.08480037686589
# ----------------------
#
# Calculating eig number 137
#
# ----------------------
# Converged at step 4:
#
# k = 12.08480037686589
# ----------------------
#
# Calculating eig number 138
#
# ----------------------
# Converged at step 4:
#
# k = 12.08480037686589
# ----------------------
#
# Calculating eig number 139
#
# ----------------------
# Converged at step 4:
#
# k = 12.08480037686589
# ----------------------
#
# Calculating eig number 140
#
# ----------------------
# Converged at step 4:
#
# k = 12.08480037686589
# ----------------------
#
# Calculating eig number 141
#
# ----------------------
# Converged at step 4:
#
# k = 12.084800376865891
# ----------------------
#
# Calculating eig number 142
#
# ----------------------
# Converged at step 4:
#
# k = 12.084800376865891
# ----------------------
#
# Calculating eig number 143
#
# ----------------------
# Converged at step 4:
#
# k = 12.08480037686589
# ----------------------
#
# Calculating eig number 144
#
# ----------------------
# Converged at step 4:
#
# k = 12.08480037686589
# ----------------------
#
# Calculating eig number 145
#
# ----------------------
# Converged at step 4:
#
# k = 12.08480037686589
# ----------------------
#
# Calculating eig number 146
#
# ----------------------
# Converged at step 4:
#
# k = 12.08480037686589
# ----------------------
#
# Calculating eig number 147
#
# ----------------------
# Converged at step 4:
#
# k = 12.084800376865891
# ----------------------
#
# Calculating eig number 148
#
# ----------------------
# Converged at step 3:
#
# k = 12.084800376865891
# ----------------------
#
# Calculating eig number 149
#
# ----------------------
# Converged at step 3:
#
# k = 12.084800376865891
# ----------------------
#
# Calculating eig number 150
#
# ----------------------
# Converged at step 3:
#
# k = 12.084800376865894
# ----------------------
#
# Calculating eig number 151
#
# ----------------------
# Converged at step 3:
#
# k = 12.084800376865891
# ----------------------
#
# Calculating eig number 152
#
# ----------------------
# Converged at step 3:
#
# k = 12.084800376865893
# ----------------------
#
# Calculating eig number 153
#
# ----------------------
# Converged at step 3:
#
# k = 12.084800376865891
# ----------------------
#
# Calculating eig number 154
#
# ----------------------
# Converged at step 3:
#
# k = 12.084800376865891
# ----------------------
#
# Calculating eig number 155
#
# ----------------------
# Converged at step 3:
#
# k = 12.084800376865893
# ----------------------
#
# Calculating eig number 156
#
# ----------------------
# Converged at step 3:
#
# k = 12.084800376865891
# ----------------------
#
# Calculating eig number 157
#
# ----------------------
# Converged at step 3:
#
# k = 12.08480037686589
# ----------------------
#
# Calculating eig number 158
#
# ----------------------
# Converged at step 3:
#
# k = 12.08480037686589
# ----------------------
#
# Calculating eig number 159
#
# ----------------------
# Converged at step 3:
#
# k = 12.08480037686589
# ----------------------
#
# Calculating eig number 160
#
# ----------------------
# Converged at step 3:
#
# k = 12.08480037686589
# ----------------------
#
# Calculating eig number 161
#
# ----------------------
# Converged at step 3:
#
# k = 12.08480037686589
# ----------------------
#
# Calculating eig number 162
#
# ----------------------
# Converged at step 3:
#
# k = 12.084800376865891
# ----------------------
#
# Calculating eig number 163
#
# ----------------------
# Converged at step 4:
#
# k = 12.08480037686589
# ----------------------
#
# Calculating eig number 164
#
# ----------------------
# Converged at step 4:
#
# k = 12.08480037686589
# ----------------------
#
# Calculating eig number 165
#
# ----------------------
# Converged at step 4:
#
# k = 12.08480037686589
# ----------------------
#
# Calculating eig number 166
#
# ----------------------
# Converged at step 4:
#
# k = 12.084800376865893
# ----------------------
#
# Calculating eig number 167
#
# ----------------------
# Converged at step 4:
#
# k = 12.08480037686589
# ----------------------
#
# Calculating eig number 168
#
# ----------------------
# Converged at step 4:
#
# k = 12.084800376865893
# ----------------------
#
# Calculating eig number 169
#
# ----------------------
# Converged at step 4:
#
# k = 12.084800376865891
# ----------------------
#
# Calculating eig number 170
#
# ----------------------
# Converged at step 4:
#
# k = 12.084800376865891
# ----------------------
#
# Calculating eig number 171
#
# ----------------------
# Converged at step 5:
#
# k = 12.08480037686589
# ----------------------
#
# Calculating eig number 172
#
# ----------------------
# Converged at step 5:
#
# k = 12.08480037686589
# ----------------------
#
# Calculating eig number 173
#
# ----------------------
# Converged at step 5:
#
# k = 12.084800376865891
# ----------------------
#
# Calculating eig number 174
#
# ----------------------
# Converged at step 5:
#
# k = 12.084800376865891
# ----------------------
#
# Calculating eig number 175
#
# ----------------------
# Converged at step 5:
#
# k = 12.08480037686589
# ----------------------
#
# Calculating eig number 176
#
# ----------------------
# Converged at step 5:
#
# k = 12.08480037686589
# ----------------------
#
# Calculating eig number 177
#
# ----------------------
# Converged at step 5:
#
# k = 12.08480037686589
# ----------------------
#
# Calculating eig number 178
#
# ----------------------
# Converged at step 5:
#
# k = 12.08480037686589
# ----------------------
#
# Calculating eig number 179
#
# ----------------------
# Converged at step 5:
#
# k = 12.084800376865891
# ----------------------
#
# Calculating eig number 180
#
# ----------------------
# Converged at step 5:
#
# k = 12.084800376865891
# ----------------------
#
# Calculating eig number 181
#
# ----------------------
# Converged at step 5:
#
# k = 12.08480037686589
# ----------------------
#
# Calculating eig number 182
#
# ----------------------
# Converged at step 5:
#
# k = 12.084800376865891
# ----------------------
#
# Calculating eig number 183
#
# ----------------------
# Converged at step 5:
#
# k = 12.08480037686589
# ----------------------
#
# Calculating eig number 184
#
# ----------------------
# Converged at step 5:
#
# k = 12.08480037686589
# ----------------------
#
# Calculating eig number 185
#
# ----------------------
# Converged at step 5:
#
# k = 12.08480037686589
# ----------------------
#
# Calculating eig number 186
#
# ----------------------
# Converged at step 5:
#
# k = 12.084800376865891
# ----------------------
#
# Calculating eig number 187
#
# ----------------------
# Converged at step 5:
#
# k = 12.084800376865891
# ----------------------
#
# Calculating eig number 188
#
# ----------------------
# Converged at step 5:
#
# k = 12.084800376865891
# ----------------------
#
# Calculating eig number 189
#
# ----------------------
# Converged at step 5:
#
# k = 12.084800376865891
# ----------------------
#
# Calculating eig number 190
#
# ----------------------
# Converged at step 5:
#
# k = 12.08480037686589
# ----------------------
#
# Calculating eig number 191
#
# ----------------------
# Converged at step 5:
#
# k = 12.08480037686589
# ----------------------
#
# Calculating eig number 192
#
# ----------------------
# Converged at step 5:
#
# k = 12.08480037686589
# ----------------------
#
# Calculating eig number 193
#
# ----------------------
# Converged at step 5:
#
# k = 12.08480037686589
# ----------------------
#
# Calculating eig number 194
#
# ----------------------
# Converged at step 5:
#
# k = 12.084800376865891
# ----------------------
#
# Calculating eig number 195
#
# ----------------------
# Converged at step 4:
#
# k = 15.274309541898486
# ----------------------
#
# Calculating eig number 196
#
# ----------------------
# Converged at step 4:
#
# k = 15.274309541898486
# ----------------------
#
# Calculating eig number 197
#
# ----------------------
# Converged at step 4:
#
# k = 15.274309541898486
# ----------------------
#
# Calculating eig number 198
#
# ----------------------
# Converged at step 4:
#
# k = 15.274309541898486
# ----------------------
#
# Calculating eig number 199
#
# ----------------------
# Converged at step 4:
#
# k = 15.274309541898486
# ----------------------
#
# Calculating eig number 200
#
# ----------------------
# Converged at step 4:
#
# k = 15.274309541898486
# ----------------------
# num_Vs = 144
#
#
#
#
#
# Calculating eig number 0
#
# ----------------------
# Converged at step 0:
#
# k = 9.793412905149268e-16
# ----------------------
#
# Calculating eig number 1
#
# ----------------------
# Converged at step 4:
#
# k = 4.342498675612405
# ----------------------
#
# Calculating eig number 2
#
# ----------------------
# Converged at step 4:
#
# k = 4.342498675612404
# ----------------------
#
# Calculating eig number 3
#
# ----------------------
# Converged at step 4:
#
# k = 4.34249867561241
# ----------------------
#
# Calculating eig number 4
#
# ----------------------
# Converged at step 3:
#
# k = 4.342498675612416
# ----------------------
#
# Calculating eig number 5
#
# ----------------------
# Converged at step 3:
#
# k = 4.342498675612412
# ----------------------
#
# Calculating eig number 6
#
# ----------------------
# Converged at step 3:
#
# k = 4.342498675612402
# ----------------------
#
# Calculating eig number 7
#
# ----------------------
# Converged at step 3:
#
# k = 4.342498675612401
# ----------------------
#
# Calculating eig number 8
#
# ----------------------
# Converged at step 4:
#
# k = 4.3424986756124015
# ----------------------
#
# Calculating eig number 9
#
# ----------------------
# Converged at step 4:
#
# k = 4.342498675612405
# ----------------------
#
# Calculating eig number 10
#
# ----------------------
# Converged at step 4:
#
# k = 4.342498675612402
# ----------------------
#
# Calculating eig number 11
#
# ----------------------
# Converged at step 5:
#
# k = 4.342498675612399
# ----------------------
#
# Calculating eig number 12
#
# ----------------------
# Converged at step 5:
#
# k = 4.342498675612405
# ----------------------
#
# Calculating eig number 13
#
# ----------------------
# Converged at step 5:
#
# k = 4.342498675612403
# ----------------------
#
# Calculating eig number 14
#
# ----------------------
# Converged at step 5:
#
# k = 4.342498675612395
# ----------------------
#
# Calculating eig number 15
#
# ----------------------
# Converged at step 5:
#
# k = 4.34249867561241
# ----------------------
#
# Calculating eig number 16
#
# ----------------------
# Converged at step 5:
#
# k = 4.342498675612406
# ----------------------
#
# Calculating eig number 17
#
# ----------------------
# Converged at step 5:
#
# k = 4.342498675612414
# ----------------------
#
# Calculating eig number 18
#
# ----------------------
# Converged at step 5:
#
# k = 4.342498675612402
# ----------------------
#
# Calculating eig number 19
#
# ----------------------
# Converged at step 5:
#
# k = 4.3424986756124
# ----------------------
#
# Calculating eig number 20
#
# ----------------------
# Converged at step 5:
#
# k = 4.342498675612414
# ----------------------
#
# Calculating eig number 21
#
# ----------------------
# Converged at step 5:
#
# k = 4.3424986756124095
# ----------------------
#
# Calculating eig number 22
#
# ----------------------
# Converged at step 5:
#
# k = 4.342498675612407
# ----------------------
#
# Calculating eig number 23
#
# ----------------------
# Converged at step 5:
#
# k = 4.342498675612402
# ----------------------
#
# Calculating eig number 24
#
# ----------------------
# Converged at step 5:
#
# k = 4.342498675612409
# ----------------------
#
# Calculating eig number 25
#
# ----------------------
# Converged at step 6:
#
# k = 4.342498675612409
# ----------------------
#
# Calculating eig number 26
#
# ----------------------
# Converged at step 6:
#
# k = 4.342498675612408
# ----------------------
#
# Calculating eig number 27
#
# ----------------------
# Converged at step 6:
#
# k = 4.3424986756124015
# ----------------------
#
# Calculating eig number 28
#
# ----------------------
# Converged at step 4:
#
# k = 6.168708858290741
# ----------------------
#
# Calculating eig number 29
#
# ----------------------
# Converged at step 4:
#
# k = 6.168708858290746
# ----------------------
#
# Calculating eig number 30
#
# ----------------------
# Converged at step 4:
#
# k = 6.168708858290743
# ----------------------
#
# Calculating eig number 31
#
# ----------------------
# Converged at step 4:
#
# k = 6.168708858290744
# ----------------------
#
# Calculating eig number 32
#
# ----------------------
# Converged at step 4:
#
# k = 6.16870885829075
# ----------------------
#
# Calculating eig number 33
#
# ----------------------
# Converged at step 4:
#
# k = 6.168708858290741
# ----------------------
#
# Calculating eig number 34
#
# ----------------------
# Converged at step 4:
#
# k = 6.168708858290741
# ----------------------
#
# Calculating eig number 35
#
# ----------------------
# Converged at step 4:
#
# k = 6.168708858290741
# ----------------------
#
# Calculating eig number 36
#
# ----------------------
# Converged at step 4:
#
# k = 6.168708858290743
# ----------------------
#
# Calculating eig number 37
#
# ----------------------
# Converged at step 4:
#
# k = 6.168708858290744
# ----------------------
#
# Calculating eig number 38
#
# ----------------------
# Converged at step 4:
#
# k = 6.168708858290744
# ----------------------
#
# Calculating eig number 39
#
# ----------------------
# Converged at step 3:
#
# k = 6.168708858290748
# ----------------------
#
# Calculating eig number 40
#
# ----------------------
# Converged at step 3:
#
# k = 6.168708858290743
# ----------------------
#
# Calculating eig number 41
#
# ----------------------
# Converged at step 3:
#
# k = 6.168708858290749
# ----------------------
#
# Calculating eig number 42
#
# ----------------------
# Converged at step 3:
#
# k = 6.168708858290751
# ----------------------
#
# Calculating eig number 43
#
# ----------------------
# Converged at step 3:
#
# k = 6.1687088582907545
# ----------------------
#
# Calculating eig number 44
#
# ----------------------
# Converged at step 3:
#
# k = 6.1687088582907466
# ----------------------
#
# Calculating eig number 45
#
# ----------------------
# Converged at step 4:
#
# k = 6.168708858290753
# ----------------------
#
# Calculating eig number 46
#
# ----------------------
# Converged at step 4:
#
# k = 6.168708858290753
# ----------------------
#
# Calculating eig number 47
#
# ----------------------
# Converged at step 4:
#
# k = 6.168708858290751
# ----------------------
#
# Calculating eig number 48
#
# ----------------------
# Converged at step 5:
#
# k = 6.168708858290743
# ----------------------
#
# Calculating eig number 49
#
# ----------------------
# Converged at step 5:
#
# k = 6.16870885829075
# ----------------------
#
# Calculating eig number 50
#
# ----------------------
# Converged at step 5:
#
# k = 6.16870885829075
# ----------------------
#
# Calculating eig number 51
#
# ----------------------
# Converged at step 5:
#
# k = 6.16870885829075
# ----------------------
#
# Calculating eig number 52
#
# ----------------------
# Converged at step 5:
#
# k = 6.1687088582907466
# ----------------------
#
# Calculating eig number 53
#
# ----------------------
# Converged at step 5:
#
# k = 6.168708858290745
# ----------------------
#
# Calculating eig number 54
#
# ----------------------
# Converged at step 5:
#
# k = 6.168708858290744
# ----------------------
#
# Calculating eig number 55
#
# ----------------------
# Converged at step 5:
#
# k = 6.168708858290754
# ----------------------
#
# Calculating eig number 56
#
# ----------------------
# Converged at step 5:
#
# k = 6.168708858290745
# ----------------------
#
# Calculating eig number 57
#
# ----------------------
# Converged at step 5:
#
# k = 6.168708858290741
# ----------------------
#
# Calculating eig number 58
#
# ----------------------
# Converged at step 5:
#
# k = 6.168708858290742
# ----------------------
#
# Calculating eig number 59
#
# ----------------------
# Converged at step 5:
#
# k = 6.168708858290746
# ----------------------
#
# Calculating eig number 60
#
# ----------------------
# Converged at step 5:
#
# k = 6.168708858290754
# ----------------------
#
# Calculating eig number 61
#
# ----------------------
# Converged at step 5:
#
# k = 6.168708858290753
# ----------------------
#
# Calculating eig number 62
#
# ----------------------
# Converged at step 5:
#
# k = 6.168708858290748
# ----------------------
#
# Calculating eig number 63
#
# ----------------------
# Converged at step 5:
#
# k = 6.168708858290756
# ----------------------
#
# Calculating eig number 64
#
# ----------------------
# Converged at step 5:
#
# k = 6.168708858290743
# ----------------------
#
# Calculating eig number 65
#
# ----------------------
# Converged at step 5:
#
# k = 6.168708858290744
# ----------------------
#
# Calculating eig number 66
#
# ----------------------
# Converged at step 5:
#
# k = 6.168708858290744
# ----------------------
#
# Calculating eig number 67
#
# ----------------------
# Converged at step 5:
#
# k = 6.16870885829075
# ----------------------
#
# Calculating eig number 68
#
# ----------------------
# Converged at step 4:
#
# k = 8.359529068901452
# ----------------------
#
# Calculating eig number 69
#
# ----------------------
# Converged at step 4:
#
# k = 8.359529068901454
# ----------------------
#
# Calculating eig number 70
#
# ----------------------
# Converged at step 4:
#
# k = 8.359529068901452
# ----------------------
#
# Calculating eig number 71
#
# ----------------------
# Converged at step 4:
#
# k = 8.359529068901452
# ----------------------
#
# Calculating eig number 72
#
# ----------------------
# Converged at step 4:
#
# k = 8.359529068901448
# ----------------------
#
# Calculating eig number 73
#
# ----------------------
# Converged at step 4:
#
# k = 8.359529068901452
# ----------------------
#
# Calculating eig number 74
#
# ----------------------
# Converged at step 4:
#
# k = 8.359529068901452
# ----------------------
#
# Calculating eig number 75
#
# ----------------------
# Converged at step 4:
#
# k = 8.359529068901455
# ----------------------
#
# Calculating eig number 76
#
# ----------------------
# Converged at step 4:
#
# k = 8.359529068901454
# ----------------------
#
# Calculating eig number 77
#
# ----------------------
# Converged at step 4:
#
# k = 8.359529068901452
# ----------------------
#
# Calculating eig number 78
#
# ----------------------
# Converged at step 4:
#
# k = 8.359529068901448
# ----------------------
#
# Calculating eig number 79
#
# ----------------------
# Converged at step 4:
#
# k = 8.359529068901454
# ----------------------
#
# Calculating eig number 80
#
# ----------------------
# Converged at step 3:
#
# k = 8.359529068901455
# ----------------------
#
# Calculating eig number 81
#
# ----------------------
# Converged at step 3:
#
# k = 8.359529068901457
# ----------------------
#
# Calculating eig number 82
#
# ----------------------
# Converged at step 3:
#
# k = 8.35952906890145
# ----------------------
#
# Calculating eig number 83
#
# ----------------------
# Converged at step 3:
#
# k = 8.359529068901454
# ----------------------
#
# Calculating eig number 84
#
# ----------------------
# Converged at step 3:
#
# k = 8.359529068901455
# ----------------------
#
# Calculating eig number 85
#
# ----------------------
# Converged at step 3:
#
# k = 8.359529068901448
# ----------------------
#
# Calculating eig number 86
#
# ----------------------
# Converged at step 3:
#
# k = 8.359529068901452
# ----------------------
#
# Calculating eig number 87
#
# ----------------------
# Converged at step 3:
#
# k = 8.359529068901454
# ----------------------
#
# Calculating eig number 88
#
# ----------------------
# Converged at step 4:
#
# k = 8.359529068901448
# ----------------------
#
# Calculating eig number 89
#
# ----------------------
# Converged at step 4:
#
# k = 8.359529068901452
# ----------------------
#
# Calculating eig number 90
#
# ----------------------
# Converged at step 4:
#
# k = 8.359529068901457
# ----------------------
#
# Calculating eig number 91
#
# ----------------------
# Converged at step 4:
#
# k = 8.359529068901454
# ----------------------
#
# Calculating eig number 92
#
# ----------------------
# Converged at step 5:
#
# k = 8.359529068901452
# ----------------------
#
# Calculating eig number 93
#
# ----------------------
# Converged at step 5:
#
# k = 8.359529068901454
# ----------------------
#
# Calculating eig number 94
#
# ----------------------
# Converged at step 5:
#
# k = 8.359529068901448
# ----------------------
#
# Calculating eig number 95
#
# ----------------------
# Converged at step 5:
#
# k = 8.359529068901452
# ----------------------
#
# Calculating eig number 96
#
# ----------------------
# Converged at step 5:
#
# k = 8.359529068901448
# ----------------------
#
# Calculating eig number 97
#
# ----------------------
# Converged at step 5:
#
# k = 8.359529068901448
# ----------------------
#
# Calculating eig number 98
#
# ----------------------
# Converged at step 5:
#
# k = 8.359529068901454
# ----------------------
#
# Calculating eig number 99
#
# ----------------------
# Converged at step 5:
#
# k = 8.359529068901454
# ----------------------
#
# Calculating eig number 100
#
# ----------------------
# Converged at step 4:
#
# k = 9.512125664084063
# ----------------------
#
# Calculating eig number 101
#
# ----------------------
# Converged at step 4:
#
# k = 9.51212566408406
# ----------------------
#
# Calculating eig number 102
#
# ----------------------
# Converged at step 3:
#
# k = 9.51212566408406
# ----------------------
#
# Calculating eig number 103
#
# ----------------------
# Converged at step 3:
#
# k = 9.512125664084062
# ----------------------
#
# Calculating eig number 104
#
# ----------------------
# Converged at step 3:
#
# k = 9.512125664084058
# ----------------------
#
# Calculating eig number 105
#
# ----------------------
# Converged at step 3:
#
# k = 9.51212566408406
# ----------------------
#
# Calculating eig number 106
#
# ----------------------
# Converged at step 3:
#
# k = 9.51212566408406
# ----------------------
#
# Calculating eig number 107
#
# ----------------------
# Converged at step 3:
#
# k = 9.51212566408406
# ----------------------
#
# Calculating eig number 108
#
# ----------------------
# Converged at step 3:
#
# k = 9.51212566408406
# ----------------------
#
# Calculating eig number 109
#
# ----------------------
# Converged at step 3:
#
# k = 9.51212566408406
# ----------------------
#
# Calculating eig number 110
#
# ----------------------
# Converged at step 3:
#
# k = 9.51212566408406
# ----------------------
#
# Calculating eig number 111
#
# ----------------------
# Converged at step 4:
#
# k = 9.512125664084062
# ----------------------
#
# Calculating eig number 112
#
# ----------------------
# Converged at step 4:
#
# k = 9.512125664084063
# ----------------------
#
# Calculating eig number 113
#
# ----------------------
# Converged at step 4:
#
# k = 9.51212566408406
# ----------------------
#
# Calculating eig number 114
#
# ----------------------
# Converged at step 4:
#
# k = 9.51212566408406
# ----------------------
#
# Calculating eig number 115
#
# ----------------------
# Converged at step 4:
#
# k = 9.512125664084062
# ----------------------
#
# Calculating eig number 116
#
# ----------------------
# Converged at step 5:
#
# k = 9.51212566408406
# ----------------------
#
# Calculating eig number 117
#
# ----------------------
# Converged at step 5:
#
# k = 9.512125664084062
# ----------------------
#
# Calculating eig number 118
#
# ----------------------
# Converged at step 5:
#
# k = 9.512125664084063
# ----------------------
#
# Calculating eig number 119
#
# ----------------------
# Converged at step 5:
#
# k = 9.512125664084063
# ----------------------
#
# Calculating eig number 120
#
# ----------------------
# Converged at step 5:
#
# k = 9.51212566408406
# ----------------------
#
# Calculating eig number 121
#
# ----------------------
# Converged at step 5:
#
# k = 9.512125664084063
# ----------------------
#
# Calculating eig number 122
#
# ----------------------
# Converged at step 3:
#
# k = 10.570310427011242
# ----------------------
#
# Calculating eig number 123
#
# ----------------------
# Converged at step 3:
#
# k = 10.570310427011238
# ----------------------
#
# Calculating eig number 124
#
# ----------------------
# Converged at step 3:
#
# k = 10.57031042701124
# ----------------------
#
# Calculating eig number 125
#
# ----------------------
# Converged at step 3:
#
# k = 10.570310427011242
# ----------------------
#
# Calculating eig number 126
#
# ----------------------
# Converged at step 3:
#
# k = 10.57031042701124
# ----------------------
#
# Calculating eig number 127
#
# ----------------------
# Converged at step 3:
#
# k = 10.570310427011242
# ----------------------
#
# Calculating eig number 128
#
# ----------------------
# Converged at step 3:
#
# k = 10.570310427011243
# ----------------------
#
# Calculating eig number 129
#
# ----------------------
# Converged at step 3:
#
# k = 10.570310427011243
# ----------------------
#
# Calculating eig number 130
#
# ----------------------
# Converged at step 3:
#
# k = 10.57031042701124
# ----------------------
#
# Calculating eig number 131
#
# ----------------------
# Converged at step 3:
#
# k = 10.570310427011242
# ----------------------
#
# Calculating eig number 132
#
# ----------------------
# Converged at step 4:
#
# k = 10.570310427011242
# ----------------------
#
# Calculating eig number 133
#
# ----------------------
# Converged at step 4:
#
# k = 10.570310427011242
# ----------------------
#
# Calculating eig number 134
#
# ----------------------
# Converged at step 4:
#
# k = 10.570310427011242
# ----------------------
#
# Calculating eig number 135
#
# ----------------------
# Converged at step 4:
#
# k = 10.570310427011242
# ----------------------
#
# Calculating eig number 136
#
# ----------------------
# Converged at step 4:
#
# k = 10.57031042701124
# ----------------------
#
# Calculating eig number 137
#
# ----------------------
# Converged at step 4:
#
# k = 10.570310427011242
# ----------------------
#
# Calculating eig number 138
#
# ----------------------
# Converged at step 5:
#
# k = 10.57031042701124
# ----------------------
#
# Calculating eig number 139
#
# ----------------------
# Converged at step 5:
#
# k = 10.570310427011242
# ----------------------
#
# Calculating eig number 140
#
# ----------------------
# Converged at step 5:
#
# k = 10.570310427011242
# ----------------------
#
# Calculating eig number 141
#
# ----------------------
# Converged at step 5:
#
# k = 10.570310427011242
# ----------------------
#
# Calculating eig number 142
#
# ----------------------
# Converged at step 5:
#
# k = 10.570310427011242
# ----------------------
#
# Calculating eig number 143
#
# ----------------------
# Converged at step 3:
#
# k = 11.6150566630603
# ----------------------
#
# Calculating eig number 144
#
# ----------------------
# Converged at step 3:
#
# k = 11.615056663060296
# ----------------------
#
# Calculating eig number 145
#
# ----------------------
# Converged at step 3:
#
# k = 11.6150566630603
# ----------------------
#
# Calculating eig number 146
#
# ----------------------
# Converged at step 3:
#
# k = 11.6150566630603
# ----------------------
#
# Calculating eig number 147
#
# ----------------------
# Converged at step 3:
#
# k = 11.615056663060301
# ----------------------
#
# Calculating eig number 148
#
# ----------------------
# Converged at step 3:
#
# k = 11.6150566630603
# ----------------------
#
# Calculating eig number 149
#
# ----------------------
# Converged at step 3:
#
# k = 11.615056663060301
# ----------------------
#
# Calculating eig number 150
#
# ----------------------
# Converged at step 3:
#
# k = 11.6150566630603
# ----------------------
#
# Calculating eig number 151
#
# ----------------------
# Converged at step 3:
#
# k = 11.615056663060301
# ----------------------
#
# Calculating eig number 152
#
# ----------------------
# Converged at step 3:
#
# k = 11.6150566630603
# ----------------------
#
# Calculating eig number 153
#
# ----------------------
# Converged at step 4:
#
# k = 11.615056663060297
# ----------------------
#
# Calculating eig number 154
#
# ----------------------
# Converged at step 4:
#
# k = 11.615056663060297
# ----------------------
#
# Calculating eig number 155
#
# ----------------------
# Converged at step 4:
#
# k = 11.6150566630603
# ----------------------
#
# Calculating eig number 156
#
# ----------------------
# Converged at step 4:
#
# k = 11.615056663060297
# ----------------------
#
# Calculating eig number 157
#
# ----------------------
# Converged at step 4:
#
# k = 11.615056663060296
# ----------------------
#
# Calculating eig number 158
#
# ----------------------
# Converged at step 4:
#
# k = 11.615056663060297
# ----------------------
#
# Calculating eig number 159
#
# ----------------------
# Converged at step 3:
#
# k = 12.183116348233238
# ----------------------
#
# Calculating eig number 160
#
# ----------------------
# Converged at step 3:
#
# k = 12.183116348233234
# ----------------------
#
# Calculating eig number 161
#
# ----------------------
# Converged at step 3:
#
# k = 12.183116348233236
# ----------------------
#
# Calculating eig number 162
#
# ----------------------
# Converged at step 3:
#
# k = 12.183116348233236
# ----------------------
#
# Calculating eig number 163
#
# ----------------------
# Converged at step 3:
#
# k = 12.183116348233238
# ----------------------
#
# Calculating eig number 164
#
# ----------------------
# Converged at step 4:
#
# k = 12.183116348233236
# ----------------------
#
# Calculating eig number 165
#
# ----------------------
# Converged at step 4:
#
# k = 12.183116348233238
# ----------------------
#
# Calculating eig number 166
#
# ----------------------
# Converged at step 4:
#
# k = 12.183116348233238
# ----------------------
#
# Calculating eig number 167
#
# ----------------------
# Converged at step 4:
#
# k = 12.183116348233234
# ----------------------
#
# Calculating eig number 168
#
# ----------------------
# Converged at step 4:
#
# k = 12.183116348233236
# ----------------------
#
# Calculating eig number 169
#
# ----------------------
# Converged at step 4:
#
# k = 12.183116348233236
# ----------------------
#
# Calculating eig number 170
#
# ----------------------
# Converged at step 4:
#
# k = 12.183116348233233
# ----------------------
#
# Calculating eig number 171
#
# ----------------------
# Converged at step 5:
#
# k = 12.183116348233234
# ----------------------
#
# Calculating eig number 172
#
# ----------------------
# Converged at step 5:
#
# k = 12.183116348233234
# ----------------------
#
# Calculating eig number 173
#
# ----------------------
# Converged at step 5:
#
# k = 12.183116348233238
# ----------------------
#
# Calculating eig number 174
#
# ----------------------
# Converged at step 5:
#
# k = 12.183116348233234
# ----------------------
#
# Calculating eig number 175
#
# ----------------------
# Converged at step 5:
#
# k = 12.183116348233238
# ----------------------
#
# Calculating eig number 176
#
# ----------------------
# Converged at step 5:
#
# k = 12.183116348233234
# ----------------------
#
# Calculating eig number 177
#
# ----------------------
# Converged at step 5:
#
# k = 12.183116348233238
# ----------------------
#
# Calculating eig number 178
#
# ----------------------
# Converged at step 5:
#
# k = 12.183116348233234
# ----------------------
#
# Calculating eig number 179
#
# ----------------------
# Converged at step 5:
#
# k = 12.183116348233234
# ----------------------
#
# Calculating eig number 180
#
# ----------------------
# Converged at step 5:
#
# k = 12.183116348233238
# ----------------------
#
# Calculating eig number 181
#
# ----------------------
# Converged at step 5:
#
# k = 12.183116348233238
# ----------------------
#
# Calculating eig number 182
#
# ----------------------
# Converged at step 5:
#
# k = 12.183116348233234
# ----------------------
#
# Calculating eig number 183
#
# ----------------------
# Converged at step 5:
#
# k = 12.183116348233238
# ----------------------
#
# Calculating eig number 184
#
# ----------------------
# Converged at step 5:
#
# k = 12.183116348233236
# ----------------------
#
# Calculating eig number 185
#
# ----------------------
# Converged at step 5:
#
# k = 12.183116348233233
# ----------------------
#
# Calculating eig number 186
#
# ----------------------
# Converged at step 4:
#
# k = 14.286229740319564
# ----------------------
#
# Calculating eig number 187
#
# ----------------------
# Converged at step 4:
#
# k = 14.286229740319564
# ----------------------
#
# Calculating eig number 188
#
# ----------------------
# Converged at step 4:
#
# k = 14.286229740319563
# ----------------------
#
# Calculating eig number 189
#
# ----------------------
# Converged at step 4:
#
# k = 14.286229740319564
# ----------------------
#
# Calculating eig number 190
#
# ----------------------
# Converged at step 3:
#
# k = 14.286229740319564
# ----------------------
#
# Calculating eig number 191
#
# ----------------------
# Converged at step 3:
#
# k = 14.286229740319564
# ----------------------
#
# Calculating eig number 192
#
# ----------------------
# Converged at step 3:
#
# k = 14.286229740319564
# ----------------------
#
# Calculating eig number 193
#
# ----------------------
# Converged at step 3:
#
# k = 14.286229740319566
# ----------------------
#
# Calculating eig number 194
#
# ----------------------
# Converged at step 3:
#
# k = 14.286229740319568
# ----------------------
#
# Calculating eig number 195
#
# ----------------------
# Converged at step 3:
#
# k = 14.286229740319563
# ----------------------
#
# Calculating eig number 196
#
# ----------------------
# Converged at step 3:
#
# k = 14.286229740319564
# ----------------------
#
# Calculating eig number 197
#
# ----------------------
# Converged at step 3:
#
# k = 14.286229740319563
# ----------------------
#
# Calculating eig number 198
#
# ----------------------
# Converged at step 3:
#
# k = 14.286229740319564
# ----------------------
#
# Calculating eig number 199
#
# ----------------------
# Converged at step 3:
#
# k = 14.286229740319566
# ----------------------
#
# Calculating eig number 200
#
# ----------------------
# Converged at step 3:
#
# k = 14.286229740319564
# ----------------------
# num_Vs = 196
#
#
#
#
#
# Calculating eig number 0
#
# ----------------------
# Converged at step 0:
#
# k = 1.604872396231845e-16
# ----------------------
#
# Calculating eig number 1
#
# ----------------------
# Converged at step 4:
#
# k = 4.352789397553277
# ----------------------
#
# ...
#
# k = 6.192358752309648
# ----------------------
#
# Calculating eig number 67
#
# ----------------------
# Converged at step 6:
#
# k = 6.192358752309966
# ----------------------
#
# Calculating eig number 68
#
# ----------------------
# Converged at step 6:
#
# k = 6.192358752309553
# ----------------------
#
# Calculating eig number 69
#
# ----------------------
# Converged at step 6:
#
# k = 6.192358752309707
# ----------------------
#
# Calculating eig number 70
#
# ----------------------
# Converged at step 6:
#
# k = 6.192358752310118
# ----------------------
#
# Calculating eig number 71
#
# ----------------------
# Converged at step 6:
#
# k = 6.192358752309983
# ----------------------
#
# Calculating eig number 72
#
# ----------------------
# Converged at step 6:
#
# k = 6.192358752309822
# ----------------------
#
# Calculating eig number 73
#
# ----------------------
# Converged at step 4:
#
# k = 8.753937780714926
# ----------------------
#
# Calculating eig number 74
#
# ----------------------
# Converged at step 4:
#
# k = 8.75393778071504
# ----------------------
#
# Calculating eig number 75
#
# ----------------------
# Converged at step 4:
#
# k = 8.75393778071529
# ----------------------
#
# Calculating eig number 76
#
# ----------------------
# Converged at step 4:
#
# k = 8.753937780714923
# ----------------------
#
# Calculating eig number 77
#
# ----------------------
# Converged at step 4:
#
# k = 8.753937780714871
# ----------------------
#
# Calculating eig number 78
#
# ----------------------
# Converged at step 4:
#
# k = 8.753937780714976
# ----------------------
#
# Calculating eig number 79
#
# ----------------------
# Converged at step 4:
#
# k = 8.753937780714951
# ----------------------
#
# Calculating eig number 80
#
# ----------------------
# Converged at step 4:
#
# k = 8.753937780714983
# ----------------------
#
# Calculating eig number 81
#
# ----------------------
# Converged at step 4:
#
# k = 8.753937780715225
# ----------------------
#
# Calculating eig number 82
#
# ----------------------
# Converged at step 4:
#
# k = 8.75393778071489
# ----------------------
#
# Calculating eig number 83
#
# ----------------------
# Converged at step 4:
#
# k = 8.75393778071485
# ----------------------
#
# Calculating eig number 84
#
# ----------------------
# Converged at step 4:
#
# k = 8.753937780714988
# ----------------------
#
# Calculating eig number 85
#
# ----------------------
# Converged at step 4:
#
# k = 8.753937780715384
# ----------------------
#
# Calculating eig number 86
#
# ----------------------
# Converged at step 4:
#
# k = 8.753937780715244
# ----------------------
#
# Calculating eig number 87
#
# ----------------------
# Converged at step 4:
#
# k = 8.753937780715003
# ----------------------
#
# Calculating eig number 88
#
# ----------------------
# Converged at step 4:
#
# k = 8.753937780715114
# ----------------------
#
# Calculating eig number 89
#
# ----------------------
# Converged at step 3:
#
# k = 8.753937780715027
# ----------------------
#
# Calculating eig number 90
#
# ----------------------
# Converged at step 3:
#
# k = 8.753937780715189
# ----------------------
#
# Calculating eig number 91
#
# ----------------------
# Converged at step 3:
#
# k = 8.753937780715004
# ----------------------
#
# Calculating eig number 92
#
# ----------------------
# Converged at step 3:
#
# k = 8.753937780715098
# ----------------------
#
# Calculating eig number 93
#
# ----------------------
# Converged at step 3:
#
# k = 8.753937780715104
# ----------------------
#
# Calculating eig number 94
#
# ----------------------
# Converged at step 3:
#
# k = 8.753937780715065
# ----------------------
#
# Calculating eig number 95
#
# ----------------------
# Converged at step 3:
#
# k = 8.753937780715386
# ----------------------
#
# Calculating eig number 96
#
# ----------------------
# Converged at step 4:
#
# k = 8.75393778071491
# ----------------------
#
# Calculating eig number 97
#
# ----------------------
# Converged at step 4:
#
# k = 8.753937780714939
# ----------------------
#
# Calculating eig number 98
#
# ----------------------
# Converged at step 4:
#
# k = 8.753937780715125
# ----------------------
#
# Calculating eig number 99
#
# ----------------------
# Converged at step 4:
#
# k = 8.75393778071498
# ----------------------
#
# Calculating eig number 100
#
# ----------------------
# Converged at step 5:
#
# k = 8.753937780715251
# ----------------------
#
# Calculating eig number 101
#
# ----------------------
# Converged at step 5:
#
# k = 8.753937780715129
# ----------------------
#
# Calculating eig number 102
#
# ----------------------
# Converged at step 5:
#
# k = 8.75393778071519
# ----------------------
#
# Calculating eig number 103
#
# ----------------------
# Converged at step 5:
#
# k = 8.753937780714915
# ----------------------
#
# Calculating eig number 104
#
# ----------------------
# Converged at step 5:
#
# k = 8.753937780715393
# ----------------------
#
# Calculating eig number 105
#
# ----------------------
# Converged at step 5:
#
# k = 8.75393778071531
# ----------------------
#
# Calculating eig number 106
#
# ----------------------
# Converged at step 5:
#
# k = 8.75393778071514
# ----------------------
#
# Calculating eig number 107
#
# ----------------------
# Converged at step 4:
#
# k = 9.788712029984781
# ----------------------
#
# Calculating eig number 108
#
# ----------------------
# Converged at step 3:
#
# k = 9.788712029984886
# ----------------------
#
# Calculating eig number 109
#
# ----------------------
# Converged at step 3:
#
# k = 9.788712029984927
# ----------------------
#
# Calculating eig number 110
#
# ----------------------
# Converged at step 3:
#
# k = 9.788712029985177
# ----------------------
#
# Calculating eig number 111
#
# ----------------------
# Converged at step 3:
#
# k = 9.788712029985092
# ----------------------
#
# Calculating eig number 112
#
# ----------------------
# Converged at step 3:
#
# k = 9.788712029984673
# ----------------------
#
# Calculating eig number 113
#
# ----------------------
# Converged at step 3:
#
# k = 9.788712029984932
# ----------------------
#
# Calculating eig number 114
#
# ----------------------
# Converged at step 3:
#
# k = 9.788712029985001
# ----------------------
#
# Calculating eig number 115
#
# ----------------------
# Converged at step 3:
#
# k = 9.788712029985163
# ----------------------
#
# Calculating eig number 116
#
# ----------------------
# Converged at step 3:
#
# k = 9.788712029984884
# ----------------------
#
# Calculating eig number 117
#
# ----------------------
# Converged at step 4:
#
# k = 9.788712029984934
# ----------------------
#
# Calculating eig number 118
#
# ----------------------
# Converged at step 4:
#
# k = 9.788712029985046
# ----------------------
#
# Calculating eig number 119
#
# ----------------------
# Converged at step 4:
#
# k = 9.788712029985113
# ----------------------
#
# Calculating eig number 120
#
# ----------------------
# Converged at step 4:
#
# k = 9.78871202998501
# ----------------------
#
# Calculating eig number 121
#
# ----------------------
# Converged at step 5:
#
# k = 9.788712029984925
# ----------------------
#
# Calculating eig number 122
#
# ----------------------
# Converged at step 5:
#
# k = 9.788712029984907
# ----------------------
#
# Calculating eig number 123
#
# ----------------------
# Converged at step 5:
#
# k = 9.788712029985044
# ----------------------
#
# Calculating eig number 124
#
# ----------------------
# Converged at step 5:
#
# k = 9.788712029984948
# ----------------------
#
# Calculating eig number 125
#
# ----------------------
# Converged at step 5:
#
# k = 9.788712029985257
# ----------------------
#
# Calculating eig number 126
#
# ----------------------
# Converged at step 5:
#
# k = 9.788712029985014
# ----------------------
#
# Calculating eig number 127
#
# ----------------------
# Converged at step 5:
#
# k = 9.788712029984975
# ----------------------
#
# Calculating eig number 128
#
# ----------------------
# Converged at step 5:
#
# k = 9.788712029985101
# ----------------------
#
# Calculating eig number 129
#
# ----------------------
# Converged at step 5:
#
# k = 9.788712029984925
# ----------------------
#
# Calculating eig number 130
#
# ----------------------
# Converged at step 5:
#
# k = 9.788712029985076
# ----------------------
#
# Calculating eig number 131
#
# ----------------------
# Converged at step 5:
#
# k = 9.788712029984922
# ----------------------
#
# Calculating eig number 132
#
# ----------------------
# Converged at step 5:
#
# k = 9.788712029985023
# ----------------------
#
# Calculating eig number 133
#
# ----------------------
# Converged at step 5:
#
# k = 9.788712029985042
# ----------------------
#
# Calculating eig number 134
#
# ----------------------
# Converged at step 5:
#
# k = 9.788712029985168
# ----------------------
#
# Calculating eig number 135
#
# ----------------------
# Converged at step 5:
#
# k = 9.788712029984854
# ----------------------
#
# Calculating eig number 136
#
# ----------------------
# Converged at step 5:
#
# k = 9.788712029984854
# ----------------------
#
# Calculating eig number 137
#
# ----------------------
# Converged at step 5:
#
# k = 9.788712029984861
# ----------------------
#
# Calculating eig number 138
#
# ----------------------
# Converged at step 5:
#
# k = 9.788712029984938
# ----------------------
#
# Calculating eig number 139
#
# ----------------------
# Converged at step 5:
#
# k = 9.788712029985165
# ----------------------
#
# Calculating eig number 140
#
# ----------------------
# Converged at step 5:
#
# k = 9.788712029984811
# ----------------------
#
# Calculating eig number 141
#
# ----------------------
# Converged at step 5:
#
# k = 9.788712029985131
# ----------------------
#
# Calculating eig number 142
#
# ----------------------
# Converged at step 5:
#
# k = 9.788712029984916
# ----------------------
#
# Calculating eig number 143
#
# ----------------------
# Converged at step 5:
#
# k = 9.78871202998497
# ----------------------
#
# Calculating eig number 144
#
# ----------------------
# Converged at step 4:
#
# k = 12.382677673037717
# ----------------------
#
# Calculating eig number 145
#
# ----------------------
# Converged at step 4:
#
# k = 12.38267767303765
# ----------------------
#
# Calculating eig number 146
#
# ----------------------
# Converged at step 4:
#
# k = 12.382677673037604
# ----------------------
#
# Calculating eig number 147
#
# ----------------------
# Converged at step 4:
#
# k = 12.382677673037819
# ----------------------
#
# Calculating eig number 148
#
# ----------------------
# Converged at step 4:
#
# k = 12.382677673037708
# ----------------------
#
# Calculating eig number 149
#
# ----------------------
# Converged at step 4:
#
# k = 12.382677673037923
# ----------------------
#
# Calculating eig number 150
#
# ----------------------
# Converged at step 4:
#
# k = 12.382677673037591
# ----------------------
#
# Calculating eig number 151
#
# ----------------------
# Converged at step 4:
#
# k = 12.382677673037682
# ----------------------
#
# Calculating eig number 152
#
# ----------------------
# Converged at step 4:
#
# k = 12.382677673037755
# ----------------------
#
# Calculating eig number 153
#
# ----------------------
# Converged at step 4:
#
# k = 12.382677673037717
# ----------------------
#
# Calculating eig number 154
#
# ----------------------
# Converged at step 4:
#
# k = 12.382677673037492
# ----------------------
#
# Calculating eig number 155
#
# ----------------------
# Converged at step 4:
#
# k = 12.382677673037582
# ----------------------
#
# Calculating eig number 156
#
# ----------------------
# Converged at step 4:
#
# k = 12.382677673037978
# ----------------------
#
# Calculating eig number 157
#
# ----------------------
# Converged at step 4:
#
# k = 12.382677673037637
# ----------------------
#
# Calculating eig number 158
#
# ----------------------
# Converged at step 4:
#
# k = 12.382677673037744
# ----------------------
#
# Calculating eig number 159
#
# ----------------------
# Converged at step 3:
#
# k = 12.382677673037911
# ----------------------
#
# Calculating eig number 160
#
# ----------------------
# Converged at step 3:
#
# k = 12.382677673037831
# ----------------------
#
# Calculating eig number 161
#
# ----------------------
# Converged at step 3:
#
# k = 12.382677673037836
# ----------------------
#
# Calculating eig number 162
#
# ----------------------
# Converged at step 3:
#
# k = 12.382677673037836
# ----------------------
#
# Calculating eig number 163
#
# ----------------------
# Converged at step 3:
#
# k = 12.382677673037604
# ----------------------
#
# Calculating eig number 164
#
# ----------------------
# Converged at step 3:
#
# k = 12.382677673037566
# ----------------------
#
# Calculating eig number 165
#
# ----------------------
# Converged at step 3:
#
# k = 12.382677673037765
# ----------------------
#
# Calculating eig number 166
#
# ----------------------
# Converged at step 3:
#
# k = 12.382677673037646
# ----------------------
#
# Calculating eig number 167
#
# ----------------------
# Converged at step 3:
#
# k = 12.382677673037744
# ----------------------
#
# Calculating eig number 168
#
# ----------------------
# Converged at step 4:
#
# k = 12.382677673037918
# ----------------------
#
# Calculating eig number 169
#
# ----------------------
# Converged at step 4:
#
# k = 12.382677673037742
# ----------------------
#
# Calculating eig number 170
#
# ----------------------
# Converged at step 4:
#
# k = 12.382677673037847
# ----------------------
#
# Calculating eig number 171
#
# ----------------------
# Converged at step 4:
#
# k = 12.382677673037723
# ----------------------
#
# Calculating eig number 172
#
# ----------------------
# Converged at step 4:
#
# k = 12.382677673037708
# ----------------------
#
# Calculating eig number 173
#
# ----------------------
# Converged at step 4:
#
# k = 12.382677673037694
# ----------------------
#
# Calculating eig number 174
#
# ----------------------
# Converged at step 5:
#
# k = 12.38267767303761
# ----------------------
#
# Calculating eig number 175
#
# ----------------------
# Converged at step 5:
#
# k = 12.382677673037648
# ----------------------
#
# Calculating eig number 176
#
# ----------------------
# Converged at step 3:
#
# k = 13.123589048899927
# ----------------------
#
# Calculating eig number 177
#
# ----------------------
# Converged at step 3:
#
# k = 13.123589048899836
# ----------------------
#
# Calculating eig number 178
#
# ----------------------
# Converged at step 3:
#
# k = 13.123589048899658
# ----------------------
#
# Calculating eig number 179
#
# ----------------------
# Converged at step 3:
#
# k = 13.123589048899465
# ----------------------
#
# Calculating eig number 180
#
# ----------------------
# Converged at step 3:
#
# k = 13.123589048899754
# ----------------------
#
# Calculating eig number 181
#
# ----------------------
# Converged at step 3:
#
# k = 13.123589048899936
# ----------------------
#
# Calculating eig number 182
#
# ----------------------
# Converged at step 3:
#
# k = 13.123589048899658
# ----------------------
#
# Calculating eig number 183
#
# ----------------------
# Converged at step 4:
#
# k = 13.123589048899833
# ----------------------
#
# Calculating eig number 184
#
# ----------------------
# Converged at step 4:
#
# k = 13.123589048899593
# ----------------------
#
# Calculating eig number 185
#
# ----------------------
# Converged at step 4:
#
# k = 13.123589048899714
# ----------------------
#
# Calculating eig number 186
#
# ----------------------
# Converged at step 4:
#
# k = 13.123589048899573
# ----------------------
#
# Calculating eig number 187
#
# ----------------------
# Converged at step 4:
#
# k = 13.123589048899857
# ----------------------
#
# Calculating eig number 188
#
# ----------------------
# Converged at step 4:
#
# k = 13.123589048899655
# ----------------------
#
# Calculating eig number 189
#
# ----------------------
# Converged at step 5:
#
# k = 13.123589048899825
# ----------------------
#
# Calculating eig number 190
#
# ----------------------
# Converged at step 3:
#
# k = 13.836089944879673
# ----------------------
#
# Calculating eig number 191
#
# ----------------------
# Converged at step 3:
#
# k = 13.836089944879342
# ----------------------
#
# Calculating eig number 192
#
# ----------------------
# Converged at step 3:
#
# k = 13.83608994487945
# ----------------------
#
# Calculating eig number 193
#
# ----------------------
# Converged at step 3:
#
# k = 13.836089944879456
# ----------------------
#
# Calculating eig number 194
#
# ----------------------
# Converged at step 3:
#
# k = 13.836089944879557
# ----------------------
#
# Calculating eig number 195
#
# ----------------------
# Converged at step 3:
#
# k = 13.836089944879488
# ----------------------
#
# Calculating eig number 196
#
# ----------------------
# Converged at step 3:
#
# k = 13.83608994487952
# ----------------------
#
# Calculating eig number 197
#
# ----------------------
# Converged at step 4:
#
# k = 13.83608994487953
# ----------------------
#
# Calculating eig number 198
#
# ----------------------
# Converged at step 4:
#
# k = 13.836089944879598
# ----------------------
#
# Calculating eig number 199
#
# ----------------------
# Converged at step 4:
#
# k = 13.836089944879626
# ----------------------
#
# Calculating eig number 200
#
# ----------------------
# Converged at step 4:
#
# k = 13.836089944879616
# ----------------------

# %%
class Eigendata:

    def __init__(self, data):

        self.data = data
        self.V_nums = np.array(list(self.data.keys()))
        self.eigendata_indices = list(self.data[self.V_nums[0]].keys())
        self.graph_eigenvalues, self.PDE_eigenvalues = self.get_eigenvalues()
        self.relative_eigenvalue_differences = self.calculate_relative_eigenvalue_differences()
        self.relative_eigenfunction_differences = self.calculate_relative_eigenfunction_differences()

    def get_eigenvalues(self):

        graph_eigenvalues = {}
        PDE_eigenvalues = {}
        for m, n in self.eigendata_indices:
            graph_eigenvalues[m, n] = []
            PDE_eigenvalues[m, n] = self.data[self.V_nums[0]][m, n]['PDE']['eigenvalue']
            for num_Vs in self.V_nums:
                graph_eigenvalues[m, n].append(self.data[num_Vs][m, n]['graph']['eigenvalue'])

        return graph_eigenvalues, PDE_eigenvalues
        
    def calculate_relative_eigenvalue_differences(self):

        relative_eigenvalue_differences = {}
        for m, n in self.eigendata_indices:
            pde_eig = self.PDE_eigenvalues[m, n]
            if np.abs(self.PDE_eigenvalues[m, n]) < 1e-14:
                rel_errs = [np.mean(np.abs(i - pde_eig)) for i in self.graph_eigenvalues[m, n]]
            else:
                rel_errs = [np.mean(np.abs((i - pde_eig) / pde_eig)) for i in self.graph_eigenvalues[m, n]]
            relative_eigenvalue_differences[m, n] = np.array(rel_errs)

        return relative_eigenvalue_differences

    def calculate_relative_eigenfunction_differences(self):

        relative_eigenfunction_differences = {}
        for m, n in self.eigendata_indices:
            relative_eigenfunction_differences[m, n] = []
            for num_Vs in self.V_nums:
                rel_errs = [(i - j).norm() for i, j in zip(self.data[num_Vs][m, n]['graph']['eigenfunction'], 
                                                           self.data[num_Vs][m, n]['PDE']['eigenfunction'])]
                relative_eigenfunction_differences[m, n].append(np.mean(rel_errs))

        return relative_eigenfunction_differences

class Graph_Modes:

    def __init__(self, g, graph_eigenvalues):

        (self.graph_eigenvalues,
         self.graph_eigenvectors, 
         self.null_space_dims) = self.calculate_graph_eigenvectors(g, graph_eigenvalues)
        self.graph_eigenfunctions = self.construct_graph_eigenfunctions(g)
    
    def construct_graph_eigenfunction(self, g, eigenvalue, eigenvector):

        graph_eigenfunction = []

        if np.abs(eigenvalue) < 1e-13:
            for e_num, ((v_num, w_num), l_vw) in enumerate(g.E_lengths_by_v_num.items()):
                edge_mode = np.ones(g.g_coords[e_num].shape[1])
                graph_eigenfunction.append(edge_mode)
        else:
            for e_num, ((v_num, w_num), l_vw) in enumerate(g.E_lengths_by_v_num.items()):
                parametrised_edge = np.linspace(0, l_vw, g.g_coords[e_num].shape[1])

                edge_mode = ((eigenvector[v_num] * np.sin(eigenvalue * parametrised_edge[::-1])
                            + eigenvector[w_num] * np.sin(eigenvalue * parametrised_edge)) 
                            / np.sin(eigenvalue * l_vw))
                
                graph_eigenfunction.append(edge_mode)

        graph_eigenfunction = Graph_Function(graph_eigenfunction, g.g_coords).normalize()

        return graph_eigenfunction
    
    def construct_graph_eigenfunctions(self, g):

        graph_eigenfunctions = []
        for eigenvalue, eigenvector in zip(self.graph_eigenvalues, self.graph_eigenvectors.T):
            graph_eigenfunctions.append(self.construct_graph_eigenfunction(g, eigenvalue, eigenvector))
        
        return graph_eigenfunctions
    
    def calculate_graph_eigenvectors(self, g, graph_eigenvalues):

        graph_eigenvectors = []
        null_space_dims = []

        for k in graph_eigenvalues:

            if np.abs(k) < 1e-12:
                Q, R, perm, r = sparseqr.qr(g.construct_L(k), tolerance=None)
            else:
                Q, R, perm, r = sparseqr.qr(g.construct_L(k), tolerance=1e-8)

            dim_null_space = len(g.interior_V_num) - r

            null_vectors = Q.toarray()[:, -dim_null_space:]

            null_space_dims.append(dim_null_space)
            graph_eigenvectors.append(null_vectors)

        graph_eigenvalues = np.repeat(graph_eigenvalues, null_space_dims)
        graph_eigenvectors = np.hstack(graph_eigenvectors)

        return graph_eigenvalues, graph_eigenvectors, null_space_dims 
    
def generate_graph_linewidth(num_Vs):
    # Just a heuristic
    return np.max([0.5, -0.086 * np.sqrt(num_Vs) + 7.66])

def style_plot(fig, ax, aspect="equal", no_ticks=False, no_xticks=False, no_yticks=False):

    # Remove white space
    fig.tight_layout()

    # Makes axes aspect equal
    if aspect:
        ax.set_aspect(aspect)

    # Make tick labels bold font
    for label in ax.get_xticklabels() + ax.get_yticklabels():
        label.set_fontweight('bold')
        label.set_fontsize(20)

    # Make border thicker
    for spine in ax.spines.values():
        spine.set_linewidth(2) 

    # xy_ticks
    major_tick_length = 7
    minor_tick_length = 4
    if no_ticks:
        major_xtick_length = 0
        major_ytick_length = 0
        minor_xtick_length = 0
        minor_ytick_length = 0
    elif no_xticks:
        major_xtick_length = 0
        major_ytick_length = major_tick_length
        minor_xtick_length = 0
        minor_ytick_length = minor_tick_length
    elif no_yticks:
        major_xtick_length = major_tick_length
        major_ytick_length = 0
        minor_xtick_length = minor_tick_length
        minor_ytick_length = 0
    else:
        major_xtick_length = major_tick_length
        major_ytick_length = major_tick_length
        minor_xtick_length = minor_tick_length
        minor_ytick_length = minor_tick_length
    ax.tick_params(axis='x', which='major', length=major_xtick_length, width=2, direction='out')
    ax.tick_params(axis='y', which='major', length=major_ytick_length, width=2, direction='out')
    ax.tick_params(axis='x', which='minor', length=minor_xtick_length, width=1, direction='out')
    ax.tick_params(axis='y', which='minor', length=minor_ytick_length, width=1, direction='out')
    
class Graph_Function:

    def __init__(self, data, domain=None):

        self.data = data
        if domain is not None:
            self.domain = [edge_domain.copy() for edge_domain in domain]

    def __add__(self, other):

        if not isinstance(other, Graph_Function):
            return NotImplemented
        
        result = [i + j for i, j in zip(self.data, other.data)]

        return Graph_Function(result, self.domain)

    def __sub__(self, other):

        if not isinstance(other, Graph_Function):
            return NotImplemented
        
        result = [i - j for i, j in zip(self.data, other.data)]

        return Graph_Function(result, self.domain)

    def __mul__(self, other):

        if isinstance(other, Graph_Function):
            result = [i * j for i, j in zip(self.data, other.data)]

        elif np.isscalar(other):  
            result = [arr * other for arr in self.data]

        else:
            return NotImplemented
        
        return Graph_Function(result, self.domain)

    def __rmul__(self, other):

        return self.__mul__(other)

    def __truediv__(self, other):

        if isinstance(other, Graph_Function):
            result = [i / j for i, j in zip(self.data, other.data)]

        elif np.isscalar(other):  
            result = [arr / other for arr in self.data]

        else:
            return NotImplemented
        
        return Graph_Function(result, self.domain)

    def __rtruediv__(self, other):

        if np.isscalar(other):
            result = [other / arr for arr in self.data]

        else:
            return NotImplemented
        
        return Graph_Function(result, self.domain)

    def __eq__(self, other):

        if not isinstance(other, Graph_Function):
            return NotImplemented
        
        return all(np.array_equal(i, j) for i, j in zip(self.data, other.data))

    def __repr__(self):

        return f"Graph_Function({self.data})"
    
    def norm(self):

        return np.sqrt(self.dot(self))
    
    def normalize(self):

        norm = self.norm()

        if norm == 0:
            raise ValueError("Cannot normalize a zero vector.")

        result = [arr / norm for arr in self.data]

        return Graph_Function(result, self.domain)
    
    def dot(self, other):
        
        if not isinstance(other, Graph_Function):
            return NotImplemented
        
        if (self.domain is None) and not (other.domain is None):
            self.domain = other.domain
        elif not (self.domain is None) and (other.domain is None):
            other.domain = self.domain
        elif (self.domain is None) and (other.domain is None):
            raise ValueError("Graph_Functions need domain attributes.")
        
        graph_inner_product = 0

        for f0_edge, f1_edge, edge in zip(self.data, other.data, self.domain):
            edge_length = np.linalg.norm([edge[0, 0] - edge[0, -1], edge[1, 0] - edge[1, -1]])
            edge_param = np.linspace(0, edge_length, edge.shape[1])
            graph_inner_product += scipy.integrate.trapezoid(f0_edge * f1_edge, edge_param)

        return graph_inner_product

# %%
class Projector:

    def __init__(self, g, eigenvalues):

        self.data = {}
        self.modes = Graph_Modes(g, eigenvalues)
        self.V_coords = g.V_coords
        self.g_coords = g.g_coords

    def generate_basis_functions(self, m, n):

        if (m > 2) or (n > 2) or (m < 0) or (n < 0):
            raise ValueError("Projector is only set up for m, n \in [0, 1, 2]")

        if (m == 0) and (n == 0):
            return lambda x, y: np.ones(x.shape), 

        cc = lambda m, n: lambda x, y: np.cos(2 * np.pi * m * x) * np.cos(2 * np.pi * n * y)
        cs = lambda m, n: lambda x, y: np.cos(2 * np.pi * m * x) * np.sin(2 * np.pi * n * y)
        sc = lambda m, n: lambda x, y: np.sin(2 * np.pi * m * x) * np.cos(2 * np.pi * n * y)
        ss = lambda m, n: lambda x, y: np.sin(2 * np.pi * m * x) * np.sin(2 * np.pi * n * y)

        if m == 0:
            return cc(m, n), cs(m, n), cc(n, m), sc(n, m)
        elif n == 0:
            return cc(m, n), sc(m, n), cc(n, m), cs(n, m)
        elif m == n:
            return cc(m, n), cs(m, n), sc(m, n), ss(m, n),
        else:
            return (cc(m, n), cs(m, n), sc(m, n), ss(m, n), 
                    cc(n, m), cs(n, m), sc(n, m), ss(n, m))

    def construct_pde_functions(self, m, n, function_domain="vertices"):

        basis_functions = self.generate_basis_functions(m, n)

        if function_domain == "vertices":
            x, y = self.V_coords[:, 0], self.V_coords[:, 1]

            pde_eigenvectors = [function(x, y) for function in basis_functions]
            pde_eigenvectors = [function / np.linalg.norm(function) for function in pde_eigenvectors]
            pde_eigenvectors = np.vstack((pde_eigenvectors)).T

            return pde_eigenvectors
        
        elif function_domain == "graph":
            pde_eigenfunctions = [[] for _ in range(len(basis_functions))]

            for edge in self.g_coords:
                x, y = edge
                
                for i in range(len(basis_functions)):
                    pde_eigenfunctions[i].append(basis_functions[i](x, y))

            pde_eigenfunctions = [Graph_Function(pde_eigenfunction, self.g_coords).normalize() 
                                  for pde_eigenfunction in pde_eigenfunctions]
            
            return pde_eigenfunctions

        elif function_domain == "continuum":
            edge = np.linspace(0, 1, 256, endpoint=True)   
            x, y = np.meshgrid(edge, edge)
            pde_eigenfunctions = [function(x, y) for function in basis_functions]

            return x, y, pde_eigenfunctions

    def find_graph_eigenspace(self, m, n):

        pde_eigenvectors = self.construct_pde_functions(m, n, function_domain="vertices")
        num_basis_functions = pde_eigenvectors.shape[1]
        prod = pde_eigenvectors.T @ pde_eigenvectors
        invert_prod = np.linalg.inv(prod)
        proj = (pde_eigenvectors @ invert_prod @ pde_eigenvectors.T)

        keep_args = proj @ self.modes.graph_eigenvectors
        keep_args = np.argsort(np.linalg.norm(keep_args, axis=0))[-num_basis_functions:]

        # Handle when the graph eigenspace is larger than the PDE eigenspace
        uniques, counts = np.unique(np.round(self.modes.graph_eigenvalues[keep_args], 10), return_counts=True)
        new_keep_args = []
        for unique, count in zip(uniques, counts):
            where_equal = np.where(np.abs(self.modes.graph_eigenvalues - unique) < 1e-9)[0]
            if np.shape(where_equal)[0] != count:
                message = (f"For num_Vs={self.V_coords.shape[0]},m={m},n={n}, the graph eigenspace is larger than the PDE eigenspace. " + 
                            "This might be (a) a problem, (b) saying something interesting, or (c) nothing special.")
                warnings.warn(message)
            new_keep_args.append(where_equal)
        keep_args = np.concatenate((new_keep_args))

        return keep_args

    def __call__(self, m, n):

        self.data[m, n] = {"graph": {}, "PDE": {}}

        # Get PDE eigenvalues
        self.data[m, n]["PDE"]["eigenvalue"] = calculate_pde_eigenvalues(m, n)

        # Get PDE eigenfunctions
        pde_eigenfunctions = self.construct_pde_functions(m, n, function_domain="graph")
        self.data[m, n]["PDE"]["eigenfunction"] = pde_eigenfunctions
        
        # Get graph eigenvalues
        keep_args = self.find_graph_eigenspace(m, n)
        self.data[m, n]["graph"]["eigenvalue"] = self.modes.graph_eigenvalues[keep_args]

        # Get graph eigenfunctions
        project_functions = []
        for pde_eigenfunction in pde_eigenfunctions:
            projection = []
            for arg in keep_args:
                ip = pde_eigenfunction.dot(self.modes.graph_eigenfunctions[arg])
                projection.append(ip * self.modes.graph_eigenfunctions[arg])
            project_functions.append(np.sum(projection))
        self.data[m, n]["graph"]["eigenfunction"] = project_functions

# %%
mn = [[0, 0], [0, 1], [0, 2], [1, 1], [1, 2], [2, 2]]

# %%
full_data = {}

for tile_num in tiles_per_dim:

    g = construct_graph.tiling.Tiling(tile_type='bathroom_tile0',
                                      num_horizontal_displacements=tile_num,
                                      num_vertical_displacements=tile_num,
                                      autoplot=False)
    print(g.num_Vs)
    p = Projector(g, eigenvalue_data[g.num_Vs])
    for m, n in mn:
        p(m, n)
    full_data[g.num_Vs] = p.data
# Out:
# 100
# 144
# 196
# 324
# 576
# 900
# 1444
# 2500
# 3844
# 6084
# 10000

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
order_line_color = colors[6]
colors = colors[:6] + colors[7:]
def plot_loglog_rel_err(Num_Vs, rel_errs, show_legend=False):
    fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True, figsize=(7, 6), gridspec_kw={'height_ratios': [6, 1]})
    fig.subplots_adjust(hspace=0.2, )  # adjust space between axes

    # Separate data by size
    for en, rel_err in enumerate(rel_errs.T):
        if np.all(rel_err > 1e-10):
            ax1.loglog(Num_Vs, rel_err, 'o-', markersize=10, c=colors[en], label=str(en))
        else:
            ax2.loglog(Num_Vs, rel_err, 'o-', markersize=10, c=colors[en], label=str(en))
            if np.any(rel_err > 1e-10):
                relevant_data = rel_err[rel_err <= 1e-10]
                ax2.set_ylim(0.1 * np.min(relevant_data), 10 * np.max(relevant_data))

    # Setup convergence line
    ax1_data_lims = (np.min(rel_errs[rel_errs > 1e-10]), np.max(rel_errs[rel_errs > 1e-10]))
    ax1_log_dif = np.log10(ax1_data_lims[1]) - np.log10(ax1_data_lims[0])
    max_order_height = np.max(rel_errs) / np.max(Num_Vs**(-1.))
    order_line_data = max_order_height * Num_Vs**(-0.5) * 10**(0.15 * ax1_log_dif) / 10
    # order_line_data = max_order_height * Num_Vs**(-1.) * 1
    ax1.loglog(Num_Vs, order_line_data, 
               linewidth=4, c=order_line_color)

    # hide the spines between ax and ax2
    ax1.spines.bottom.set_visible(False)
    ax2.spines.top.set_visible(False)
    ax1.xaxis.tick_top()
    ax1.tick_params(labeltop=False)  # don't put tick labels at the top
    ax2.xaxis.tick_bottom()

    # Slanted lines
    d = 0.5
    kwargs = dict(marker=[(-1, -d), (1, d)], markersize=12,
                linestyle="none", color='k', mec='k', mew=3, clip_on=False)
    ax1.plot([0, 1], [0, 0], transform=ax1.transAxes, **kwargs)
    ax2.plot([0, 1], [1, 1], transform=ax2.transAxes, **kwargs)

    style_plot(fig, ax1, aspect=None, no_xticks=True)
    style_plot(fig, ax2, aspect=None)

    if show_legend:
        ax1.legend()
        ax2.legend()

    ax1.set_ylim(2e-3, 2e0)

    return fig, fig.axes

# %%
edata = Eigendata(full_data)

# %%
x = edata.V_nums
y = np.array(list(edata.relative_eigenvalue_differences.values())).T
plot_loglog_rel_err(x, y, show_legend=False)
plt.savefig("tiling/bathroom_tile0_periodic/bathroom_tile0_periodic_tiling_eigenvalue_relerr.png", dpi=200, bbox_inches='tight')

# %%
x = edata.V_nums
y = np.array(list(edata.relative_eigenfunction_differences.values())).T
plot_loglog_rel_err(x, y, show_legend=False)
# plt.savefig("tiling/bathroom_tile0_periodic/bathroom_tile0_periodic_tiling_eigenfunction_relerr.png", dpi=200, bbox_inches='tight')
# Out:
# (<Figure size 700x600 with 2 Axes>, [<Axes: >, <Axes: >])

# %% [markdown]
# ### Plot and save modes for moderate sized graph

# %%
plot_and_save_modes = False

if plot_and_save_modes:

    g = construct_graph.tiling.Tiling(tile_type='bathroom_tile0',
                                        num_horizontal_displacements=tiles_per_dim[4],
                                        num_vertical_displacements=tiles_per_dim[4],
                                        autoplot=False)
    print(g.num_Vs)

    for m, n in mn:
        emodes = full_data[g.num_Vs][m, n]['graph']['eigenfunction']
        for en, emode in enumerate(emodes):
            fig, ax = g.plot_graph(eigenmode=emode.data, return_figax=True, background_color="black", linewidth=generate_graph_linewidth(g.num_Vs))
            plt.savefig(f"tiling/bathroom_tile0_periodic/mode_plots/eigenmode_{g.num_Vs}Vs_m{m}_n{n}_number{en}.png", dpi=200, bbox_inches='tight')
            plt.close()

# %% [markdown]
# ### Plot and save continuum modes

# %%
plot_and_save_continuum_modes = False

if plot_and_save_continuum_modes:

    g = construct_graph.tiling.Tiling(tile_type='hexagonal_tile',
                                        num_horizontal_displacements=tiles_per_dim[0],
                                        num_vertical_displacements=tiles_per_dim[0],
                                        autoplot=False)
    print(g.num_Vs)
    p = Projector(g, eigenvalue_data[g.num_Vs])

    for m, n in mn:
        x, y, A = p.construct_pde_functions(m, n, function_domain="continuum")
        for en, a in enumerate(A):
            fig = plt.figure(figsize=(10, 10))
            ax = fig.add_subplot(111)
            ax.pcolormesh(x, y, a, cmap="plasma", shading='auto')
            style_plot(fig, ax, aspect="equal", no_ticks=True)
            ax.axis('off')
            fig.set_facecolor("black")
            plt.savefig(f"tiling/bathroom_tile0_periodic/PDE_mode_plots/continuum_eigenmode_m{m}_n{n}_number{en}.png", dpi=200, bbox_inches='tight')
            plt.close()
# Out:
# 100
